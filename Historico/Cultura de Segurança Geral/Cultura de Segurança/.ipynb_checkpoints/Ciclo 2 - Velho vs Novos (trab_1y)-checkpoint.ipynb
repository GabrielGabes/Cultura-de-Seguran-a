# %%
## BIBLIOTECAS
import requests
from bs4 import BeautifulSoup

#Manipulação de Dados
import pandas as pd
import numpy as np

import shutil
import os
import pyautogui

import unidecode #arrumar textos

#tempo
import time
from time import sleep

import re #regex

import pyperclip

import statistics
import math

from scipy import stats

import warnings #Warning inuteis
#from pandas.core.common import SettingWithCopyWarning
#warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)

import pyperclip
#from tableone import TableOne

# %%
inicio = time.time() #iniciando o cronometro

df = pd.read_excel("0 - Dados Limpos.xlsx")
df_bruto = df.copy()
df.sample(5)

fim = time.time() #encerrando cronometro
print('Tempo para rodar a simulação:', round(fim - inicio, 3))
# Out:
# Tempo para rodar a simulação: 248.487

# %%
355.797/60
# Out:
# 5.929950000000001

# %%
df.columns
# Out:
# Index(['Ano', 'Unidade',
#        'Qual é sua principal área ou unidade neste hospital?',
#        '1. As pessoas se apoiam umas às outras nesta unidade',
#        '2. Temos pessoas suficientes para lidar com o volume de trabalho',
#        '3. Quando há muito trabalho a ser feito e rapidamente, trabalhamos juntos em equipe para realizar a tarefa',
#        '4. Nesta unidade, as pessoas se tratam com respeito',
#        '5. Os funcionários desta unidade trabalham mais horas do que o recomendado no atendimento a pacientes',
#        '6. Estamos ativamente buscando melhorias para a segurança do paciente',
#        '7. Utilizamos mais funcionários temporários do que o recomendado no atendimento a paciente',
#        '8. Os funcionários sentem que seus erros são usados contra eles',
#        '9. Erros que ocorreram levaram a mudanças positivas nesta unidade',
#        '10. É apenas por acaso que erros mais sérios não acontecem por aqui',
#        '11. Quando uma área nesta unidade fica muito movimentada, as demais ajudam',
#        '12. Quando um evento é notificado, sentimos que o foco se concentra no indivíduo, e não no problema',
#        '13. Quando fazemos mudanças para melhorar a segurança do paciente, nós avaliamos sua efetividade',
#        '14. Trabalhamos “em modo de crise”, tentando fazer coisas demais, rápido demais',
#        '15. A segurança do paciente nunca é sacrificada em prol de se trabalhar mais',
#        '16. Os funcionários se preocupam que seus erros sejam registrados em seu arquivo funcional',
#        '17. Temos problemas com a segurança do paciente nesta unidade',
#        '18. Nossos procedimentos e sistemas são bons para impedir que os erros aconteçam',
#        '19. Meu supervisor/gerente elogia quando vê um trabalho feito de acordo com os procedimentos estabelecidos para a segurança do paciente.',
#        '20. Meu supervisor/gerente considera seriamente as sugestões dos funcionários para melhorar a segurança do paciente',
#        '21. Sempre que a pressão aumenta, meu supervisor/gerente quer que trabalhemos mais rápido, mesmo que isto signifique tomar atalhos',
#        '22. Meu supervisor/gerente ignora problemas recorrentes na segurança do paciente',
#        '23. Recebemos feedback das mudanças implementadas com base nos eventos notificados',
#        '24. Os funcionários falam voluntariamente se vêem algo que possa afetar negativamente o atendimento aos pacientes',
#        '25. Somos informados sobre os erros que acontecem nesta unidade',
#        '26. Os funcionários sentem-se à vontade para questionar decisões ou ações dos que têm mais autoridade',
#        '27. Nesta unidade, discutimos maneiras de impedir que os erros tornem a acontecer',
#        '28. Os funcionários têm receio de perguntar quando algo não parece certo',
#        '29. Quando acontece um erro, mas ele é identificado e corrigido antes de afetar o paciente, com que frequência é notificado?',
#        '30. Quando acontece um erro, mas que não tem potencial de dano ao paciente, com que frequência é notificado?',
#        '31. Quando acontece um erro que poderia prejudicar o paciente, mas isto não ocorreu, com que frequência é notificado?',
#        'Por favor, dê uma nota geral para a segurança do paciente em sua área/unidade de trabalho hospitalar.',
#        '32. A administração do hospital cria um ambiente de trabalho que promove a segurança do paciente',
#        '33. As unidades hospitalares não se coordenam bem entre si.',
#        '34. Coisas "escapam por entre os dedos” quando os pacientes são transferidos de uma unidade para outra',
#        '35. Existe uma boa cooperação entre as unidades hospitalares que precisam trabalhar juntas',
#        '36. Importantes informações sobre a assistência se perdem durante as mudanças de turno',
#        '37. Muitas vezes é desagradável trabalhar unidades com funcionários de outras unidades do hospital',
#        '38. Os problemas com frequência ocorrem na troca de informações entre as unidades do hospital',
#        '39. As ações da administração do hospital mostram que a segurança do paciente é uma prioridade máxima',
#        '40. A administração do hospital parece se interessar pela segurança do paciente apenas quando acontece um evento adverso',
#        '41. As unidades do hospital trabalham bem juntas para prestar o melhor atendimento aos pacientes',
#        '42. As mudanças de turno são problemáticas para os pacientes deste Hospital',
#        'SEÇÃO G: Número de Eventos Notificados  Nos últimos 12 meses, quantas notificações de evento você preencheu e enviou?',
#        'SEÇÃO H: 1. Há quanto tempo você trabalha neste hospital?',
#        'SEÇÃO H: 2.Há quanto tempo você trabalha nesta área/unidade de trabalho hospitalar?',
#        'SEÇÃO H: 3.Tipicamente, quantas horas por semana você trabalha neste hospital?',
#        '5. Em sua função, você tipicamente tem contato ou interação direta com os pacientes?',
#        '6. Há quanto tempo você trabalha em sua profissão ou especialização atual?',
#        'Regional', 'Estado', 'Acreditação', 'Cargo', 'Acreditação2',
#        'acreditacao', 'SEÇÃO G2: Notificou algum evento nos ultimos 12 meses',
#        'SEÇÃO G: Número de Eventos Notificados  Nos últimos 12 meses, quantas notificações de evento você preencheu e enviou?_0. Nenhuma notificações de eventos',
#        'SEÇÃO G: Número de Eventos Notificados  Nos últimos 12 meses, quantas notificações de evento você preencheu e enviou?_1. 1 a 2 notificações de eventos',
#        'SEÇÃO G: Número de Eventos Notificados  Nos últimos 12 meses, quantas notificações de evento você preencheu e enviou?_2. 3 a 5 notificações de eventos',
#        'SEÇÃO G: Número de Eventos Notificados  Nos últimos 12 meses, quantas notificações de evento você preencheu e enviou?_3. 6 a 10 notificações de eventos',
#        'SEÇÃO G: Número de Eventos Notificados  Nos últimos 12 meses, quantas notificações de evento você preencheu e enviou?_4. 11 a 20 notificações de eventos',
#        'SEÇÃO G: Número de Eventos Notificados  Nos últimos 12 meses, quantas notificações de evento você preencheu e enviou?_5. 21 notificações de eventos ou mais',
#        'SEÇÃO H: 3.2 Trabalha mais que 40horas semanais',
#        'SEÇÃO H: 3.2 Trabalha mais que 60horas semanais',
#        'SEÇÃO H: 3.2 Trabalha mais que 80horas semanais',
#        'SEÇÃO H: Horas trabalhadas semanais',
#        'Por favor, dê uma nota geral para a segurança do paciente em sua área/unidade de trabalho hospitalar._Excelente',
#        'Por favor, dê uma nota geral para a segurança do paciente em sua área/unidade de trabalho hospitalar._Muito boa',
#        'Por favor, dê uma nota geral para a segurança do paciente em sua área/unidade de trabalho hospitalar._Muito ruim',
#        'Por favor, dê uma nota geral para a segurança do paciente em sua área/unidade de trabalho hospitalar._Ruim',
#        'Por favor, dê uma nota geral para a segurança do paciente em sua área/unidade de trabalho hospitalar._Satisfatória',
#        'Nota Geral == Satisfatoria ?', 'Nota Geral == Boa ?', 'Nota Geral',
#        'Setor', 'SEÇÃO H: 1.2 trabalha a mais de 1 ano no hospital?',
#        'SEÇÃO H: 1.3 trabalha a mais de 5 anos no hospital?',
#        'SEÇÃO H: 1. Há quanto tempo você trabalha neste hospital?_0. Menos de 1 ano',
#        'SEÇÃO H: 1. Há quanto tempo você trabalha neste hospital?_1. 1 a 5 anos',
#        'SEÇÃO H: 1. Há quanto tempo você trabalha neste hospital?_2. 6 a 10 anos',
#        'SEÇÃO H: 1. Há quanto tempo você trabalha neste hospital?_3. 11 a 15 anos',
#        'SEÇÃO H: 1. Há quanto tempo você trabalha neste hospital?_4. 16 a 20 anos',
#        'SEÇÃO H: 1. Há quanto tempo você trabalha neste hospital?_5. 21 anos ou mais',
#        '6. Há quanto tempo você trabalha em sua profissão ou especialização atual?_0. Menos de 1 ano',
#        '6. Há quanto tempo você trabalha em sua profissão ou especialização atual?_1. 1 a 5 anos',
#        '6. Há quanto tempo você trabalha em sua profissão ou especialização atual?_2. 6 a 10 anos',
#        '6. Há quanto tempo você trabalha em sua profissão ou especialização atual?_3. 11 a 15 anos',
#        '6. Há quanto tempo você trabalha em sua profissão ou especialização atual?_4. 16 a 20 anos',
#        '6. Há quanto tempo você trabalha em sua profissão ou especialização atual?_5. 21 anos ou mais'],
#       dtype='object')

# %% [raw]
# #df = df[df['Qual é sua principal área ou unidade neste hospital?'] != 'Administrativa'].reset_index(drop=True)
# #df['Qual é sua principal área ou unidade neste hospital?'][df['Setor'] == 'Gestão'].unique()
#
# df_backup = df.copy()
# df = df[df['Setor'] != 'Gestão'].reset_index(drop=True)
# df_bruto = df.copy()
# #df = df_backup.copy()
# #df['Setor'].unique()

# %%
for coluna in df.columns:
    print(coluna, '='*25)
    counts = df[coluna].value_counts()
    percentages = df[coluna].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'

    # Usando o método 'agg' para juntar contagens e porcentagens em uma mesma DataFrame
    res = pd.DataFrame({'counts': counts, 'percentage': percentages})
    print(res)
    print('\n')
# Out:
# Ano =========================
#       counts percentage
# Ano
# 2022   48176      18.6%
# 2021   43317      16.7%
# 2020   36945      14.2%
# 2019   32631      12.6%
# 2018   27828      10.7%
# 2017   26698      10.3%
# 2016   23506       9.1%
# 2015   13318       5.1%
# 2014    6849       2.6%
#
#
# Unidade =========================
#                counts percentage
# Unidade
# Itaim           13456       5.2%
# Copa D'Or       10705       4.1%
# Quinta D'Or     10309       4.0%
# Brasil           9982       3.9%
# Anália Franco    9756       3.8%
# ...               ...        ...
# Yutaka            296       0.1%
# Santa Emília      200       0.1%
# HNSN Epitácio     198       0.1%
# Santa Marina      122       0.0%
# Orthoservice       87       0.0%
#
# [71 rows x 2 columns]
#
#
# Qual é sua principal área ou unidade neste hospital? =========================
#                                                     counts percentage
# Qual é sua principal área ou unidade neste hosp...
# Unidade de terapia intensiva adulto                  34413      15.3%
# Unidade de Internação adulto                         31293      13.9%
# Administrativa                                       26157      11.6%
# Emergência adulto                                    22037       9.8%
# Centro Cirúrgico                                     15104       6.7%
# Farmácia                                             12501       5.6%
# Nutrição                                             11042       4.9%
# Radiologia                                            8225       3.7%
# Laboratório Clínico                                   6756       3.0%
# Emergência pediátrica                                 5855       2.6%
# Unidade de terapia intensiva pediátrica               5422       2.4%
# Central de Material Esterilizado                      5145       2.3%
# Unidade de terapia intensiva neonatal                 4984       2.2%
# Maternidade                                           4916       2.2%
# Suprimentos                                           4404       2.0%
# Anestesiologia                                        3705       1.6%
# Pediatria                                             3433       1.5%
# Unidade de Internação pediátrica                      3295       1.5%
# Reabilitação                                          2318       1.0%
# Cardiologia Intervencionistas                         2225       1.0%
# Unidade de Internação neonatal/ berçário              2097       0.9%
# Centro Obstétrico                                     1973       0.9%
# Ressonância Magnética                                 1551       0.7%
# Endoscopia                                            1269       0.6%
# Ultrassonografia                                      1216       0.5%
# Emergência ginecologia                                1102       0.5%
# Gerência                                              1101       0.5%
# Diretoria                                             1070       0.5%
# Psiquiatria/Saúde mental                               282       0.1%
#
#
# 1. As pessoas se apoiam umas às outras nesta unidade =========================
#                                                     counts percentage
# 1. As pessoas se apoiam umas às outras nesta un...
# 1.0                                                 177728      69.2%
# 0.0                                                  79062      30.8%
#
#
# 2. Temos pessoas suficientes para lidar com o volume de trabalho =========================
#                                                     counts percentage
# 2. Temos pessoas suficientes para lidar com o v...
# 0.0                                                 152818      59.5%
# 1.0                                                 104178      40.5%
#
#
# 3. Quando há muito trabalho a ser feito e rapidamente, trabalhamos juntos em equipe para realizar a tarefa =========================
#                                                     counts percentage
# 3. Quando há muito trabalho a ser feito e rapid...
# 1.0                                                 204797      79.6%
# 0.0                                                  52382      20.4%
#
#
# 4. Nesta unidade, as pessoas se tratam com respeito =========================
#                                                     counts percentage
# 4. Nesta unidade, as pessoas se tratam com resp...
# 1.0                                                 211661      82.4%
# 0.0                                                  45324      17.6%
#
#
# 5. Os funcionários desta unidade trabalham mais horas do que o recomendado no atendimento a pacientes =========================
#                                                     counts percentage
# 5. Os funcionários desta unidade trabalham mais...
# 1.0                                                 140471      54.8%
# 0.0                                                 115977      45.2%
#
#
# 6. Estamos ativamente buscando melhorias para a segurança do paciente =========================
#                                                     counts percentage
# 6. Estamos ativamente buscando melhorias para a...
# 1.0                                                 231369      90.2%
# 0.0                                                  25253       9.8%
#
#
# 7. Utilizamos mais funcionários temporários do que o recomendado no atendimento a paciente =========================
#                                                     counts percentage
# 7. Utilizamos mais funcionários temporários do ...
# 1.0                                                 166721      65.2%
# 0.0                                                  89058      34.8%
#
#
# 8. Os funcionários sentem que seus erros são usados contra eles =========================
#                                                     counts percentage
# 8. Os funcionários sentem que seus erros são us...
# 1.0                                                 134249      52.5%
# 0.0                                                 121615      47.5%
#
#
# 9. Erros que ocorreram levaram a mudanças positivas nesta unidade =========================
#                                                     counts percentage
# 9. Erros que ocorreram levaram a mudanças posit...
# 1.0                                                 188989      73.9%
# 0.0                                                  66795      26.1%
#
#
# 10. É apenas por acaso que erros mais sérios não acontecem por aqui =========================
#                                                     counts percentage
# 10. É apenas por acaso que erros mais sérios nã...
# 1.0                                                 154884      60.8%
# 0.0                                                  99757      39.2%
#
#
# 11. Quando uma área nesta unidade fica muito movimentada, as demais ajudam =========================
#                                                     counts percentage
# 11. Quando uma área nesta unidade fica muito mo...
# 1.0                                                 137216      53.6%
# 0.0                                                 118789      46.4%
#
#
# 12. Quando um evento é notificado, sentimos que o foco se concentra no indivíduo, e não no problema =========================
#                                                     counts percentage
# 12. Quando um evento é notificado, sentimos que...
# 1.0                                                 129162      50.4%
# 0.0                                                 127099      49.6%
#
#
# 13. Quando fazemos mudanças para melhorar a segurança do paciente, nós avaliamos sua efetividade =========================
#                                                     counts percentage
# 13. Quando fazemos mudanças para melhorar a seg...
# 1.0                                                 196688      76.8%
# 0.0                                                  59537      23.2%
#
#
# 14. Trabalhamos “em modo de crise”, tentando fazer coisas demais, rápido demais =========================
#                                                     counts percentage
# 14. Trabalhamos “em modo de crise”, tentando fa...
# 0.0                                                 134953      52.7%
# 1.0                                                 121097      47.3%
#
#
# 15. A segurança do paciente nunca é sacrificada em prol de se trabalhar mais =========================
#                                                     counts percentage
# 15. A segurança do paciente nunca é sacrificada...
# 1.0                                                 132462      52.0%
# 0.0                                                 122452      48.0%
#
#
# 16. Os funcionários se preocupam que seus erros sejam registrados em seu arquivo funcional =========================
#                                                     counts percentage
# 16. Os funcionários se preocupam que seus erros...
# 0.0                                                 200670      78.6%
# 1.0                                                  54797      21.4%
#
#
# 17. Temos problemas com a segurança do paciente nesta unidade =========================
#                                                     counts percentage
# 17. Temos problemas com a segurança do paciente...
# 1.0                                                 175155      68.5%
# 0.0                                                  80617      31.5%
#
#
# 18. Nossos procedimentos e sistemas são bons para impedir que os erros aconteçam =========================
#                                                     counts percentage
# 18. Nossos procedimentos e sistemas são bons pa...
# 1.0                                                 181431      70.8%
# 0.0                                                  74721      29.2%
#
#
# 19. Meu supervisor/gerente elogia quando vê um trabalho feito de acordo com os procedimentos estabelecidos para a segurança do paciente. =========================
#                                                     counts percentage
# 19. Meu supervisor/gerente elogia quando vê um ...
# 1.0                                                 180990      70.4%
# 0.0                                                  76125      29.6%
#
#
# 20. Meu supervisor/gerente considera seriamente as sugestões dos funcionários para melhorar a segurança do paciente =========================
#                                                     counts percentage
# 20. Meu supervisor/gerente considera seriamente...
# 1.0                                                 182125      71.0%
# 0.0                                                  74538      29.0%
#
#
# 21. Sempre que a pressão aumenta, meu supervisor/gerente quer que trabalhemos mais rápido, mesmo que isto signifique tomar atalhos =========================
#                                                     counts percentage
# 21. Sempre que a pressão aumenta, meu superviso...
# 1.0                                                 158703      61.9%
# 0.0                                                  97530      38.1%
#
#
# 22. Meu supervisor/gerente ignora problemas recorrentes na segurança do paciente =========================
#                                                     counts percentage
# 22. Meu supervisor/gerente ignora problemas rec...
# 1.0                                                 220087      85.9%
# 0.0                                                  36124      14.1%
#
#
# 23. Recebemos feedback das mudanças implementadas com base nos eventos notificados =========================
#                                                     counts percentage
# 23. Recebemos feedback das mudanças implementad...
# 1.0                                                 136307      53.1%
# 0.0                                                 120306      46.9%
#
#
# 24. Os funcionários falam voluntariamente se vêem algo que possa afetar negativamente o atendimento aos pacientes =========================
#                                                     counts percentage
# 24. Os funcionários falam voluntariamente se vê...
# 1.0                                                 148472      57.9%
# 0.0                                                 107895      42.1%
#
#
# 25. Somos informados sobre os erros que acontecem nesta unidade =========================
#                                                     counts percentage
# 25. Somos informados sobre os erros que acontec...
# 1.0                                                 153400      59.9%
# 0.0                                                 102789      40.1%
#
#
# 26. Os funcionários sentem-se à vontade para questionar decisões ou ações dos que têm mais autoridade =========================
#                                                     counts percentage
# 26. Os funcionários sentem-se à vontade para qu...
# 0.0                                                 170512      66.6%
# 1.0                                                  85343      33.4%
#
#
# 27. Nesta unidade, discutimos maneiras de impedir que os erros tornem a acontecer =========================
#                                                     counts percentage
# 27. Nesta unidade, discutimos maneiras de imped...
# 1.0                                                 177395      69.3%
# 0.0                                                  78605      30.7%
#
#
# 28. Os funcionários têm receio de perguntar quando algo não parece certo =========================
#                                                     counts percentage
# 28. Os funcionários têm receio de perguntar qua...
# 1.0                                                 128364      50.1%
# 0.0                                                 127636      49.9%
#
#
# 29. Quando acontece um erro, mas ele é identificado e corrigido antes de afetar o paciente, com que frequência é notificado? =========================
#                                                     counts percentage
# 29. Quando acontece um erro, mas ele é identifi...
# 1.0                                                 157588      61.5%
# 0.0                                                  98691      38.5%
#
#
# 30. Quando acontece um erro, mas que não tem potencial de dano ao paciente, com que frequência é notificado? =========================
#                                                     counts percentage
# 30. Quando acontece um erro, mas que não tem po...
# 1.0                                                 150282      58.8%
# 0.0                                                 105264      41.2%
#
#
# 31. Quando acontece um erro que poderia prejudicar o paciente, mas isto não ocorreu, com que frequência é notificado? =========================
#                                                     counts percentage
# 31. Quando acontece um erro que poderia prejudi...
# 1.0                                                 163225      63.9%
# 0.0                                                  92236      36.1%
#
#
# Por favor, dê uma nota geral para a segurança do paciente em sua área/unidade de trabalho hospitalar. =========================
#                                                     counts percentage
# Por favor, dê uma nota geral para a segurança d...
# 4. Muito boa                                         93209      36.4%
# 3. Excelente                                         76745      30.0%
# 2. Satisfatória                                      75626      29.6%
# 1. Ruim                                               7805       3.1%
# 0. Muito ruim                                         2515       1.0%
#
#
# 32. A administração do hospital cria um ambiente de trabalho que promove a segurança do paciente =========================
#                                                     counts percentage
# 32. A administração do hospital cria um ambient...
# 1.0                                                 212043      82.5%
# 0.0                                                  45117      17.5%
#
#
# 33. As unidades hospitalares não se coordenam bem entre si. =========================
#                                                     counts percentage
# 33. As unidades hospitalares não se coordenam b...
# 1.0                                                 143241      55.9%
# 0.0                                                 113047      44.1%
#
#
# 34. Coisas "escapam por entre os dedos” quando os pacientes são transferidos de uma unidade para outra =========================
#                                                     counts percentage
# 34. Coisas "escapam por entre os dedos” quando ...
# 1.0                                                 136450      53.4%
# 0.0                                                 119197      46.6%
#
#
# 35. Existe uma boa cooperação entre as unidades hospitalares que precisam trabalhar juntas =========================
#                                                     counts percentage
# 35. Existe uma boa cooperação entre as unidades...
# 1.0                                                 158040      61.7%
# 0.0                                                  98110      38.3%
#
#
# 36. Importantes informações sobre a assistência se perdem durante as mudanças de turno =========================
#                                                     counts percentage
# 36. Importantes informações sobre a assistência...
# 1.0                                                 130810      51.2%
# 0.0                                                 124896      48.8%
#
#
# 37. Muitas vezes é desagradável trabalhar unidades com funcionários de outras unidades do hospital =========================
#                                                     counts percentage
# 37. Muitas vezes é desagradável trabalhar unida...
# 1.0                                                 144136      56.3%
# 0.0                                                 111781      43.7%
#
#
# 38. Os problemas com frequência ocorrem na troca de informações entre as unidades do hospital =========================
#                                                     counts percentage
# 38. Os problemas com frequência ocorrem na troc...
# 0.0                                                 133429      52.2%
# 1.0                                                 121999      47.8%
#
#
# 39. As ações da administração do hospital mostram que a segurança do paciente é uma prioridade máxima =========================
#                                                     counts percentage
# 39. As ações da administração do hospital mostr...
# 1.0                                                 206676      80.8%
# 0.0                                                  49027      19.2%
#
#
# 40. A administração do hospital parece se interessar pela segurança do paciente apenas quando acontece um evento adverso =========================
#                                                     counts percentage
# 40. A administração do hospital parece se inter...
# 1.0                                                 169021      66.1%
# 0.0                                                  86845      33.9%
#
#
# 41. As unidades do hospital trabalham bem juntas para prestar o melhor atendimento aos pacientes =========================
#                                                     counts percentage
# 41. As unidades do hospital trabalham bem junta...
# 1.0                                                 187563      73.4%
# 0.0                                                  67977      26.6%
#
#
# 42. As mudanças de turno são problemáticas para os pacientes deste Hospital =========================
#                                                     counts percentage
# 42. As mudanças de turno são problemáticas para...
# 1.0                                                 158061      61.9%
# 0.0                                                  97153      38.1%
#
#
# SEÇÃO G: Número de Eventos Notificados  Nos últimos 12 meses, quantas notificações de evento você preencheu e enviou? =========================
#                                                     counts percentage
# SEÇÃO G: Número de Eventos Notificados  Nos últ...
# 0. Nenhuma notificações de eventos                  120207      46.9%
# 1. 1 a 2 notificações de eventos                     55183      21.5%
# 2. 3 a 5 notificações de eventos                     36186      14.1%
# 3. 6 a 10 notificações de eventos                    22258       8.7%
# 4. 11 a 20 notificações de eventos                   11726       4.6%
# 5. 21 notificações de eventos ou mais                10597       4.1%
#
#
# SEÇÃO H: 1. Há quanto tempo você trabalha neste hospital? =========================
#                                                     counts percentage
# SEÇÃO H: 1. Há quanto tempo você trabalha neste...
# 1. 1 a 5 anos                                       121452      47.3%
# 0. Menos de 1 ano                                    54735      21.3%
# 2. 6 a 10 anos                                       49508      19.3%
# 3. 11 a 15 anos                                      16889       6.6%
# 4. 16 a 20 anos                                       8246       3.2%
# 5. 21 anos ou mais                                    6200       2.4%
#
#
# SEÇÃO H: 2.Há quanto tempo você trabalha nesta área/unidade de trabalho hospitalar? =========================
#                                                     counts percentage
# SEÇÃO H: 2.Há quanto tempo você trabalha nesta ...
# 1. 1 a 5 anos                                       121377      47.2%
# 0. Menos de 1 ano                                    53896      21.0%
# 2. 6 a 10 anos                                       48277      18.8%
# 3. 11 a 15 anos                                      17711       6.9%
# 4. 16 a 20 anos                                       8972       3.5%
# 5. 21 anos ou mais                                    6671       2.6%
#
#
# SEÇÃO H: 3.Tipicamente, quantas horas por semana você trabalha neste hospital? =========================
#                                                     counts percentage
# SEÇÃO H: 3.Tipicamente, quantas horas por seman...
# 3. 40 a 59 horas por semana                         135076      52.7%
# 2. 20 a 39 horas por semana                          91281      35.6%
# 1. Menos de 20 horas por semana                      18421       7.2%
# 4. 60 a 79 horas por semana                           8078       3.2%
# 5. 80 a 99 horas por semana                           1833       0.7%
# 6. 100 horas por semana ou mais                       1641       0.6%
#
#
# 5. Em sua função, você tipicamente tem contato ou interação direta com os pacientes? =========================
#                                                     counts percentage
# 5. Em sua função, você tipicamente tem contato ...
# a. SIM, tipicamente tenho contato ou interação ...  199671      77.0%
# b. NÃO, tipicamente não tenho contato ou intera...   59597      23.0%
#
#
# 6. Há quanto tempo você trabalha em sua profissão ou especialização atual? =========================
#                                                     counts percentage
# 6. Há quanto tempo você trabalha em sua profiss...
# 1. 1 a 5 anos                                        88963      34.6%
# 2. 6 a 10 anos                                       66117      25.7%
# 3. 11 a 15 anos                                      38371      14.9%
# 0. Menos de 1 ano                                    22232       8.6%
# 4. 16 a 20 anos                                      21939       8.5%
# 5. 21 anos ou mais                                   19523       7.6%
#
#
# Regional =========================
#           counts percentage
# Regional
# SE        183510      70.8%
# NE         51214      19.8%
# CO         21969       8.5%
# SUL         1968       0.8%
# N            607       0.2%
#
#
# Estado =========================
#         counts percentage
# Estado
# SP       95363      36.8%
# RJ       88147      34.0%
# PE       26899      10.4%
# DF       21401       8.3%
# BA       11052       4.3%
# MA        5513       2.1%
# SE        4397       1.7%
# PR        1968       0.8%
# CE        1590       0.6%
# PB         955       0.4%
# AL         808       0.3%
# PA         607       0.2%
# MS         568       0.2%
#
#
# Acreditação =========================
#              counts percentage
# Acreditação
# ONA          109283      42.2%
# Qmentum       67447      26.0%
# JCI           52947      20.4%
# 0             29591      11.4%
#
#
# Cargo =========================
#                        counts percentage
# Cargo
# Tecnico de Enfermeiro   80732      41.1%
# Outros                  50755      25.8%
# Enfermeiro              32685      16.6%
# Médico                  26925      13.7%
# Tecnico Enfermeiro       5425       2.8%
#
#
# Acreditação2 =========================
#               counts percentage
# Acreditação2
# ONA 3          75091      29.0%
# Qmentum        67447      26.0%
# JCI            52947      20.4%
# 0              29591      11.4%
# ONA 2          25382       9.8%
# ONA 1           8810       3.4%
#
#
# acreditacao =========================
#              counts percentage
# acreditacao
# 1            229677      88.6%
# 0             29591      11.4%
#
#
# SEÇÃO G2: Notificou algum evento nos ultimos 12 meses =========================
#                                                     counts percentage
# SEÇÃO G2: Notificou algum evento nos ultimos 12...
# 1.0                                                 135950      53.1%
# 0.0                                                 120207      46.9%
#
#
# SEÇÃO G: Número de Eventos Notificados  Nos últimos 12 meses, quantas notificações de evento você preencheu e enviou?_0. Nenhuma notificações de eventos =========================
#                                                     counts percentage
# SEÇÃO G: Número de Eventos Notificados  Nos últ...
# 0                                                   139061      53.6%
# 1                                                   120207      46.4%
#
#
# SEÇÃO G: Número de Eventos Notificados  Nos últimos 12 meses, quantas notificações de evento você preencheu e enviou?_1. 1 a 2 notificações de eventos =========================
#                                                     counts percentage
# SEÇÃO G: Número de Eventos Notificados  Nos últ...
# 0                                                   204085      78.7%
# 1                                                    55183      21.3%
#
#
# SEÇÃO G: Número de Eventos Notificados  Nos últimos 12 meses, quantas notificações de evento você preencheu e enviou?_2. 3 a 5 notificações de eventos =========================
#                                                     counts percentage
# SEÇÃO G: Número de Eventos Notificados  Nos últ...
# 0                                                   223082      86.0%
# 1                                                    36186      14.0%
#
#
# SEÇÃO G: Número de Eventos Notificados  Nos últimos 12 meses, quantas notificações de evento você preencheu e enviou?_3. 6 a 10 notificações de eventos =========================
#                                                     counts percentage
# SEÇÃO G: Número de Eventos Notificados  Nos últ...
# 0                                                   237010      91.4%
# 1                                                    22258       8.6%
#
#
# SEÇÃO G: Número de Eventos Notificados  Nos últimos 12 meses, quantas notificações de evento você preencheu e enviou?_4. 11 a 20 notificações de eventos =========================
#                                                     counts percentage
# SEÇÃO G: Número de Eventos Notificados  Nos últ...
# 0                                                   247542      95.5%
# 1                                                    11726       4.5%
#
#
# SEÇÃO G: Número de Eventos Notificados  Nos últimos 12 meses, quantas notificações de evento você preencheu e enviou?_5. 21 notificações de eventos ou mais =========================
#                                                     counts percentage
# SEÇÃO G: Número de Eventos Notificados  Nos últ...
# 0                                                   248671      95.9%
# 1                                                    10597       4.1%
#
#
# SEÇÃO H: 3.2 Trabalha mais que 40horas semanais =========================
#                                                  counts percentage
# SEÇÃO H: 3.2 Trabalha mais que 40horas semanais
# 1.0                                              146628      57.2%
# 0.0                                              109702      42.8%
#
#
# SEÇÃO H: 3.2 Trabalha mais que 60horas semanais =========================
#                                                  counts percentage
# SEÇÃO H: 3.2 Trabalha mais que 60horas semanais
# 0.0                                              244778      95.5%
# 1.0                                               11552       4.5%
#
#
# SEÇÃO H: 3.2 Trabalha mais que 80horas semanais =========================
#                                                  counts percentage
# SEÇÃO H: 3.2 Trabalha mais que 80horas semanais
# 0.0                                              252856      98.6%
# 1.0                                                3474       1.4%
#
#
# SEÇÃO H: Horas trabalhadas semanais =========================
#                                      counts percentage
# SEÇÃO H: Horas trabalhadas semanais
# 1. 40 a - 79                         143154      55.8%
# 0. 20 a 39                           109702      42.8%
# 2. > 80                                3474       1.4%
#
#
# Por favor, dê uma nota geral para a segurança do paciente em sua área/unidade de trabalho hospitalar._Excelente =========================
#                                                     counts percentage
# Por favor, dê uma nota geral para a segurança d...
# 0                                                   182523      70.4%
# 1                                                    76745      29.6%
#
#
# Por favor, dê uma nota geral para a segurança do paciente em sua área/unidade de trabalho hospitalar._Muito boa =========================
#                                                     counts percentage
# Por favor, dê uma nota geral para a segurança d...
# 0                                                   166059      64.0%
# 1                                                    93209      36.0%
#
#
# Por favor, dê uma nota geral para a segurança do paciente em sua área/unidade de trabalho hospitalar._Muito ruim =========================
#                                                     counts percentage
# Por favor, dê uma nota geral para a segurança d...
# 0                                                   256753      99.0%
# 1                                                     2515       1.0%
#
#
# Por favor, dê uma nota geral para a segurança do paciente em sua área/unidade de trabalho hospitalar._Ruim =========================
#                                                     counts percentage
# Por favor, dê uma nota geral para a segurança d...
# 0                                                   251463      97.0%
# 1                                                     7805       3.0%
#
#
# Por favor, dê uma nota geral para a segurança do paciente em sua área/unidade de trabalho hospitalar._Satisfatória =========================
#                                                     counts percentage
# Por favor, dê uma nota geral para a segurança d...
# 0                                                   183642      70.8%
# 1                                                    75626      29.2%
#
#
# Nota Geral == Satisfatoria ? =========================
#                               counts percentage
# Nota Geral == Satisfatoria ?
# 1.0                           245580      96.0%
# 0.0                            10320       4.0%
#
#
# Nota Geral == Boa ? =========================
#                      counts percentage
# Nota Geral == Boa ?
# 1.0                  169954      66.4%
# 0.0                   85946      33.6%
#
#
# Nota Geral =========================
#             counts percentage
# Nota Geral
# 2.0         169954      66.4%
# 1.0          75626      29.6%
# 0.0          10320       4.0%
#
#
# Setor =========================
#                                   counts percentage
# Setor
# UTI                                44819      19.9%
# UI                                 40400      18.0%
# Área de Apoio                      37727      16.8%
# Processo Cirurgico ou Obstétrico   29192      13.0%
# Emergência                         28994      12.9%
# Gestão                             27227      12.1%
# Serviço Diagnóstico                16532       7.4%
#
#
# SEÇÃO H: 1.2 trabalha a mais de 1 ano no hospital? =========================
#                                                     counts percentage
# SEÇÃO H: 1.2 trabalha a mais de 1 ano no hospital?
# 1.0                                                 202295      78.7%
# 0.0                                                  54735      21.3%
#
#
# SEÇÃO H: 1.3 trabalha a mais de 5 anos no hospital? =========================
#                                                     counts percentage
# SEÇÃO H: 1.3 trabalha a mais de 5 anos no hospi...
# 0.0                                                 176187      68.5%
# 1.0                                                  80843      31.5%
#
#
# SEÇÃO H: 1. Há quanto tempo você trabalha neste hospital?_0. Menos de 1 ano =========================
#                                                     counts percentage
# SEÇÃO H: 1. Há quanto tempo você trabalha neste...
# 0                                                   204533      78.9%
# 1                                                    54735      21.1%
#
#
# SEÇÃO H: 1. Há quanto tempo você trabalha neste hospital?_1. 1 a 5 anos =========================
#                                                     counts percentage
# SEÇÃO H: 1. Há quanto tempo você trabalha neste...
# 0                                                   137816      53.2%
# 1                                                   121452      46.8%
#
#
# SEÇÃO H: 1. Há quanto tempo você trabalha neste hospital?_2. 6 a 10 anos =========================
#                                                     counts percentage
# SEÇÃO H: 1. Há quanto tempo você trabalha neste...
# 0                                                   209760      80.9%
# 1                                                    49508      19.1%
#
#
# SEÇÃO H: 1. Há quanto tempo você trabalha neste hospital?_3. 11 a 15 anos =========================
#                                                     counts percentage
# SEÇÃO H: 1. Há quanto tempo você trabalha neste...
# 0                                                   242379      93.5%
# 1                                                    16889       6.5%
#
#
# SEÇÃO H: 1. Há quanto tempo você trabalha neste hospital?_4. 16 a 20 anos =========================
#                                                     counts percentage
# SEÇÃO H: 1. Há quanto tempo você trabalha neste...
# 0                                                   251022      96.8%
# 1                                                     8246       3.2%
#
#
# SEÇÃO H: 1. Há quanto tempo você trabalha neste hospital?_5. 21 anos ou mais =========================
#                                                     counts percentage
# SEÇÃO H: 1. Há quanto tempo você trabalha neste...
# 0                                                   253068      97.6%
# 1                                                     6200       2.4%
#
#
# 6. Há quanto tempo você trabalha em sua profissão ou especialização atual?_0. Menos de 1 ano =========================
#                                                     counts percentage
# 6. Há quanto tempo você trabalha em sua profiss...
# 0                                                   237036      91.4%
# 1                                                    22232       8.6%
#
#
# 6. Há quanto tempo você trabalha em sua profissão ou especialização atual?_1. 1 a 5 anos =========================
#                                                     counts percentage
# 6. Há quanto tempo você trabalha em sua profiss...
# 0                                                   170305      65.7%
# 1                                                    88963      34.3%
#
#
# 6. Há quanto tempo você trabalha em sua profissão ou especialização atual?_2. 6 a 10 anos =========================
#                                                     counts percentage
# 6. Há quanto tempo você trabalha em sua profiss...
# 0                                                   193151      74.5%
# 1                                                    66117      25.5%
#
#
# 6. Há quanto tempo você trabalha em sua profissão ou especialização atual?_3. 11 a 15 anos =========================
#                                                     counts percentage
# 6. Há quanto tempo você trabalha em sua profiss...
# 0                                                   220897      85.2%
# 1                                                    38371      14.8%
#
#
# 6. Há quanto tempo você trabalha em sua profissão ou especialização atual?_4. 16 a 20 anos =========================
#                                                     counts percentage
# 6. Há quanto tempo você trabalha em sua profiss...
# 0                                                   237329      91.5%
# 1                                                    21939       8.5%
#
#
# 6. Há quanto tempo você trabalha em sua profissão ou especialização atual?_5. 21 anos ou mais =========================
#                                                     counts percentage
# 6. Há quanto tempo você trabalha em sua profiss...
# 0                                                   239745      92.5%
# 1                                                    19523       7.5%

# %% [markdown]
# # Contagens Simples

# %% [raw]
# inicio = time.time() #iniciando o cronometro
#
# table = TableOne(df)
# display(table)
# table.to_excel('1 - Tabela_Contagens.xlsx')
#
# fim = time.time() #encerrando cronometro
# print('Tempo para rodar a simulação:', round(fim - inicio, 3))

# %% [markdown]
# # Contagens por grupo (Acreditação)

# %% [raw]
# inicio = time.time() #iniciando o cronometro
#
# table = TableOne(df, columns=list(df.columns), groupby=['Acreditação'], pval=True)
# display(table)
# table.to_excel('2 - Tabela_Associacao_Acreditacao.xlsx')
#
# fim = time.time() #encerrando cronometro
# print('Tempo para rodar a simulação:', round(fim - inicio, 3))

# %% [raw]
# inicio = time.time() #iniciando o cronometro
#
# table = TableOne(df, columns=list(df.columns), groupby=['SEÇÃO G2: Notificou algum evento nos ultimos 12 meses'], pval=True)
# display(table)
# table.to_excel('2 - Tabela_Associacao_Acreditacao.xlsx')
#
# fim = time.time() #encerrando cronometro
# print('Tempo para rodar a simulação:', round(fim - inicio, 3))

# %% [raw]
# inicio = time.time() #iniciando o cronometro
# table = TableOne(df, columns=list(df.columns), groupby=['acreditacao'], pval=True)
# display(table)
# table.to_excel('2 - Tabela_Associacao_Acreditacao.xlsx')
# fim = time.time() #encerrando cronometro
# print('Tempo para rodar a simulação:', round(fim - inicio, 3))
#
# ######################################################################################
#
# inicio = time.time() #iniciando o cronometro
# table = TableOne(df, columns=list(df.columns), groupby=['Acreditação'], pval=True)
# display(table)
# table.to_excel('2 - Tabela_Associacao_Acreditacao1.xlsx')
# fim = time.time() #encerrando cronometro
# print('Tempo para rodar a simulação:', round(fim - inicio, 3))
#
# ######################################################################################
#
# inicio = time.time() #iniciando o cronometro
# table = TableOne(df, columns=list(df.columns), groupby=['Acreditação2'], pval=True)
# display(table)
# table.to_excel('2 - Tabela_Associacao_Acreditacao2.xlsx')
# fim = time.time() #encerrando cronometro
# print('Tempo para rodar a simulação:', round(fim - inicio, 3))

# %%
lista_scores = ['1. As pessoas se apoiam umas às outras nesta unidade',
                '2. Temos pessoas suficientes para lidar com o volume de trabalho',
                '3. Quando há muito trabalho a ser feito e rapidamente, trabalhamos juntos em equipe para realizar a tarefa',
                '4. Nesta unidade, as pessoas se tratam com respeito',
                '5. Os funcionários desta unidade trabalham mais horas do que o recomendado no atendimento a pacientes',
                '6. Estamos ativamente buscando melhorias para a segurança do paciente',
                '7. Utilizamos mais funcionários temporários do que o recomendado no atendimento a paciente',
                '8. Os funcionários sentem que seus erros são usados contra eles',
                '9. Erros que ocorreram levaram a mudanças positivas nesta unidade',
                '10. É apenas por acaso que erros mais sérios não acontecem por aqui',
                '11. Quando uma área nesta unidade fica muito movimentada, as demais ajudam',
                '12. Quando um evento é notificado, sentimos que o foco se concentra no indivíduo, e não no problema',
                '13. Quando fazemos mudanças para melhorar a segurança do paciente, nós avaliamos sua efetividade',
                '14. Trabalhamos “em modo de crise”, tentando fazer coisas demais, rápido demais',
                '15. A segurança do paciente nunca é sacrificada em prol de se trabalhar mais',
                '16. Os funcionários se preocupam que seus erros sejam registrados em seu arquivo funcional',
                '17. Temos problemas com a segurança do paciente nesta unidade',
                '18. Nossos procedimentos e sistemas são bons para impedir que os erros aconteçam',
                '19. Meu supervisor/gerente elogia quando vê um trabalho feito de acordo com os procedimentos estabelecidos para a segurança do paciente.',
                '20. Meu supervisor/gerente considera seriamente as sugestões dos funcionários para melhorar a segurança do paciente',
                '21. Sempre que a pressão aumenta, meu supervisor/gerente quer que trabalhemos mais rápido, mesmo que isto signifique tomar atalhos',
                '22. Meu supervisor/gerente ignora problemas recorrentes na segurança do paciente',
                '23. Recebemos feedback das mudanças implementadas com base nos eventos notificados',
                '24. Os funcionários falam voluntariamente se vêem algo que possa afetar negativamente o atendimento aos pacientes',
                '25. Somos informados sobre os erros que acontecem nesta unidade',
                '26. Os funcionários sentem-se à vontade para questionar decisões ou ações dos que têm mais autoridade',
                '27. Nesta unidade, discutimos maneiras de impedir que os erros tornem a acontecer',
                '28. Os funcionários têm receio de perguntar quando algo não parece certo',
                '29. Quando acontece um erro, mas ele é identificado e corrigido antes de afetar o paciente, com que frequência é notificado?',
                '30. Quando acontece um erro, mas que não tem potencial de dano ao paciente, com que frequência é notificado?',
                '31. Quando acontece um erro que poderia prejudicar o paciente, mas isto não ocorreu, com que frequência é notificado?',
                '32. A administração do hospital cria um ambiente de trabalho que promove a segurança do paciente',
                '33. As unidades hospitalares não se coordenam bem entre si.',
                '34. Coisas "escapam por entre os dedos” quando os pacientes são transferidos de uma unidade para outra',
                '35. Existe uma boa cooperação entre as unidades hospitalares que precisam trabalhar juntas',
                '36. Importantes informações sobre a assistência se perdem durante as mudanças de turno',
                '37. Muitas vezes é desagradável trabalhar unidades com funcionários de outras unidades do hospital',
                '38. Os problemas com frequência ocorrem na troca de informações entre as unidades do hospital',
                '39. As ações da administração do hospital mostram que a segurança do paciente é uma prioridade máxima',
                '40. A administração do hospital parece se interessar pela segurança do paciente apenas quando acontece um evento adverso',
                '41. As unidades do hospital trabalham bem juntas para prestar o melhor atendimento aos pacientes',
                '42. As mudanças de turno são problemáticas para os pacientes deste Hospital']

# %%
colunas_adicionais = ['SEÇÃO G2: Notificou algum evento nos ultimos 12 meses',
                    'SEÇÃO G: Número de Eventos Notificados  Nos últimos 12 meses, quantas notificações de evento você preencheu e enviou?_0. Nenhuma notificações de eventos',
                    'SEÇÃO G: Número de Eventos Notificados  Nos últimos 12 meses, quantas notificações de evento você preencheu e enviou?_1. 1 a 2 notificações de eventos',
                    'SEÇÃO G: Número de Eventos Notificados  Nos últimos 12 meses, quantas notificações de evento você preencheu e enviou?_2. 3 a 5 notificações de eventos',
                    'SEÇÃO G: Número de Eventos Notificados  Nos últimos 12 meses, quantas notificações de evento você preencheu e enviou?_3. 6 a 10 notificações de eventos',
                    'SEÇÃO G: Número de Eventos Notificados  Nos últimos 12 meses, quantas notificações de evento você preencheu e enviou?_4. 11 a 20 notificações de eventos',
                    'SEÇÃO G: Número de Eventos Notificados  Nos últimos 12 meses, quantas notificações de evento você preencheu e enviou?_5. 21 notificações de eventos ou mais',
                    'SEÇÃO H: 3.2 Trabalha mais que 40horas semanais',
                    'SEÇÃO H: 3.2 Trabalha mais que 60horas semanais',
                    'SEÇÃO H: 3.2 Trabalha mais que 80horas semanais',
                    'Por favor, dê uma nota geral para a segurança do paciente em sua área/unidade de trabalho hospitalar._Excelente',
                    'Por favor, dê uma nota geral para a segurança do paciente em sua área/unidade de trabalho hospitalar._Muito boa',
                    'Por favor, dê uma nota geral para a segurança do paciente em sua área/unidade de trabalho hospitalar._Muito ruim',
                    'Por favor, dê uma nota geral para a segurança do paciente em sua área/unidade de trabalho hospitalar._Ruim',
                    'Por favor, dê uma nota geral para a segurança do paciente em sua área/unidade de trabalho hospitalar._Satisfatória',
                    'Nota Geral == Satisfatoria ?', 'Nota Geral == Boa ?',
                    'SEÇÃO H: 1.2 trabalha a mais de 1 ano no hospital?',
                    'SEÇÃO H: 1.3 trabalha a mais de 5 anos no hospital?',
                    'SEÇÃO H: 1. Há quanto tempo você trabalha neste hospital?_0. Menos de 1 ano',
                    'SEÇÃO H: 1. Há quanto tempo você trabalha neste hospital?_1. 1 a 5 anos',
                    'SEÇÃO H: 1. Há quanto tempo você trabalha neste hospital?_2. 6 a 10 anos',
                    'SEÇÃO H: 1. Há quanto tempo você trabalha neste hospital?_3. 11 a 15 anos',
                    'SEÇÃO H: 1. Há quanto tempo você trabalha neste hospital?_4. 16 a 20 anos',
                    'SEÇÃO H: 1. Há quanto tempo você trabalha neste hospital?_5. 21 anos ou mais',
                    '6. Há quanto tempo você trabalha em sua profissão ou especialização atual?_0. Menos de 1 ano',
                    '6. Há quanto tempo você trabalha em sua profissão ou especialização atual?_1. 1 a 5 anos',
                    '6. Há quanto tempo você trabalha em sua profissão ou especialização atual?_2. 6 a 10 anos',
                    '6. Há quanto tempo você trabalha em sua profissão ou especialização atual?_3. 11 a 15 anos',
                    '6. Há quanto tempo você trabalha em sua profissão ou especialização atual?_4. 16 a 20 anos',
                    '6. Há quanto tempo você trabalha em sua profissão ou especialização atual?_5. 21 anos ou mais']
lista_scores.extend(colunas_adicionais)
print(lista_scores)
# Out:
# ['1. As pessoas se apoiam umas às outras nesta unidade', '2. Temos pessoas suficientes para lidar com o volume de trabalho', '3. Quando há muito trabalho a ser feito e rapidamente, trabalhamos juntos em equipe para realizar a tarefa', '4. Nesta unidade, as pessoas se tratam com respeito', '5. Os funcionários desta unidade trabalham mais horas do que o recomendado no atendimento a pacientes', '6. Estamos ativamente buscando melhorias para a segurança do paciente', '7. Utilizamos mais funcionários temporários do que o recomendado no atendimento a paciente', '8. Os funcionários sentem que seus erros são usados contra eles', '9. Erros que ocorreram levaram a mudanças positivas nesta unidade', '10. É apenas por acaso que erros mais sérios não acontecem por aqui', '11. Quando uma área nesta unidade fica muito movimentada, as demais ajudam', '12. Quando um evento é notificado, sentimos que o foco se concentra no indivíduo, e não no problema', '13. Quando fazemos mudanças para melhorar a segurança do paciente, nós avaliamos sua efetividade', '14. Trabalhamos “em modo de crise”, tentando fazer coisas demais, rápido demais', '15. A segurança do paciente nunca é sacrificada em prol de se trabalhar mais', '16. Os funcionários se preocupam que seus erros sejam registrados em seu arquivo funcional', '17. Temos problemas com a segurança do paciente nesta unidade', '18. Nossos procedimentos e sistemas são bons para impedir que os erros aconteçam', '19. Meu supervisor/gerente elogia quando vê um trabalho feito de acordo com os procedimentos estabelecidos para a segurança do paciente.', '20. Meu supervisor/gerente considera seriamente as sugestões dos funcionários para melhorar a segurança do paciente', '21. Sempre que a pressão aumenta, meu supervisor/gerente quer que trabalhemos mais rápido, mesmo que isto signifique tomar atalhos', '22. Meu supervisor/gerente ignora problemas recorrentes na segurança do paciente', '23. Recebemos feedback das mudanças implementadas com base nos eventos notificados', '24. Os funcionários falam voluntariamente se vêem algo que possa afetar negativamente o atendimento aos pacientes', '25. Somos informados sobre os erros que acontecem nesta unidade', '26. Os funcionários sentem-se à vontade para questionar decisões ou ações dos que têm mais autoridade', '27. Nesta unidade, discutimos maneiras de impedir que os erros tornem a acontecer', '28. Os funcionários têm receio de perguntar quando algo não parece certo', '29. Quando acontece um erro, mas ele é identificado e corrigido antes de afetar o paciente, com que frequência é notificado?', '30. Quando acontece um erro, mas que não tem potencial de dano ao paciente, com que frequência é notificado?', '31. Quando acontece um erro que poderia prejudicar o paciente, mas isto não ocorreu, com que frequência é notificado?', '32. A administração do hospital cria um ambiente de trabalho que promove a segurança do paciente', '33. As unidades hospitalares não se coordenam bem entre si.', '34. Coisas "escapam por entre os dedos” quando os pacientes são transferidos de uma unidade para outra', '35. Existe uma boa cooperação entre as unidades hospitalares que precisam trabalhar juntas', '36. Importantes informações sobre a assistência se perdem durante as mudanças de turno', '37. Muitas vezes é desagradável trabalhar unidades com funcionários de outras unidades do hospital', '38. Os problemas com frequência ocorrem na troca de informações entre as unidades do hospital', '39. As ações da administração do hospital mostram que a segurança do paciente é uma prioridade máxima', '40. A administração do hospital parece se interessar pela segurança do paciente apenas quando acontece um evento adverso', '41. As unidades do hospital trabalham bem juntas para prestar o melhor atendimento aos pacientes', '42. As mudanças de turno são problemáticas para os pacientes deste Hospital', 'SEÇÃO G2: Notificou algum evento nos ultimos 12 meses', 'SEÇÃO G: Número de Eventos Notificados  Nos últimos  ...

# %% [markdown]
# # Score por Ano x Acreditação

# %%
df = df_bruto.copy()

# %% [raw]
# inicio = time.time() #iniciando o cronometro
#
# resultado = pd.DataFrame()
#
# for Ano in sorted(df['Ano'].unique()):
#     dff = df[df['Ano'] == Ano].copy().reset_index(drop=True)
#     fd = pd.DataFrame({'Ano': dff['Ano'].unique()})
#     fd['quant'] = len(dff)
#     fd['quant_unidade'] = len(dff['Unidade'].unique())
#
#     for coluna in lista_scores:
#         fd[coluna] = np.nan
#         for i in range(len(fd)):
#             if len(dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)) > 1:
#                 fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
#             else:
#                 fd[coluna][i] = 0
#
#     fd = fd.sort_values(by = 'Ano', ascending = True).reset_index(drop=True)
#     resultado = pd.concat([resultado, fd]).reset_index(drop=True)
#
# fim = time.time() #encerrando cronometro
# print('Tempo para rodar a simulação:', round(fim - inicio, 3))
#
# print('quantidade de linhas sumarizadas:', sum(resultado['quant']))

# %% [raw]
# # inicio = time.time() #iniciando o cronometro
#
# resultado = pd.DataFrame()
#
# for Ano in sorted(df['Ano'].unique()):
#
#     ###################################################
#     for acreditacao in range(2):
#         dff = df[(df['Ano'] == Ano) & (df['acreditacao'] == acreditacao)].copy().reset_index(drop=True)
#         fd = pd.DataFrame({'Ano': dff['Ano'].unique()})
#         fd['acreditacao'] = acreditacao
#         fd['quant'] = len(dff)
#         fd['quant_unidade'] = len(dff['Unidade'].unique())
#
#         for coluna in lista_scores:
#             fd[coluna] = np.nan
#             for i in range(len(fd)):
#                 if len(dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)) > 1:
#                     fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
#                 else:
#                     fd[coluna][i] = 0
#
#         fd = fd.sort_values(by = 'Ano', ascending = True).reset_index(drop=True)
#         resultado = pd.concat([resultado, fd]).reset_index(drop=True)
#
# fim = time.time() #encerrando cronometro
# print('Tempo para rodar a simulação:', round(fim - inicio, 3))
#
# print('quantidade de linhas sumarizadas:', sum(resultado['quant']))

# %% [raw]
# # df = resultado.copy()
#
# df['Abertura de comunicação'] = 0
# lista = ['24. Os funcionários falam voluntariamente se vêem algo que possa afetar negativamente o atendimento aos pacientes',
#          '26. Os funcionários sentem-se à vontade para questionar decisões ou ações dos que têm mais autoridade',
#          '28. Os funcionários têm receio de perguntar quando algo não parece certo']
# for i in lista:
#     df['Abertura de comunicação'] = df['Abertura de comunicação'] + df[i]
# df['Abertura de comunicação'] = df['Abertura de comunicação']/len(lista)
#
# df['Feedback e comunicação sobre erros'] = 0
# lista = ['23. Recebemos feedback das mudanças implementadas com base nos eventos notificados',
#          '25. Somos informados sobre os erros que acontecem nesta unidade',
#          '27. Nesta unidade, discutimos maneiras de impedir que os erros tornem a acontecer']
# for i in lista:
#     df['Feedback e comunicação sobre erros'] = df['Feedback e comunicação sobre erros'] + df[i]
# df['Feedback e comunicação sobre erros'] = df['Feedback e comunicação sobre erros']/len(lista)
#
# df['Frequência de eventos relatados'] = 0
# lista = ['29. Quando acontece um erro, mas ele é identificado e corrigido antes de afetar o paciente, com que frequência é notificado?',
#          '30. Quando acontece um erro, mas que não tem potencial de dano ao paciente, com que frequência é notificado?',
#          '31. Quando acontece um erro que poderia prejudicar o paciente, mas isto não ocorreu, com que frequência é notificado?']
# for i in lista:
#     df['Frequência de eventos relatados'] = df['Frequência de eventos relatados'] + df[i]
# df['Frequência de eventos relatados'] = df['Frequência de eventos relatados']/len(lista)
#
# df['Apoio de gestão hospitalar para segurança do paciente'] = 0
# lista = ['32. A administração do hospital cria um ambiente de trabalho que promove a segurança do paciente',
#          '39. As ações da administração do hospital mostram que a segurança do paciente é uma prioridade máxima',
#          '40. A administração do hospital parece se interessar pela segurança do paciente apenas quando acontece um evento adverso']
# for i in lista:
#     df['Apoio de gestão hospitalar para segurança do paciente'] = df['Apoio de gestão hospitalar para segurança do paciente'] + df[i]
# df['Apoio de gestão hospitalar para segurança do paciente'] = df['Apoio de gestão hospitalar para segurança do paciente']/len(lista)
#
# df['Trabalho em equipe entre as unidades hospitalares'] = 0
# lista = ['33. As unidades hospitalares não se coordenam bem entre si.',
#          '35. Existe uma boa cooperação entre as unidades hospitalares que precisam trabalhar juntas',
#          '37. Muitas vezes é desagradável trabalhar unidades com funcionários de outras unidades do hospital',
#          '41. As unidades do hospital trabalham bem juntas para prestar o melhor atendimento aos pacientes']
# for i in lista:
#     df['Trabalho em equipe entre as unidades hospitalares'] = df['Trabalho em equipe entre as unidades hospitalares'] + df[i]
# df['Trabalho em equipe entre as unidades hospitalares'] = df['Trabalho em equipe entre as unidades hospitalares']/len(lista)
#
# df['Trabalho em equipe no âmbito das unidades'] = 0
# lista = ['1. As pessoas se apoiam umas às outras nesta unidade',
#          '3. Quando há muito trabalho a ser feito e rapidamente, trabalhamos juntos em equipe para realizar a tarefa',
#          '4. Nesta unidade, as pessoas se tratam com respeito',
#          '11. Quando uma área nesta unidade fica muito movimentada, as demais ajudam']
# for i in lista:
#     df['Trabalho em equipe no âmbito das unidades'] = df['Trabalho em equipe no âmbito das unidades'] + df[i]
# df['Trabalho em equipe no âmbito das unidades'] = df['Trabalho em equipe no âmbito das unidades']/len(lista)
#
# df['Transferências internas e passagens de plantão'] = 0
# lista = ['34. Coisas "escapam por entre os dedos” quando os pacientes são transferidos de uma unidade para outra',
#          '36. Importantes informações sobre a assistência se perdem durante as mudanças de turno',
#          '38. Os problemas com frequência ocorrem na troca de informações entre as unidades do hospital',
#          '42. As mudanças de turno são problemáticas para os pacientes deste Hospital']
# for i in lista:
#     df['Transferências internas e passagens de plantão'] = df['Transferências internas e passagens de plantão'] + df[i]
# df['Transferências internas e passagens de plantão'] = df['Transferências internas e passagens de plantão']/len(lista)
#
# df['Aprendizado organizacional - melhoria contínua'] = 0
# lista = ['6. Estamos ativamente buscando melhorias para a segurança do paciente',
#          '9. Erros que ocorreram levaram a mudanças positivas nesta unidade',
#          '13. Quando fazemos mudanças para melhorar a segurança do paciente, nós avaliamos sua efetividade']
# for i in lista:
#     df['Aprendizado organizacional - melhoria contínua'] = df['Aprendizado organizacional - melhoria contínua'] + df[i]
# df['Aprendizado organizacional - melhoria contínua'] = df['Aprendizado organizacional - melhoria contínua']/len(lista)
#
# df['Expectativas de promoção da segurança dos supervisores e gerentes'] = 0
# lista = ['19. Meu supervisor/gerente elogia quando vê um trabalho feito de acordo com os procedimentos estabelecidos para a segurança do paciente.',
#          '20. Meu supervisor/gerente considera seriamente as sugestões dos funcionários para melhorar a segurança do paciente',
#          '21. Sempre que a pressão aumenta, meu supervisor/gerente quer que trabalhemos mais rápido, mesmo que isto signifique tomar atalhos',
#          '22. Meu supervisor/gerente ignora problemas recorrentes na segurança do paciente']
# for i in lista:
#     df['Expectativas de promoção da segurança dos supervisores e gerentes'] = df['Expectativas de promoção da segurança dos supervisores e gerentes'] + df[i]
# df['Expectativas de promoção da segurança dos supervisores e gerentes'] = df['Expectativas de promoção da segurança dos supervisores e gerentes']/len(lista)
#
# df['Percepção gerais sobre segurança'] = 0
# lista = ['10. É apenas por acaso que erros mais sérios não acontecem por aqui',
#          '15. A segurança do paciente nunca é sacrificada em prol de se trabalhar mais',
#          '17. Temos problemas com a segurança do paciente nesta unidade',
#          '18. Nossos procedimentos e sistemas são bons para impedir que os erros aconteçam']
# for i in lista:
#     df['Percepção gerais sobre segurança'] = df['Percepção gerais sobre segurança'] + df[i]
# df['Percepção gerais sobre segurança'] = df['Percepção gerais sobre segurança']/len(lista)
#
# df['Respostas não punitivas aos erros'] = 0
# lista = ['8. Os funcionários sentem que seus erros são usados contra eles',
#          '12. Quando um evento é notificado, sentimos que o foco se concentra no indivíduo, e não no problema',
#          '16. Os funcionários se preocupam que seus erros sejam registrados em seu arquivo funcional']
# for i in lista:
#     df['Respostas não punitivas aos erros'] = df['Respostas não punitivas aos erros'] + df[i]
# df['Respostas não punitivas aos erros'] = df['Respostas não punitivas aos erros']/len(lista)
#
# df['Staffing'] = 0
# lista = ['2. Temos pessoas suficientes para lidar com o volume de trabalho',
#          '5. Os funcionários desta unidade trabalham mais horas do que o recomendado no atendimento a pacientes',
#          '7. Utilizamos mais funcionários temporários do que o recomendado no atendimento a paciente',
#          '14. Trabalhamos “em modo de crise”, tentando fazer coisas demais, rápido demais']
# for i in lista:
#     df['Staffing'] = df['Staffing'] + df[i]
# df['Staffing'] = df['Staffing']/len(lista)

# %%
display(df)
# Out:
#          Ano            Unidade  \
# 0       2014  Coração do Brasil
# 1       2014  Coração do Brasil
# 2       2014  Coração do Brasil
# 3       2014  Coração do Brasil
# 4       2014  Coração do Brasil
# ...      ...                ...
# 259263  2022            Morumbi
# 259264  2022            Morumbi
# 259265  2022            Morumbi
# 259266  2022            Morumbi
# 259267  2022            Morumbi
#
#        Qual é sua principal área ou unidade neste hospital?  \
# 0                                             Suprimentos
# 1                                                     NaN
# 2                                          Administrativa
# 3                                        Centro Cirúrgico
# 4                                                Farmácia
# ...                                                   ...
# 259263                                                NaN
# 259264                       Unidade de Internação adulto
# 259265                                                NaN
# 259266                                                NaN
# 259267                                                NaN
#
#         1. As pessoas se apoiam umas às outras nesta unidade  \
# 0                                                     1.0
# 1                                                     1.0
# 2                                                     1.0
# 3                                                     0.0
# 4                                                     1.0
# ...                                                   ...
# 259263                                                1.0
# 259264                                                0.0
# 259265                                                1.0
# 259266                                                1.0
# 259267                                                1.0
#
#         2. Temos pessoas suficientes para lidar com o volume de trabalho  \
# 0                                                     0.0
# 1                                                     1.0
# 2                                                     1.0
# 3                                                     0.0
# 4                                                     0.0
# ...                                                   ...
# 259263                                                1.0
# 259264                                                0.0
# 259265                                                1.0
# 259266                                                1.0
# 259267                                                1.0
#
#         3. Quando há muito trabalho a ser feito e rapidamente, trabalhamos juntos em equipe para realizar a tarefa  \
# 0                                                     1.0
# 1                                                     1.0
# 2                                                     1.0
# 3                                                     1.0
# 4                                                     1.0
# ...                                                   ...
# 259263                                                1.0
# 259264                                                0.0
# 259265                                                1.0
# 259266                                                1.0
# 259267                                                1.0
#
#         4. Nesta unidade, as pessoas se tratam com respeito  \
# 0                                                     1.0
# 1                                                     0.0
# 2                                                     1.0
# 3                                                     1.0
# 4                                                     1.0
# ...                                                   ...
# 259263                                                1.0
# 259264                                                0.0
# 259265                                                1.0
# 259266                                                1.0
# 259267                                                1.0
#
#         5. Os funcionários desta unidade trabalham mais horas do que o recomendado no atendimento a pacientes  \
# 0                                                     0.0
# 1                                                     0.0
# 2                                                     0.0
# 3                                                     1.0
# 4                                                     0.0
# ...                                                   ...
# 259263                                                0.0
# 259264                                                0.0
# 259265                                                1.0
# 259266                                                1.0
# 259267                                                1.0
#
#         6. Estamos ativamente buscando melhorias para a segurança do paciente  \
# 0                                                     1.0
# 1                                                     1.0
# 2                                                     1.0
# 3                                                     1.0
# 4                                                     1.0
# ...                                                   ...
# 259263                                                1.0
# 259264                                                0.0
# 259265                                                1.0
# 259266                                                1.0
# 259267                                                1.0
#
#         7. Utilizamos mais funcionários temporários do que o recomendado no atendimento a paciente  \
# 0                                                     1.0
# 1                                                     1.0
# 2                                                     0.0
# 3                                                     1.0
# 4                                                     1.0
# ...                                                   ...
# 259263                                                1.0
# 259264                                                0.0
# 259265                                                1.0
# 259266                                                1.0
# 259267                                                1.0
#
#         ...  \
# 0       ...
# 1       ...
# 2       ...
# 3       ...
# 4       ...
# ...     ...
# 259263  ...
# 259264  ...
# 259265  ...
# 259266  ...
# 259267  ...
#
#         SEÇÃO H: 1. Há quanto tempo você trabalha neste hospital?_2. 6 a 10 anos  \
# 0                                                       0
# 1                                                       0
# 2                                                       0
# 3                                                       0
# 4                                                       0
# ...                                                   ...
# 259263                                                  0
# 259264                                                  0
# 259265                                                  0
# 259266                                                  0
# 259267                                                  0
#
#         SEÇÃO H: 1. Há quanto tempo você trabalha neste hospital?_3. 11 a 15 anos  \
# 0                                                       0
# 1                                                       0
# 2                                                       0
# 3                                                       0
# 4                                                       0
# ...                                                   ...
# 259263                                                  0
# 259264                                                  0
# 259265                                                  1
# 259266                                                  0
# 259267                                                  1
#
#         SEÇÃO H: 1. Há quanto tempo você trabalha neste hospital?_4. 16 a 20 anos  \
# 0                                                       0
# 1                                                       0
# 2                                                       0
# 3                                                       0
# 4                                                       0
# ...                                                   ...
# 259263                                                  0
# 259264                                                  0
# 259265                                                  0
# 259266                                                  0
# 259267                                                  0
#
#         SEÇÃO H: 1. Há quanto tempo você trabalha neste hospital?_5. 21 anos ou mais  \
# 0                                                       0
# 1                                                       0
# 2                                                       0
# 3                                                       0
# 4                                                       0
# ...                                                   ...
# 259263                                                  0
# 259264                                                  0
# 259265                                                  0
# 259266                                                  0
# 259267                                                  0
#
#         6. Há quanto tempo você trabalha em sua profissão ou especialização atual?_0. Menos de 1 ano  \
# 0                                                       0
# 1                                                       1
# 2                                                       0
# 3                                                       0
# 4                                                       0
# ...                                                   ...
# 259263                                                  0
# 259264                                                  0
# 259265                                                  0
# 259266                                                  0
# 259267                                                  0
#
#         6. Há quanto tempo você trabalha em sua profissão ou especialização atual?_1. 1 a 5 anos  \
# 0                                                       0
# 1                                                       0
# 2                                                       1
# 3                                                       0
# 4                                                       1
# ...                                                   ...
# 259263                                                  1
# 259264                                                  1
# 259265                                                  1
# 259266                                                  0
# 259267                                                  0
#
#         6. Há quanto tempo você trabalha em sua profissão ou especialização atual?_2. 6 a 10 anos  \
# 0                                                       1
# 1                                                       0
# 2                                                       0
# 3                                                       1
# 4                                                       0
# ...                                                   ...
# 259263                                                  0
# 259264                                                  0
# 259265                                                  0
# 259266                                                  0
# 259267                                                  0
#
#         6. Há quanto tempo você trabalha em sua profissão ou especialização atual?_3. 11 a 15 anos  \
# 0                                                       0
# 1                                                       0
# 2                                                       0
# 3                                                       0
# 4                                                       0
# ...                                                   ...
# 259263                                                  0
# 259264                                                  0
# 259265                                                  0
# 259266                                                  1
# 259267                                                  1
#
#         6. Há quanto tempo você trabalha em sua profissão ou especialização atual?_4. 16 a 20 anos  \
# 0                                                       0
# 1                                                       0
# 2                                                       0
# 3                                                       0
# 4                                                       0
# ...                                                   ...
# 259263                                                  0
# 259264                                                  0
# 259265                                                  0
# 259266                                                  0
# 259267                                                  0
#
#         6. Há quanto tempo você trabalha em sua profissão ou especialização atual?_5. 21 anos ou mais
# 0                                                       0
# 1                                                       0
# 2                                                       0
# 3                                                       0
# 4                                                       0
# ...                                                   ...
# 259263                                                  0
# 259264                                                  0
# 259265                                                  0
# 259266                                                  0
# 259267                                                  0
#
# [259268 rows x 92 columns]

# %% [raw]
# df = df[df["quant"] >= 10].reset_index(drop=True)

# %%
#df.to_excel('3 - Dados_Score_Ano_vs_Acreditacao.xlsx')

# %%
#stop

# %% [markdown]
# # Score por Ano x Acreditação x (NOVOS vs VELHOS)

# %%
print(len(df))
count = 0
for tempo_trabalho in range(2):
    df_teste = df[df['SEÇÃO H: 1.2 trabalha a mais de 1 ano no hospital?'] == tempo_trabalho]
    print(len(df_teste))
    count += len(df_teste)
print(count)
# Out:
# 259268
# 54735
# 202295
# 257030

# %%
inicio = time.time() #iniciando o cronometro

resultado = pd.DataFrame()

nome_grande = 'SEÇÃO H: 1.2 trabalha a mais de 1 ano no hospital?'

for Ano in sorted(df['Ano'].unique()):
    ###################################################
    for tempo_trabalho in range(2):
        for acreditacao in range(2):
            dff = df[(df['Ano'] == Ano) & (df['acreditacao'] == acreditacao) & (df[nome_grande] == tempo_trabalho)].copy().reset_index(drop=True)
            fd = pd.DataFrame({'Ano': dff['Ano'].unique()})
            fd['acreditacao'] = acreditacao
            fd['quant'] = len(dff)
            fd['quant_unidade'] = len(dff['Unidade'].unique())
            fd['trabalha_mais_1ano'] = tempo_trabalho

            for coluna in lista_scores:
                fd[coluna] = np.nan
                for i in range(len(fd)):
                    if len(dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)) > 1:
                        fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
                    else:
                        fd[coluna][i] = 0

            fd = fd.sort_values(by = 'Ano', ascending = True).reset_index(drop=True)
            resultado = pd.concat([resultado, fd]).reset_index(drop=True)

fim = time.time() #encerrando cronometro
print('Tempo para rodar a simulação:', round(fim - inicio, 3))

print('quantidade de linhas sumarizadas:', sum(resultado['quant']))
# Out:
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = 0
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = 0
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = 0
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = 0
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = 0
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = 0
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = 0
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = 0
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = 0
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# Tempo para rodar a simulação: 4.608
# quantidade de linhas sumarizadas: 257030
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = 0
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = 0
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100
# C:\Users\ADM\AppData\Local\Temp\ipykernel_8728\1313537387.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fd[coluna][i] = dff[coluna][dff['Ano'] == fd['Ano'][i]].value_counts(normalize=True)[1]*100

# %%
df = resultado.copy()

df['Abertura de comunicação'] = 0
lista = ['24. Os funcionários falam voluntariamente se vêem algo que possa afetar negativamente o atendimento aos pacientes',
         '26. Os funcionários sentem-se à vontade para questionar decisões ou ações dos que têm mais autoridade',
         '28. Os funcionários têm receio de perguntar quando algo não parece certo']
for i in lista:
    df['Abertura de comunicação'] = df['Abertura de comunicação'] + df[i]
df['Abertura de comunicação'] = df['Abertura de comunicação']/len(lista)

df['Feedback e comunicação sobre erros'] = 0
lista = ['23. Recebemos feedback das mudanças implementadas com base nos eventos notificados',
         '25. Somos informados sobre os erros que acontecem nesta unidade',
         '27. Nesta unidade, discutimos maneiras de impedir que os erros tornem a acontecer']
for i in lista:
    df['Feedback e comunicação sobre erros'] = df['Feedback e comunicação sobre erros'] + df[i]
df['Feedback e comunicação sobre erros'] = df['Feedback e comunicação sobre erros']/len(lista)

df['Frequência de eventos relatados'] = 0
lista = ['29. Quando acontece um erro, mas ele é identificado e corrigido antes de afetar o paciente, com que frequência é notificado?',
         '30. Quando acontece um erro, mas que não tem potencial de dano ao paciente, com que frequência é notificado?',
         '31. Quando acontece um erro que poderia prejudicar o paciente, mas isto não ocorreu, com que frequência é notificado?']
for i in lista:
    df['Frequência de eventos relatados'] = df['Frequência de eventos relatados'] + df[i]
df['Frequência de eventos relatados'] = df['Frequência de eventos relatados']/len(lista)

df['Apoio de gestão hospitalar para segurança do paciente'] = 0
lista = ['32. A administração do hospital cria um ambiente de trabalho que promove a segurança do paciente',
         '39. As ações da administração do hospital mostram que a segurança do paciente é uma prioridade máxima',
         '40. A administração do hospital parece se interessar pela segurança do paciente apenas quando acontece um evento adverso']
for i in lista:
    df['Apoio de gestão hospitalar para segurança do paciente'] = df['Apoio de gestão hospitalar para segurança do paciente'] + df[i]
df['Apoio de gestão hospitalar para segurança do paciente'] = df['Apoio de gestão hospitalar para segurança do paciente']/len(lista)

df['Trabalho em equipe entre as unidades hospitalares'] = 0
lista = ['33. As unidades hospitalares não se coordenam bem entre si.',
         '35. Existe uma boa cooperação entre as unidades hospitalares que precisam trabalhar juntas',
         '37. Muitas vezes é desagradável trabalhar unidades com funcionários de outras unidades do hospital',
         '41. As unidades do hospital trabalham bem juntas para prestar o melhor atendimento aos pacientes']
for i in lista:
    df['Trabalho em equipe entre as unidades hospitalares'] = df['Trabalho em equipe entre as unidades hospitalares'] + df[i]
df['Trabalho em equipe entre as unidades hospitalares'] = df['Trabalho em equipe entre as unidades hospitalares']/len(lista)

df['Trabalho em equipe no âmbito das unidades'] = 0
lista = ['1. As pessoas se apoiam umas às outras nesta unidade',
         '3. Quando há muito trabalho a ser feito e rapidamente, trabalhamos juntos em equipe para realizar a tarefa',
         '4. Nesta unidade, as pessoas se tratam com respeito',
         '11. Quando uma área nesta unidade fica muito movimentada, as demais ajudam']
for i in lista:
    df['Trabalho em equipe no âmbito das unidades'] = df['Trabalho em equipe no âmbito das unidades'] + df[i]
df['Trabalho em equipe no âmbito das unidades'] = df['Trabalho em equipe no âmbito das unidades']/len(lista)

df['Transferências internas e passagens de plantão'] = 0
lista = ['34. Coisas "escapam por entre os dedos” quando os pacientes são transferidos de uma unidade para outra',
         '36. Importantes informações sobre a assistência se perdem durante as mudanças de turno',
         '38. Os problemas com frequência ocorrem na troca de informações entre as unidades do hospital',
         '42. As mudanças de turno são problemáticas para os pacientes deste Hospital']
for i in lista:
    df['Transferências internas e passagens de plantão'] = df['Transferências internas e passagens de plantão'] + df[i]
df['Transferências internas e passagens de plantão'] = df['Transferências internas e passagens de plantão']/len(lista)

df['Aprendizado organizacional - melhoria contínua'] = 0
lista = ['6. Estamos ativamente buscando melhorias para a segurança do paciente',
         '9. Erros que ocorreram levaram a mudanças positivas nesta unidade',
         '13. Quando fazemos mudanças para melhorar a segurança do paciente, nós avaliamos sua efetividade']
for i in lista:
    df['Aprendizado organizacional - melhoria contínua'] = df['Aprendizado organizacional - melhoria contínua'] + df[i]
df['Aprendizado organizacional - melhoria contínua'] = df['Aprendizado organizacional - melhoria contínua']/len(lista)

df['Expectativas de promoção da segurança dos supervisores e gerentes'] = 0
lista = ['19. Meu supervisor/gerente elogia quando vê um trabalho feito de acordo com os procedimentos estabelecidos para a segurança do paciente.',
         '20. Meu supervisor/gerente considera seriamente as sugestões dos funcionários para melhorar a segurança do paciente',
         '21. Sempre que a pressão aumenta, meu supervisor/gerente quer que trabalhemos mais rápido, mesmo que isto signifique tomar atalhos',
         '22. Meu supervisor/gerente ignora problemas recorrentes na segurança do paciente']
for i in lista:
    df['Expectativas de promoção da segurança dos supervisores e gerentes'] = df['Expectativas de promoção da segurança dos supervisores e gerentes'] + df[i]
df['Expectativas de promoção da segurança dos supervisores e gerentes'] = df['Expectativas de promoção da segurança dos supervisores e gerentes']/len(lista)

df['Percepção gerais sobre segurança'] = 0
lista = ['10. É apenas por acaso que erros mais sérios não acontecem por aqui',
         '15. A segurança do paciente nunca é sacrificada em prol de se trabalhar mais',
         '17. Temos problemas com a segurança do paciente nesta unidade',
         '18. Nossos procedimentos e sistemas são bons para impedir que os erros aconteçam']
for i in lista:
    df['Percepção gerais sobre segurança'] = df['Percepção gerais sobre segurança'] + df[i]
df['Percepção gerais sobre segurança'] = df['Percepção gerais sobre segurança']/len(lista)

df['Respostas não punitivas aos erros'] = 0
lista = ['8. Os funcionários sentem que seus erros são usados contra eles',
         '12. Quando um evento é notificado, sentimos que o foco se concentra no indivíduo, e não no problema',
         '16. Os funcionários se preocupam que seus erros sejam registrados em seu arquivo funcional']
for i in lista:
    df['Respostas não punitivas aos erros'] = df['Respostas não punitivas aos erros'] + df[i]
df['Respostas não punitivas aos erros'] = df['Respostas não punitivas aos erros']/len(lista)

df['Staffing'] = 0
lista = ['2. Temos pessoas suficientes para lidar com o volume de trabalho',
         '5. Os funcionários desta unidade trabalham mais horas do que o recomendado no atendimento a pacientes',
         '7. Utilizamos mais funcionários temporários do que o recomendado no atendimento a paciente',
         '14. Trabalhamos “em modo de crise”, tentando fazer coisas demais, rápido demais']
for i in lista:
    df['Staffing'] = df['Staffing'] + df[i]
df['Staffing'] = df['Staffing']/len(lista)

# %%
df.to_excel('3 - Dados_Score_Ano_vs_Acreditacao_tempotrab.xlsx')

# %%
stop
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 stop
#
# NameError: name 'stop' is not defined

# %% [markdown]
# # Score Por Ano x Acreditação x Unidade

# %%
df = df_bruto.copy()

# %%
inicio = time.time() #iniciando o cronometro

resultado = pd.DataFrame()

for Ano in sorted(df['Ano'].unique()):

    ###################################################
    for acreditacao in range(2):
        dff = df[(df['Ano'] == Ano) & (df['acreditacao'] == acreditacao)].copy().reset_index(drop=True)
        fd = pd.DataFrame({'Unidade': dff['Unidade'].unique()})
        fd['acreditacao'] = acreditacao
        
        fd['Acreditação'] = np.nan
        fd['Acreditação2'] = np.nan
        
        fd['Ano'] = Ano
        fd['Regional'] = np.nan
        fd['Estado'] = np.nan
        fd['quant'] = np.nan

        for coluna in lista_scores:
            fd[coluna] = np.nan
            for i in range(len(fd)):
                if len(dff[coluna][dff['Unidade'] == fd['Unidade'][i]].value_counts(normalize=True)) > 1:
                    fd[coluna][i] = dff[coluna][dff['Unidade'] == fd['Unidade'][i]].value_counts(normalize=True)[1]*100
                else:
                    fd[coluna][i] = 0
                fd['Regional'][i] = dff['Regional'][dff['Unidade'] == fd['Unidade'][i]].values[0]
                fd['Estado'][i] = dff['Estado'][dff['Unidade'] == fd['Unidade'][i]].values[0]
                fd['quant'][i] = len(dff[dff['Unidade'] == fd['Unidade'][i]])
                
                fd['Acreditação'][i] = dff['Acreditação'][(dff['Unidade'] == fd['Unidade'][i]) &
                                                          (dff['Ano'] == fd['Ano'][i])].values[0]
                fd['Acreditação2'][i] = dff['Acreditação2'][(dff['Unidade'] == fd['Unidade'][i]) &
                                                            (dff['Ano'] == fd['Ano'][i])].values[0]
                
        resultado = pd.concat([resultado, fd]).reset_index(drop=True)

fim = time.time() #encerrando cronometro
print('Tempo para rodar a simulação:', round(fim - inicio, 3))

print('quantidade de linhas sumarizadas:', sum(resultado['quant']))
df = resultado.sort_values(by = ['Unidade','Ano'], ascending = True).reset_index(drop=True)

# %%
df['Abertura de comunicação'] = 0
lista = ['24. Os funcionários falam voluntariamente se vêem algo que possa afetar negativamente o atendimento aos pacientes',
         '26. Os funcionários sentem-se à vontade para questionar decisões ou ações dos que têm mais autoridade',
         '28. Os funcionários têm receio de perguntar quando algo não parece certo']
for i in lista:
    df['Abertura de comunicação'] = df['Abertura de comunicação'] + df[i]
df['Abertura de comunicação'] = df['Abertura de comunicação']/len(lista)

df['Feedback e comunicação sobre erros'] = 0
lista = ['23. Recebemos feedback das mudanças implementadas com base nos eventos notificados',
         '25. Somos informados sobre os erros que acontecem nesta unidade',
         '27. Nesta unidade, discutimos maneiras de impedir que os erros tornem a acontecer']
for i in lista:
    df['Feedback e comunicação sobre erros'] = df['Feedback e comunicação sobre erros'] + df[i]
df['Feedback e comunicação sobre erros'] = df['Feedback e comunicação sobre erros']/len(lista)

df['Frequência de eventos relatados'] = 0
lista = ['29. Quando acontece um erro, mas ele é identificado e corrigido antes de afetar o paciente, com que frequência é notificado?',
         '30. Quando acontece um erro, mas que não tem potencial de dano ao paciente, com que frequência é notificado?',
         '31. Quando acontece um erro que poderia prejudicar o paciente, mas isto não ocorreu, com que frequência é notificado?']
for i in lista:
    df['Frequência de eventos relatados'] = df['Frequência de eventos relatados'] + df[i]
df['Frequência de eventos relatados'] = df['Frequência de eventos relatados']/len(lista)

df['Apoio de gestão hospitalar para segurança do paciente'] = 0
lista = ['32. A administração do hospital cria um ambiente de trabalho que promove a segurança do paciente',
         '39. As ações da administração do hospital mostram que a segurança do paciente é uma prioridade máxima',
         '40. A administração do hospital parece se interessar pela segurança do paciente apenas quando acontece um evento adverso']
for i in lista:
    df['Apoio de gestão hospitalar para segurança do paciente'] = df['Apoio de gestão hospitalar para segurança do paciente'] + df[i]
df['Apoio de gestão hospitalar para segurança do paciente'] = df['Apoio de gestão hospitalar para segurança do paciente']/len(lista)

df['Trabalho em equipe entre as unidades hospitalares'] = 0
lista = ['33. As unidades hospitalares não se coordenam bem entre si.',
         '35. Existe uma boa cooperação entre as unidades hospitalares que precisam trabalhar juntas',
         '37. Muitas vezes é desagradável trabalhar unidades com funcionários de outras unidades do hospital',
         '41. As unidades do hospital trabalham bem juntas para prestar o melhor atendimento aos pacientes']
for i in lista:
    df['Trabalho em equipe entre as unidades hospitalares'] = df['Trabalho em equipe entre as unidades hospitalares'] + df[i]
df['Trabalho em equipe entre as unidades hospitalares'] = df['Trabalho em equipe entre as unidades hospitalares']/len(lista)

df['Trabalho em equipe no âmbito das unidades'] = 0
lista = ['1. As pessoas se apoiam umas às outras nesta unidade',
         '3. Quando há muito trabalho a ser feito e rapidamente, trabalhamos juntos em equipe para realizar a tarefa',
         '4. Nesta unidade, as pessoas se tratam com respeito',
         '11. Quando uma área nesta unidade fica muito movimentada, as demais ajudam']
for i in lista:
    df['Trabalho em equipe no âmbito das unidades'] = df['Trabalho em equipe no âmbito das unidades'] + df[i]
df['Trabalho em equipe no âmbito das unidades'] = df['Trabalho em equipe no âmbito das unidades']/len(lista)

df['Transferências internas e passagens de plantão'] = 0
lista = ['34. Coisas "escapam por entre os dedos” quando os pacientes são transferidos de uma unidade para outra',
         '36. Importantes informações sobre a assistência se perdem durante as mudanças de turno',
         '38. Os problemas com frequência ocorrem na troca de informações entre as unidades do hospital',
         '42. As mudanças de turno são problemáticas para os pacientes deste Hospital']
for i in lista:
    df['Transferências internas e passagens de plantão'] = df['Transferências internas e passagens de plantão'] + df[i]
df['Transferências internas e passagens de plantão'] = df['Transferências internas e passagens de plantão']/len(lista)

df['Aprendizado organizacional - melhoria contínua'] = 0
lista = ['6. Estamos ativamente buscando melhorias para a segurança do paciente',
         '9. Erros que ocorreram levaram a mudanças positivas nesta unidade',
         '13. Quando fazemos mudanças para melhorar a segurança do paciente, nós avaliamos sua efetividade']
for i in lista:
    df['Aprendizado organizacional - melhoria contínua'] = df['Aprendizado organizacional - melhoria contínua'] + df[i]
df['Aprendizado organizacional - melhoria contínua'] = df['Aprendizado organizacional - melhoria contínua']/len(lista)

df['Expectativas de promoção da segurança dos supervisores e gerentes'] = 0
lista = ['19. Meu supervisor/gerente elogia quando vê um trabalho feito de acordo com os procedimentos estabelecidos para a segurança do paciente.',
         '20. Meu supervisor/gerente considera seriamente as sugestões dos funcionários para melhorar a segurança do paciente',
         '21. Sempre que a pressão aumenta, meu supervisor/gerente quer que trabalhemos mais rápido, mesmo que isto signifique tomar atalhos',
         '22. Meu supervisor/gerente ignora problemas recorrentes na segurança do paciente']
for i in lista:
    df['Expectativas de promoção da segurança dos supervisores e gerentes'] = df['Expectativas de promoção da segurança dos supervisores e gerentes'] + df[i]
df['Expectativas de promoção da segurança dos supervisores e gerentes'] = df['Expectativas de promoção da segurança dos supervisores e gerentes']/len(lista)

df['Percepção gerais sobre segurança'] = 0
lista = ['10. É apenas por acaso que erros mais sérios não acontecem por aqui',
         '15. A segurança do paciente nunca é sacrificada em prol de se trabalhar mais',
         '17. Temos problemas com a segurança do paciente nesta unidade',
         '18. Nossos procedimentos e sistemas são bons para impedir que os erros aconteçam']
for i in lista:
    df['Percepção gerais sobre segurança'] = df['Percepção gerais sobre segurança'] + df[i]
df['Percepção gerais sobre segurança'] = df['Percepção gerais sobre segurança']/len(lista)

df['Respostas não punitivas aos erros'] = 0
lista = ['8. Os funcionários sentem que seus erros são usados contra eles',
         '12. Quando um evento é notificado, sentimos que o foco se concentra no indivíduo, e não no problema',
         '16. Os funcionários se preocupam que seus erros sejam registrados em seu arquivo funcional']
for i in lista:
    df['Respostas não punitivas aos erros'] = df['Respostas não punitivas aos erros'] + df[i]
df['Respostas não punitivas aos erros'] = df['Respostas não punitivas aos erros']/len(lista)

df['Staffing'] = 0
lista = ['2. Temos pessoas suficientes para lidar com o volume de trabalho',
         '5. Os funcionários desta unidade trabalham mais horas do que o recomendado no atendimento a pacientes',
         '7. Utilizamos mais funcionários temporários do que o recomendado no atendimento a paciente',
         '14. Trabalhamos “em modo de crise”, tentando fazer coisas demais, rápido demais']
for i in lista:
    df['Staffing'] = df['Staffing'] + df[i]
df['Staffing'] = df['Staffing']/len(lista)

# %%
df = df[df["quant"] >= 10].reset_index(drop=True)

# %%
df['passou_a_ser_acreditado'] = 0
tabela = pd.DataFrame(columns = df.columns)
count = 0
for unidade in sorted(df['Unidade'].unique()):
    if len(df['acreditacao'][df['Unidade'] == unidade].unique()) >= 2:
        df['passou_a_ser_acreditado'][df['Unidade'] == unidade] = 1
        print(unidade, '='*25)
        print(df[df['Unidade'] == unidade].groupby(['Ano', 'acreditacao']).size(), '\n')
        count += 1
        
        tabela = pd.concat([tabela, df[df['Unidade'] == unidade]])
        
print('='*25, 'QUANTIDADE:', count, '='*25)
display(tabela)

display(df['passou_a_ser_acreditado'].value_counts())

# %%
for i in df['passou_a_ser_acreditado'].unique():
    print(i,'='*50)
    count = 0
    for t in df['Unidade'][df['passou_a_ser_acreditado'] == i].unique():
        print(df['acreditacao'][df['Unidade'] == t].unique())
        count += 1
    print(count)

df['passou_a_ser_acreditado'].value_counts()

# %%
df['status_eterno'] = np.nan

df['status_eterno'][df['passou_a_ser_acreditado'] == 0] = df['acreditacao']
df['status_eterno'].value_counts()

# %%
display(pd.concat([df.head(10),df.tail(10)]))

# %%
df.to_excel('4 - Dados_Score_Ano_vs_Acreditacao_vs_Unidade.xlsx')
