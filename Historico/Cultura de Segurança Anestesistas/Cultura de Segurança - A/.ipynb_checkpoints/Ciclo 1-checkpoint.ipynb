# %%
#Roda ele
## BIBLIOTECAS
import requests
from bs4 import BeautifulSoup

#Manipulação de Dados
import pandas as pd
import numpy as np

import shutil
import os
import pyautogui

import unidecode #arrumar textos

#tempo
import time
from time import sleep

import re #regex

import matplotlib.pyplot as plt
import matplotlib.cm as cm

import matplotlib.font_manager as fm #para alterar as fontes dos graficos
import seaborn as sns

import pyperclip

import statistics
import math

from scipy import stats

import warnings #Warning inuteis
from pandas.core.common import SettingWithCopyWarning
warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)


# Definindo o estilo de fonte e tema
fonte = fm.FontProperties(family="Calibri", style="italic")

sns.set_style('whitegrid') #cor da grade(fundo)

import pyperclip
from tableone import TableOne

#TESTE ANOVA
import statsmodels.api as sm
from statsmodels.formula.api import ols

import seaborn

from statsmodels.stats.stattools import durbin_watson #teste de autocorrelação

# %%
inicio = time.time() #iniciando o cronometro

df = pd.read_excel("BANCO CULTURA.xlsx")
df = df[df['Qual é sua principal área ou unidade neste hospital?'] == "Anestesiologia"]
df.sample(5)

fim = time.time() #encerrando cronometro
print('Tempo para rodar a simulação:', round(fim - inicio, 3))
# Out:
# Tempo para rodar a simulação: 141.266

# %%
len(df)
# Out:
# 3705

# %%
print(df.columns)
display(df.sample(5))
# Out:
# Index(['Ano', 'Unidade',
#        'Qual é sua principal área ou unidade neste hospital?',
#        'Outro (especifique)',
#        '1. As pessoas se apoiam umas às outras nesta unidade',
#        '2. Temos pessoas suficientes para lidar com o volume de trabalho',
#        '3. Quando há muito trabalho a ser feito e rapidamente, trabalhamos juntos em equipe para realizar a tarefa',
#        '4. Nesta unidade, as pessoas se tratam com respeito',
#        '5. Os funcionários desta unidade trabalham mais horas do que o recomendado no atendimento a pacientes',
#        '6. Estamos ativamente buscando melhorias para a segurança do paciente',
#        '7. Utilizamos mais funcionários temporários do que o recomendado no atendimento a paciente',
#        '8. Os funcionários sentem que seus erros são usados contra eles',
#        '9. Erros que ocorreram levaram a mudanças positivas nesta unidade',
#        '10. É apenas por acaso que erros mais sérios não acontecem por aqui',
#        '11. Quando uma área nesta unidade fica muito movimentada, as demais ajudam',
#        '12. Quando um evento é notificado, sentimos que o foco se concentra no indivíduo, e não no problema',
#        '13. Quando fazemos mudanças para melhorar a segurança do paciente, nós avaliamos sua efetividade',
#        '14. Trabalhamos “em modo de crise”, tentando fazer coisas demais, rápido demais',
#        '15. A segurança do paciente nunca é sacrificada em prol de se trabalhar mais',
#        '16. Os funcionários se preocupam que seus erros sejam registrados em seu arquivo funcional',
#        '17. Temos problemas com a segurança do paciente nesta unidade',
#        '18. Nossos procedimentos e sistemas são bons para impedir que os erros aconteçam',
#        '19. Meu supervisor/gerente elogia quando vê um trabalho feito de acordo com os procedimentos estabelecidos para a segurança do paciente.',
#        '20. Meu supervisor/gerente considera seriamente as sugestões dos funcionários para melhorar a segurança do paciente',
#        '21. Sempre que a pressão aumenta, meu supervisor/gerente quer que trabalhemos mais rápido, mesmo que isto signifique tomar atalhos',
#        '22. Meu supervisor/gerente ignora problemas recorrentes na segurança do paciente',
#        '23. Recebemos feedback das mudanças implementadas com base nos eventos notificados',
#        '24. Os funcionários falam voluntariamente se vêem algo que possa afetar negativamente o atendimento aos pacientes',
#        '25. Somos informados sobre os erros que acontecem nesta unidade',
#        '26. Os funcionários sentem-se à vontade para questionar decisões ou ações dos que têm mais autoridade',
#        '27. Nesta unidade, discutimos maneiras de impedir que os erros tornem a acontecer',
#        '28. Os funcionários têm receio de perguntar quando algo não parece certo',
#        '29. Quando acontece um erro, mas ele é identificado e corrigido antes de afetar o paciente, com que frequência é notificado?',
#        '30. Quando acontece um erro, mas que não tem potencial de dano ao paciente, com que frequência é notificado?',
#        '31. Quando acontece um erro que poderia prejudicar o paciente, mas isto não ocorreu, com que frequência é notificado?',
#        'Por favor, dê uma nota geral para a segurança do paciente em sua área/unidade de trabalho hospitalar.',
#        '32. A administração do hospital cria um ambiente de trabalho que promove a segurança do paciente',
#        '33. As unidades hospitalares não se coordenam bem entre si.',
#        '34. Coisas "escapam por entre os dedos” quando os pacientes são transferidos de uma unidade para outra',
#        '35. Existe uma boa cooperação entre as unidades hospitalares que precisam trabalhar juntas',
#        '36. Importantes informações sobre a assistência se perdem durante as mudanças de turno',
#        '37. Muitas vezes é desagradável trabalhar unidades com funcionários de outras unidades do hospital',
#        '38. Os problemas com frequência ocorrem na troca de informações entre as unidades do hospital',
#        '39. As ações da administração do hospital mostram que a segurança do paciente é uma prioridade máxima',
#        '40. A administração do hospital parece se interessar pela segurança do paciente apenas quando acontece um evento adverso',
#        '41. As unidades do hospital trabalham bem juntas para prestar o melhor atendimento aos pacientes',
#        '42. As mudanças de turno são problemáticas para os pacientes deste Hospital',
#        'SEÇÃO G: Número de Eventos Notificados  Nos últimos 12 meses, quantas notificações de evento você preencheu e enviou?',
#        'SEÇÃO H: 1. Há quanto tempo você trabalha neste hospital?',
#        'SEÇÃO H: 2.Há quanto tempo você trabalha nesta área/unidade de trabalho hospitalar?',
#        'SEÇÃO H: 3.Tipicamente, quantas horas por semana você trabalha neste hospital?  ',
#        ' SEÇÃO H: 4. Qual é o seu cargo neste hospital? Marque UMA resposta que melhor descreva a sua função.',
#        'Outro (especifique)2',
#        '5. Em sua função, você tipicamente tem contato ou interação direta com os pacientes?  ',
#        '5. Em sua função, você tipicamente tem contato ou interação direta com os pacientes?  3',
#        '6. Há quanto tempo você trabalha em sua profissão ou especialização atual?  ',
#        'SEÇÃO I: Seus Comentários  Por favor, sinta-se à vontade para fazer quaisquer comentários sobre a segurança do paciente, erros ou  notificação de eventos em seu hospital.  ',
#        '5. Em sua função, você tipicamente tem contato ou interação direta com os pacientes?  32',
#        'Regional', 'Estado', 'Acreditação'],
#       dtype='object')
#          Ano             Unidade  \
# 177426  2016       Anália Franco
# 161950  2014       Anália Franco
# 208063  2019  Jabaquara/ Criança
# 38470   2020           São Lucas
# 199774  2018             Morumbi
#
#        Qual é sua principal área ou unidade neste hospital?  \
# 177426                                     Anestesiologia
# 161950                                     Anestesiologia
# 208063                                     Anestesiologia
# 38470                                      Anestesiologia
# 199774                                     Anestesiologia
#
#        Outro (especifique)  \
# 177426                 NaN
# 161950                 NaN
# 208063                 NaN
# 38470                  NaN
# 199774                 NaN
#
#        1. As pessoas se apoiam umas às outras nesta unidade  \
# 177426                     Concordo + Concordo totalmente
# 161950                     Concordo + Concordo totalmente
# 208063                     Concordo + Concordo totalmente
# 38470                      Concordo + Concordo totalmente
# 199774                     Discordo + Discordo totalmente
#
#        2. Temos pessoas suficientes para lidar com o volume de trabalho  \
# 177426                     Discordo + Discordo totalmente
# 161950                     Concordo + Concordo totalmente
# 208063                     Concordo + Concordo totalmente
# 38470                      Concordo + Concordo totalmente
# 199774                     Discordo + Discordo totalmente
#
#        3. Quando há muito trabalho a ser feito e rapidamente, trabalhamos juntos em equipe para realizar a tarefa  \
# 177426                     Concordo + Concordo totalmente
# 161950                     Concordo + Concordo totalmente
# 208063                     Concordo + Concordo totalmente
# 38470                      Concordo + Concordo totalmente
# 199774                     Concordo + Concordo totalmente
#
#        4. Nesta unidade, as pessoas se tratam com respeito  \
# 177426                     Concordo + Concordo totalmente
# 161950                     Concordo + Concordo totalmente
# 208063                     Concordo + Concordo totalmente
# 38470                      Concordo + Concordo totalmente
# 199774                     Concordo + Concordo totalmente
#
#        5. Os funcionários desta unidade trabalham mais horas do que o recomendado no atendimento a pacientes  \
# 177426                     Discordo + Discordo totalmente
# 161950                     Discordo + Discordo totalmente
# 208063                                   Nem um nem outro
# 38470                      Concordo + Concordo totalmente
# 199774                     Concordo + Concordo totalmente
#
#        6. Estamos ativamente buscando melhorias para a segurança do paciente  \
# 177426                     Concordo + Concordo totalmente
# 161950                     Concordo + Concordo totalmente
# 208063                                   Nem um nem outro
# 38470                      Concordo + Concordo totalmente
# 199774                     Concordo + Concordo totalmente
#
#         ...  \
# 177426  ...
# 161950  ...
# 208063  ...
# 38470   ...
# 199774  ...
#
#         SEÇÃO H: 4. Qual é o seu cargo neste hospital? Marque UMA resposta que melhor descreva a sua função.  \
# 177426                             Médico staff cirúrgico
# 161950                                                NaN
# 208063                               Médico staff clínico
# 38470                              Médico staff cirúrgico
# 199774                             Médico staff cirúrgico
#
#            Outro (especifique)2  \
# 177426                      NaN
# 161950  medico anestesiologista
# 208063                      NaN
# 38470                       NaN
# 199774                      NaN
#
#        5. Em sua função, você tipicamente tem contato ou interação direta com os pacientes?    \
# 177426  a. SIM, tipicamente tenho contato ou interação...
# 161950  a. SIM, tipicamente tenho contato ou interação...
# 208063                                                NaN
# 38470   a. SIM, tipicamente tenho contato ou interação...
# 199774  a. SIM, tipicamente tenho contato ou interação...
#
#        5. Em sua função, você tipicamente tem contato ou interação direta com os pacientes?  3  \
# 177426                                                NaN
# 161950                                                NaN
# 208063  b. NÃO, tipicamente não tenho contato ou inter...
# 38470                                                 NaN
# 199774                                                NaN
#
#        6. Há quanto tempo você trabalha em sua profissão ou especialização atual?    \
# 177426                                      b. 1 a 5 anos
# 161950                                      b. 1 a 5 anos
# 208063                                     c. 6 a 10 anos
# 38470                                      c. 6 a 10 anos
# 199774                                    d. 11 a 15 anos
#
#        SEÇÃO I: Seus Comentários  Por favor, sinta-se à vontade para fazer quaisquer comentários sobre a segurança do paciente, erros ou  notificação de eventos em seu hospital.    \
# 177426  Não é certo colocar o paciente em sala sem ane...
# 161950  Cirurgião não aguarda o anestesista liberar pa...
# 208063                                                  .
# 38470   Existe sim uma preocupação com a segurança do ...
# 199774                                                NaN
#
#        5. Em sua função, você tipicamente tem contato ou interação direta com os pacientes?  32  \
# 177426  a. SIM, tipicamente tenho contato ou interação...
# 161950  a. SIM, tipicamente tenho contato ou interação...
# 208063  b. NÃO, tipicamente não tenho contato ou inter...
# 38470   a. SIM, tipicamente tenho contato ou interação...
# 199774  a. SIM, tipicamente tenho contato ou interação...
#
#        Regional Estado Acreditação
# 177426       SE     SP     Qmentum
# 161950       SE     SP       ONA 3
# 208063       SE     SP           0
# 38470        NE     SE     Qmentum
# 199774       SE     SP     Qmentum
#
# [5 rows x 61 columns]

# %%
df = df.drop('Outro (especifique)', axis=1)
df = df.drop('Outro (especifique)2', axis=1)
df = df.drop('SEÇÃO I: Seus Comentários  Por favor, sinta-se à vontade para fazer quaisquer comentários sobre a segurança do paciente, erros ou  notificação de eventos em seu hospital.  ', axis=1)

df = df.drop(df[df['22. Meu supervisor/gerente ignora problemas recorrentes na segurança do paciente'] == 'Algumas vezes'].index)
df = df.reset_index(drop=True)

df['5. Em sua função, você tipicamente tem contato ou interação direta com os pacientes?  '].fillna('b. NÃO, tipicamente não tenho contato ou interação direta com os pacientes.', inplace = True)
df = df.drop('5. Em sua função, você tipicamente tem contato ou interação direta com os pacientes?  3', axis=1)
df = df.drop('5. Em sua função, você tipicamente tem contato ou interação direta com os pacientes?  32', axis=1)

coluna = '5. Em sua função, você tipicamente tem contato ou interação direta com os pacientes?  '
counts = df[coluna].value_counts()
percentages = df[coluna].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
res = pd.DataFrame({'counts': counts, 'percentage': percentages})
print(res)

df_backup = df.copy()

#df = df.drop('', axis=1)
# Out:
#                                                     counts percentage
# a. SIM, tipicamente tenho contato ou interação ...    3608      97.4%
# b. NÃO, tipicamente não tenho contato ou intera...      97       2.6%

# %%
coluna = ' SEÇÃO H: 4. Qual é o seu cargo neste hospital? Marque UMA resposta que melhor descreva a sua função.'
print(df[coluna].value_counts(),'\n')

df["Cargo"] = np.nan
df["Cargo"][df[coluna] == 'Enfermeiro Supervisor/Coordenador/Gerente'] = "Enfermeiro"
df["Cargo"][df[coluna] == 'Enfermeiro(a) Assistencial'] = "Enfermeiro"
df["Cargo"][df[coluna] == 'Técnico de Enfermagem'] = "Tecnico de Enfermeiro"
df["Cargo"][df[coluna] == 'Farmacêutico'] = "Outros"
df["Cargo"][df[coluna] == 'Ouvidor'] = "Outros"
df["Cargo"][df[coluna] == 'Assistente/Atendente/Secretária da Unidade'] = "Outros"
df["Cargo"][df[coluna] == 'Copeiro'] = "Outros"
df["Cargo"][df[coluna] == 'Administrativo (Recepções)'] = "Outros"
df["Cargo"][df[coluna] == 'Psicologo'] = "Outros"
df["Cargo"][df[coluna] == 'Médico plantonista terapia intensiva'] = "Médico"
df["Cargo"][df[coluna] == 'Radiologia)'] = "Outros"
df["Cargo"][df[coluna] == 'Fisioterapeuta'] = "Outros"
df["Cargo"][df[coluna] == 'Nutricionista'] = "Outros"
df["Cargo"][df[coluna] == 'Técnico de exames (ex.: Eletrocardiograma Laboratório'] = "Outros"
df["Cargo"][df[coluna] == 'Auxiliar de Enfermagem'] = "Tecnico Enfermeiro"
df["Cargo"][df[coluna] == 'Médico staff cirúrgico'] = "Médico"
df["Cargo"][df[coluna] == 'Médico Gerente'] = "Médico"
df["Cargo"][df[coluna] == 'Médico staff clínico'] = "Médico"
df["Cargo"][df[coluna] == 'Concierge'] = "Outros"
df["Cargo"][df[coluna] == 'Farmacêutico Supervisor/Coordenador/Gerente'] = "Outros"
df["Cargo"][df[coluna] == 'Médico assistente -  clínico'] = "Médico"
df["Cargo"][df[coluna] == 'Assistente social'] = "Outros"
df["Cargo"][df[coluna] == 'Nutricionista Supervisor/Coordenador/Gerente'] = "Outros"
df["Cargo"][df[coluna] == 'Médico plantonista emergência'] = "Médico"
df["Cargo"][df[coluna] == 'Médico assistente - cirúrgico'] = "Médico"
df["Cargo"][df[coluna] == 'Médico SADT'] = "Médico"
df["Cargo"][df[coluna] == 'Fonoaudiólogo'] = "Outros"
df["Cargo"][df[coluna] == 'Terapeuta Ocupacional'] = "Outros"

df = df.drop(' SEÇÃO H: 4. Qual é o seu cargo neste hospital? Marque UMA resposta que melhor descreva a sua função.', axis=1)

print(df['Cargo'].value_counts(), '\n')
# Out:
# Médico staff cirúrgico                          1412
# Médico assistente - cirúrgico                    626
# Médico staff clínico                             267
# Médico Gerente                                   107
# Médico assistente -  clínico                     101
# Médico plantonista emergência                     32
# Médico SADT                                       21
# Técnico de Enfermagem                             15
# Ouvidor                                           13
# Enfermeiro(a) Assistencial                        11
# Administrativo (Recepções)                         8
# Médico plantonista terapia intensiva               6
# Assistente/Atendente/Secretária da Unidade         5
# Enfermeiro Supervisor/Coordenador/Gerente          3
# Auxiliar de Enfermagem                             3
# Fisioterapeuta                                     2
# Nutricionista Supervisor/Coordenador/Gerente       1
# Radiologia)                                        1
# Copeiro                                            1
# Concierge                                          1
# Nutricionista                                      1
# Name:  SEÇÃO H: 4. Qual é o seu cargo neste hospital? Marque UMA resposta que melhor descreva a sua função., dtype: int64
#
# Médico                   2572
# Outros                     33
# Tecnico de Enfermeiro      15
# Enfermeiro                 14
# Tecnico Enfermeiro          3
# Name: Cargo, dtype: int64

# %%
sum(pd.isnull(df['Acreditação']))
# Out:
# 0

# %%
df['Acreditação'][df['Acreditação'] == 'Não possui'] = 0
df['Acreditação'][df['Acreditação'] == 0] = 0

df['Acreditação2'] = df['Acreditação']

df['Acreditação'][df['Acreditação'] == 'ONA 2'] = 'ONA'
df['Acreditação'][df['Acreditação'] == 'ONA 3'] = 'ONA'
df['Acreditação'][df['Acreditação'] == 'ONA 1'] = 'ONA'
df['Acreditação'][df['Acreditação'] == 'Qmentum'] = 'Qmentum'
df['Acreditação'][df['Acreditação'] == 'JCI'] = 'JCI'

df['Acreditação2'][df['Acreditação2'] == 'N1'] = 'ONA 1'
df['Acreditação'][df['Acreditação'] == 'N1'] = 'ONA'

print(df['Acreditação'].value_counts(),'\n')
print(df['Acreditação2'].value_counts(),'\n')

###################################################3#
df['acreditacao'] = 0
df['acreditacao'][df['Acreditação'] != 0] = 1
print(df['acreditacao'].value_counts())
# Out:
# ONA        1557
# JCI         896
# Qmentum     717
# 0           535
# Name: Acreditação, dtype: int64
#
# ONA 3      1050
# JCI         896
# Qmentum     717
# 0           535
# ONA 2       420
# ONA 1        87
# Name: Acreditação2, dtype: int64
#
# 1    3170
# 0     535
# Name: acreditacao, dtype: int64

# %%
df.describe(include='all').T
# Out:
#                                                      count unique  \
# Ano                                                 3705.0    NaN
# Unidade                                               3705     68
# Qual é sua principal área ou unidade neste hosp...    3705      1
# 1. As pessoas se apoiam umas às outras nesta un...    3685      3
# 2. Temos pessoas suficientes para lidar com o v...    3679      3
# 3. Quando há muito trabalho a ser feito e rapid...    3674      3
# 4. Nesta unidade, as pessoas se tratam com resp...    3679      3
# 5. Os funcionários desta unidade trabalham mais...    3676      3
# 6. Estamos ativamente buscando melhorias para a...    3681      3
# 7. Utilizamos mais funcionários temporários do ...    3676      3
# 8. Os funcionários sentem que seus erros são us...    3672      3
# 9. Erros que ocorreram levaram a mudanças posit...    3675      3
# 10. É apenas por acaso que erros mais sérios nã...    3675      3
# 11. Quando uma área nesta unidade fica muito mo...    3681      3
# 12. Quando um evento é notificado, sentimos que...    3680      3
# 13. Quando fazemos mudanças para melhorar a seg...    3675      3
# 14. Trabalhamos “em modo de crise”, tentando fa...    3680      3
# 15. A segurança do paciente nunca é sacrificada...    3677      3
# 16. Os funcionários se preocupam que seus erros...    3672      3
# 17. Temos problemas com a segurança do paciente...    3678      3
# 18. Nossos procedimentos e sistemas são bons pa...    3676      3
# 19. Meu supervisor/gerente elogia quando vê um ...    3673      3
# 20. Meu supervisor/gerente considera seriamente...    3676      3
# 21. Sempre que a pressão aumenta, meu superviso...    3669      3
# 22. Meu supervisor/gerente ignora problemas rec...    3675      3
# 23. Recebemos feedback das mudanças implementad...    3673      3
# 24. Os funcionários falam voluntariamente se vê...    3676      3
# 25. Somos informados sobre os erros que acontec...    3673      3
# 26. Os funcionários sentem-se à vontade para qu...    3668      3
# 27. Nesta unidade, discutimos maneiras de imped...    3669      3
# 28. Os funcionários têm receio de perguntar qua...    3669      3
# 29. Quando acontece um erro, mas ele é identifi...    3678      3
# 30. Quando acontece um erro, mas que não tem po...    3673      3
# 31. Quando acontece um erro que poderia prejudi...    3671      3
# Por favor, dê uma nota geral para a segurança d...    3673      5
# 32. A administração do hospital cria um ambient...    3679      3
# 33. As unidades hospitalares não se coordenam b...    3678      3
# 34. Coisas "escapam por entre os dedos” quando ...    3677      3
# 35. Existe uma boa cooperação entre as unidades...    3679      3
# 36. Importantes informações sobre a assistência...    3679      3
# 37. Muitas vezes é desagradável trabalhar unida...    3671      3
# 38. Os problemas com frequência ocorrem na troc...    3671      3
# 39. As ações da administração do hospital mostr...    3675      3
# 40. A administração do hospital parece se inter...    3676      3
# 41. As unidades do hospital trabalham bem junta...    3671      3
# 42. As mudanças de turno são problemáticas para...    3671      3
# SEÇÃO G: Número de Eventos Notificados  Nos últ...    3675      6
# SEÇÃO H: 1. Há quanto tempo você trabalha neste...    3672      6
# SEÇÃO H: 2.Há quanto tempo você trabalha nesta ...    3677      6
# SEÇÃO H: 3.Tipicamente, quantas horas por seman...    3677      6
# 5. Em sua função, você tipicamente tem contato ...    3705      2
# 6. Há quanto tempo você trabalha em sua profiss...    3673      6
# Regional                                              3705      5
# Estado                                                3705     13
# Acreditação                                           3705      4
# Cargo                                                 2637      5
# Acreditação2                                          3705      6
# acreditacao                                         3705.0    NaN
#
#                                                                                                   top  \
# Ano                                                                                               NaN
# Unidade                                                                                         Itaim
# Qual é sua principal área ou unidade neste hosp...                                     Anestesiologia
# 1. As pessoas se apoiam umas às outras nesta un...                     Concordo + Concordo totalmente
# 2. Temos pessoas suficientes para lidar com o v...                     Concordo + Concordo totalmente
# 3. Quando há muito trabalho a ser feito e rapid...                     Concordo + Concordo totalmente
# 4. Nesta unidade, as pessoas se tratam com resp...                     Concordo + Concordo totalmente
# 5. Os funcionários desta unidade trabalham mais...                     Discordo + Discordo totalmente
# 6. Estamos ativamente buscando melhorias para a...                     Concordo + Concordo totalmente
# 7. Utilizamos mais funcionários temporários do ...                     Discordo + Discordo totalmente
# 8. Os funcionários sentem que seus erros são us...                     Discordo + Discordo totalmente
# 9. Erros que ocorreram levaram a mudanças posit...                     Concordo + Concordo totalmente
# 10. É apenas por acaso que erros mais sérios nã...                     Discordo + Discordo totalmente
# 11. Quando uma área nesta unidade fica muito mo...                     Concordo + Concordo totalmente
# 12. Quando um evento é notificado, sentimos que...                     Discordo + Discordo totalmente
# 13. Quando fazemos mudanças para melhorar a seg...                     Concordo + Concordo totalmente
# 14. Trabalhamos “em modo de crise”, tentando fa...                     Discordo + Discordo totalmente
# 15. A segurança do paciente nunca é sacrificada...                     Concordo + Concordo totalmente
# 16. Os funcionários se preocupam que seus erros...                     Concordo + Concordo totalmente
# 17. Temos problemas com a segurança do paciente...                     Discordo + Discordo totalmente
# 18. Nossos procedimentos e sistemas são bons pa...                     Concordo + Concordo totalmente
# 19. Meu supervisor/gerente elogia quando vê um ...                     Concordo + Concordo totalmente
# 20. Meu supervisor/gerente considera seriamente...                     Concordo + Concordo totalmente
# 21. Sempre que a pressão aumenta, meu superviso...                     Discordo + Discordo totalmente
# 22. Meu supervisor/gerente ignora problemas rec...                     Discordo + Discordo totalmente
# 23. Recebemos feedback das mudanças implementad...                          Maioria do tempo + Sempre
# 24. Os funcionários falam voluntariamente se vê...                          Maioria do tempo + Sempre
# 25. Somos informados sobre os erros que acontec...                          Maioria do tempo + Sempre
# 26. Os funcionários sentem-se à vontade para qu...                                      Algumas vezes
# 27. Nesta unidade, discutimos maneiras de imped...                          Maioria do tempo + Sempre
# 28. Os funcionários têm receio de perguntar qua...                                  Nunca + Raramente
# 29. Quando acontece um erro, mas ele é identifi...                          Maioria do tempo + Sempre
# 30. Quando acontece um erro, mas que não tem po...                          Maioria do tempo + Sempre
# 31. Quando acontece um erro que poderia prejudi...                          Maioria do tempo + Sempre
# Por favor, dê uma nota geral para a segurança d...                                          Muito boa
# 32. A administração do hospital cria um ambient...                     Concordo + Concordo totalmente
# 33. As unidades hospitalares não se coordenam b...                     Discordo + Discordo totalmente
# 34. Coisas "escapam por entre os dedos” quando ...                     Discordo + Discordo totalmente
# 35. Existe uma boa cooperação entre as unidades...                     Concordo + Concordo totalmente
# 36. Importantes informações sobre a assistência...                     Discordo + Discordo totalmente
# 37. Muitas vezes é desagradável trabalhar unida...                     Discordo + Discordo totalmente
# 38. Os problemas com frequência ocorrem na troc...                     Discordo + Discordo totalmente
# 39. As ações da administração do hospital mostr...                     Concordo + Concordo totalmente
# 40. A administração do hospital parece se inter...                     Discordo + Discordo totalmente
# 41. As unidades do hospital trabalham bem junta...                     Concordo + Concordo totalmente
# 42. As mudanças de turno são problemáticas para...                     Discordo + Discordo totalmente
# SEÇÃO G: Número de Eventos Notificados  Nos últ...                 a. Nenhuma notificações de eventos
# SEÇÃO H: 1. Há quanto tempo você trabalha neste...                                         1 a 5 anos
# SEÇÃO H: 2.Há quanto tempo você trabalha nesta ...                                         1 a 5 anos
# SEÇÃO H: 3.Tipicamente, quantas horas por seman...                        b. 20 a 39 horas por semana
# 5. Em sua função, você tipicamente tem contato ...  a. SIM, tipicamente tenho contato ou interação...
# 6. Há quanto tempo você trabalha em sua profiss...                                      b. 1 a 5 anos
# Regional                                                                                           SE
# Estado                                                                                             SP
# Acreditação                                                                                       ONA
# Cargo                                                                                          Médico
# Acreditação2                                                                                    ONA 3
# acreditacao                                                                                       NaN
#
#                                                     freq         mean  \
# Ano                                                  NaN  2019.585965
# Unidade                                              433          NaN
# Qual é sua principal área ou unidade neste hosp...  3705          NaN
# 1. As pessoas se apoiam umas às outras nesta un...  2980          NaN
# 2. Temos pessoas suficientes para lidar com o v...  2125          NaN
# 3. Quando há muito trabalho a ser feito e rapid...  2926          NaN
# 4. Nesta unidade, as pessoas se tratam com resp...  3180          NaN
# 5. Os funcionários desta unidade trabalham mais...  1555          NaN
# 6. Estamos ativamente buscando melhorias para a...  3092          NaN
# 7. Utilizamos mais funcionários temporários do ...  1874          NaN
# 8. Os funcionários sentem que seus erros são us...  1675          NaN
# 9. Erros que ocorreram levaram a mudanças posit...  2736          NaN
# 10. É apenas por acaso que erros mais sérios nã...  2557          NaN
# 11. Quando uma área nesta unidade fica muito mo...  1916          NaN
# 12. Quando um evento é notificado, sentimos que...  1861          NaN
# 13. Quando fazemos mudanças para melhorar a seg...  2653          NaN
# 14. Trabalhamos “em modo de crise”, tentando fa...  2083          NaN
# 15. A segurança do paciente nunca é sacrificada...  1982          NaN
# 16. Os funcionários se preocupam que seus erros...  1688          NaN
# 17. Temos problemas com a segurança do paciente...  2329          NaN
# 18. Nossos procedimentos e sistemas são bons pa...  2645          NaN
# 19. Meu supervisor/gerente elogia quando vê um ...  2681          NaN
# 20. Meu supervisor/gerente considera seriamente...  2823          NaN
# 21. Sempre que a pressão aumenta, meu superviso...  2404          NaN
# 22. Meu supervisor/gerente ignora problemas rec...  3125          NaN
# 23. Recebemos feedback das mudanças implementad...  1945          NaN
# 24. Os funcionários falam voluntariamente se vê...  2024          NaN
# 25. Somos informados sobre os erros que acontec...  1949          NaN
# 26. Os funcionários sentem-se à vontade para qu...  1364          NaN
# 27. Nesta unidade, discutimos maneiras de imped...  2440          NaN
# 28. Os funcionários têm receio de perguntar qua...  1705          NaN
# 29. Quando acontece um erro, mas ele é identifi...  2256          NaN
# 30. Quando acontece um erro, mas que não tem po...  2133          NaN
# 31. Quando acontece um erro que poderia prejudi...  2378          NaN
# Por favor, dê uma nota geral para a segurança d...  1413          NaN
# 32. A administração do hospital cria um ambient...  2757          NaN
# 33. As unidades hospitalares não se coordenam b...  1806          NaN
# 34. Coisas "escapam por entre os dedos” quando ...  1601          NaN
# 35. Existe uma boa cooperação entre as unidades...  2099          NaN
# 36. Importantes informações sobre a assistência...  1843          NaN
# 37. Muitas vezes é desagradável trabalhar unida...  1713          NaN
# 38. Os problemas com frequência ocorrem na troc...  1576          NaN
# 39. As ações da administração do hospital mostr...  2527          NaN
# 40. A administração do hospital parece se inter...  2162          NaN
# 41. As unidades do hospital trabalham bem junta...  2394          NaN
# 42. As mudanças de turno são problemáticas para...  1783          NaN
# SEÇÃO G: Número de Eventos Notificados  Nos últ...   903          NaN
# SEÇÃO H: 1. Há quanto tempo você trabalha neste...  1481          NaN
# SEÇÃO H: 2.Há quanto tempo você trabalha nesta ...  1463          NaN
# SEÇÃO H: 3.Tipicamente, quantas horas por seman...  1272          NaN
# 5. Em sua função, você tipicamente tem contato ...  3608          NaN
# 6. Há quanto tempo você trabalha em sua profiss...  1297          NaN
# Regional                                            2794          NaN
# Estado                                              2468          NaN
# Acreditação                                         1557          NaN
# Cargo                                               2572          NaN
# Acreditação2                                        1050          NaN
# acreditacao                                          NaN     0.855601
#
#                                                          std     min     25%  \
# Ano                                                  2.16982  2014.0  2018.0
# Unidade                                                  NaN     NaN     NaN
# Qual é sua principal área ou unidade neste hosp...       NaN     NaN     NaN
# 1. As pessoas se apoiam umas às outras nesta un...       NaN     NaN     NaN
# 2. Temos pessoas suficientes para lidar com o v...       NaN     NaN     NaN
# 3. Quando há muito trabalho a ser feito e rapid...       NaN     NaN     NaN
# 4. Nesta unidade, as pessoas se tratam com resp...       NaN     NaN     NaN
# 5. Os funcionários desta unidade trabalham mais...       NaN     NaN     NaN
# 6. Estamos ativamente buscando melhorias para a...       NaN     NaN     NaN
# 7. Utilizamos mais funcionários temporários do ...       NaN     NaN     NaN
# 8. Os funcionários sentem que seus erros são us...       NaN     NaN     NaN
# 9. Erros que ocorreram levaram a mudanças posit...       NaN     NaN     NaN
# 10. É apenas por acaso que erros mais sérios nã...       NaN     NaN     NaN
# 11. Quando uma área nesta unidade fica muito mo...       NaN     NaN     NaN
# 12. Quando um evento é notificado, sentimos que...       NaN     NaN     NaN
# 13. Quando fazemos mudanças para melhorar a seg...       NaN     NaN     NaN
# 14. Trabalhamos “em modo de crise”, tentando fa...       NaN     NaN     NaN
# 15. A segurança do paciente nunca é sacrificada...       NaN     NaN     NaN
# 16. Os funcionários se preocupam que seus erros...       NaN     NaN     NaN
# 17. Temos problemas com a segurança do paciente...       NaN     NaN     NaN
# 18. Nossos procedimentos e sistemas são bons pa...       NaN     NaN     NaN
# 19. Meu supervisor/gerente elogia quando vê um ...       NaN     NaN     NaN
# 20. Meu supervisor/gerente considera seriamente...       NaN     NaN     NaN
# 21. Sempre que a pressão aumenta, meu superviso...       NaN     NaN     NaN
# 22. Meu supervisor/gerente ignora problemas rec...       NaN     NaN     NaN
# 23. Recebemos feedback das mudanças implementad...       NaN     NaN     NaN
# 24. Os funcionários falam voluntariamente se vê...       NaN     NaN     NaN
# 25. Somos informados sobre os erros que acontec...       NaN     NaN     NaN
# 26. Os funcionários sentem-se à vontade para qu...       NaN     NaN     NaN
# 27. Nesta unidade, discutimos maneiras de imped...       NaN     NaN     NaN
# 28. Os funcionários têm receio de perguntar qua...       NaN     NaN     NaN
# 29. Quando acontece um erro, mas ele é identifi...       NaN     NaN     NaN
# 30. Quando acontece um erro, mas que não tem po...       NaN     NaN     NaN
# 31. Quando acontece um erro que poderia prejudi...       NaN     NaN     NaN
# Por favor, dê uma nota geral para a segurança d...       NaN     NaN     NaN
# 32. A administração do hospital cria um ambient...       NaN     NaN     NaN
# 33. As unidades hospitalares não se coordenam b...       NaN     NaN     NaN
# 34. Coisas "escapam por entre os dedos” quando ...       NaN     NaN     NaN
# 35. Existe uma boa cooperação entre as unidades...       NaN     NaN     NaN
# 36. Importantes informações sobre a assistência...       NaN     NaN     NaN
# 37. Muitas vezes é desagradável trabalhar unida...       NaN     NaN     NaN
# 38. Os problemas com frequência ocorrem na troc...       NaN     NaN     NaN
# 39. As ações da administração do hospital mostr...       NaN     NaN     NaN
# 40. A administração do hospital parece se inter...       NaN     NaN     NaN
# 41. As unidades do hospital trabalham bem junta...       NaN     NaN     NaN
# 42. As mudanças de turno são problemáticas para...       NaN     NaN     NaN
# SEÇÃO G: Número de Eventos Notificados  Nos últ...       NaN     NaN     NaN
# SEÇÃO H: 1. Há quanto tempo você trabalha neste...       NaN     NaN     NaN
# SEÇÃO H: 2.Há quanto tempo você trabalha nesta ...       NaN     NaN     NaN
# SEÇÃO H: 3.Tipicamente, quantas horas por seman...       NaN     NaN     NaN
# 5. Em sua função, você tipicamente tem contato ...       NaN     NaN     NaN
# 6. Há quanto tempo você trabalha em sua profiss...       NaN     NaN     NaN
# Regional                                                 NaN     NaN     NaN
# Estado                                                   NaN     NaN     NaN
# Acreditação                                              NaN     NaN     NaN
# Cargo                                                    NaN     NaN     NaN
# Acreditação2                                             NaN     NaN     NaN
# acreditacao                                         0.351542     0.0     1.0
#
#                                                        50%     75%     max
# Ano                                                 2020.0  2021.0  2022.0
# Unidade                                                NaN     NaN     NaN
# Qual é sua principal área ou unidade neste hosp...     NaN     NaN     NaN
# 1. As pessoas se apoiam umas às outras nesta un...     NaN     NaN     NaN
# 2. Temos pessoas suficientes para lidar com o v...     NaN     NaN     NaN
# 3. Quando há muito trabalho a ser feito e rapid...     NaN     NaN     NaN
# 4. Nesta unidade, as pessoas se tratam com resp...     NaN     NaN     NaN
# 5. Os funcionários desta unidade trabalham mais...     NaN     NaN     NaN
# 6. Estamos ativamente buscando melhorias para a...     NaN     NaN     NaN
# 7. Utilizamos mais funcionários temporários do ...     NaN     NaN     NaN
# 8. Os funcionários sentem que seus erros são us...     NaN     NaN     NaN
# 9. Erros que ocorreram levaram a mudanças posit...     NaN     NaN     NaN
# 10. É apenas por acaso que erros mais sérios nã...     NaN     NaN     NaN
# 11. Quando uma área nesta unidade fica muito mo...     NaN     NaN     NaN
# 12. Quando um evento é notificado, sentimos que...     NaN     NaN     NaN
# 13. Quando fazemos mudanças para melhorar a seg...     NaN     NaN     NaN
# 14. Trabalhamos “em modo de crise”, tentando fa...     NaN     NaN     NaN
# 15. A segurança do paciente nunca é sacrificada...     NaN     NaN     NaN
# 16. Os funcionários se preocupam que seus erros...     NaN     NaN     NaN
# 17. Temos problemas com a segurança do paciente...     NaN     NaN     NaN
# 18. Nossos procedimentos e sistemas são bons pa...     NaN     NaN     NaN
# 19. Meu supervisor/gerente elogia quando vê um ...     NaN     NaN     NaN
# 20. Meu supervisor/gerente considera seriamente...     NaN     NaN     NaN
# 21. Sempre que a pressão aumenta, meu superviso...     NaN     NaN     NaN
# 22. Meu supervisor/gerente ignora problemas rec...     NaN     NaN     NaN
# 23. Recebemos feedback das mudanças implementad...     NaN     NaN     NaN
# 24. Os funcionários falam voluntariamente se vê...     NaN     NaN     NaN
# 25. Somos informados sobre os erros que acontec...     NaN     NaN     NaN
# 26. Os funcionários sentem-se à vontade para qu...     NaN     NaN     NaN
# 27. Nesta unidade, discutimos maneiras de imped...     NaN     NaN     NaN
# 28. Os funcionários têm receio de perguntar qua...     NaN     NaN     NaN
# 29. Quando acontece um erro, mas ele é identifi...     NaN     NaN     NaN
# 30. Quando acontece um erro, mas que não tem po...     NaN     NaN     NaN
# 31. Quando acontece um erro que poderia prejudi...     NaN     NaN     NaN
# Por favor, dê uma nota geral para a segurança d...     NaN     NaN     NaN
# 32. A administração do hospital cria um ambient...     NaN     NaN     NaN
# 33. As unidades hospitalares não se coordenam b...     NaN     NaN     NaN
# 34. Coisas "escapam por entre os dedos” quando ...     NaN     NaN     NaN
# 35. Existe uma boa cooperação entre as unidades...     NaN     NaN     NaN
# 36. Importantes informações sobre a assistência...     NaN     NaN     NaN
# 37. Muitas vezes é desagradável trabalhar unida...     NaN     NaN     NaN
# 38. Os problemas com frequência ocorrem na troc...     NaN     NaN     NaN
# 39. As ações da administração do hospital mostr...     NaN     NaN     NaN
# 40. A administração do hospital parece se inter...     NaN     NaN     NaN
# 41. As unidades do hospital trabalham bem junta...     NaN     NaN     NaN
# 42. As mudanças de turno são problemáticas para...     NaN     NaN     NaN
# SEÇÃO G: Número de Eventos Notificados  Nos últ...     NaN     NaN     NaN
# SEÇÃO H: 1. Há quanto tempo você trabalha neste...     NaN     NaN     NaN
# SEÇÃO H: 2.Há quanto tempo você trabalha nesta ...     NaN     NaN     NaN
# SEÇÃO H: 3.Tipicamente, quantas horas por seman...     NaN     NaN     NaN
# 5. Em sua função, você tipicamente tem contato ...     NaN     NaN     NaN
# 6. Há quanto tempo você trabalha em sua profiss...     NaN     NaN     NaN
# Regional                                               NaN     NaN     NaN
# Estado                                                 NaN     NaN     NaN
# Acreditação                                            NaN     NaN     NaN
# Cargo                                                  NaN     NaN     NaN
# Acreditação2                                           NaN     NaN     NaN
# acreditacao                                            1.0     1.0     1.0

# %%
for coluna in df.columns:
    print(coluna, '='*25)
    counts = df[coluna].value_counts()
    percentages = df[coluna].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'

    # Usando o método 'agg' para juntar contagens e porcentagens em uma mesma DataFrame
    res = pd.DataFrame({'counts': counts, 'percentage': percentages})
    print(res)
    print('\n')
# Out:
# Ano =========================
#       counts percentage
# 2022     865      23.3%
# 2021     716      19.3%
# 2020     617      16.7%
# 2018     419      11.3%
# 2019     417      11.3%
# 2017     257       6.9%
# 2016     209       5.6%
# 2015     112       3.0%
# 2014      93       2.5%
#
#
# Unidade =========================
#                counts percentage
# Itaim             433      11.7%
# Anália Franco     346       9.3%
# Morumbi           317       8.6%
# Osasco            276       7.4%
# Villa Lobos       238       6.4%
# ...               ...        ...
# Santa Emília        2       0.1%
# 5 de outubro        1       0.0%
# Quinta D'Or         1       0.0%
# Copa Star           1       0.0%
# HNSN Epitácio       1       0.0%
#
# [68 rows x 2 columns]
#
#
# Qual é sua principal área ou unidade neste hospital? =========================
#                 counts percentage
# Anestesiologia    3705     100.0%
#
#
# 1. As pessoas se apoiam umas às outras nesta unidade =========================
#                                 counts percentage
# Concordo + Concordo totalmente    2980      80.9%
# Nem um nem outro                   435      11.8%
# Discordo + Discordo totalmente     270       7.3%
#
#
# 2. Temos pessoas suficientes para lidar com o volume de trabalho =========================
#                                 counts percentage
# Concordo + Concordo totalmente    2125      57.8%
# Discordo + Discordo totalmente    1072      29.1%
# Nem um nem outro                   482      13.1%
#
#
# 3. Quando há muito trabalho a ser feito e rapidamente, trabalhamos juntos em equipe para realizar a tarefa =========================
#                                 counts percentage
# Concordo + Concordo totalmente    2926      79.6%
# Nem um nem outro                   431      11.7%
# Discordo + Discordo totalmente     317       8.6%
#
#
# 4. Nesta unidade, as pessoas se tratam com respeito =========================
#                                 counts percentage
# Concordo + Concordo totalmente    3180      86.4%
# Nem um nem outro                   323       8.8%
# Discordo + Discordo totalmente     176       4.8%
#
#
# 5. Os funcionários desta unidade trabalham mais horas do que o recomendado no atendimento a pacientes =========================
#                                 counts percentage
# Discordo + Discordo totalmente    1555      42.3%
# Nem um nem outro                  1062      28.9%
# Concordo + Concordo totalmente    1059      28.8%
#
#
# 6. Estamos ativamente buscando melhorias para a segurança do paciente =========================
#                                 counts percentage
# Concordo + Concordo totalmente    3092      84.0%
# Nem um nem outro                   371      10.1%
# Discordo + Discordo totalmente     218       5.9%
#
#
# 7. Utilizamos mais funcionários temporários do que o recomendado no atendimento a paciente =========================
#                                 counts percentage
# Discordo + Discordo totalmente    1874      51.0%
# Nem um nem outro                  1323      36.0%
# Concordo + Concordo totalmente     479      13.0%
#
#
# 8. Os funcionários sentem que seus erros são usados contra eles =========================
#                                 counts percentage
# Discordo + Discordo totalmente    1675      45.6%
# Concordo + Concordo totalmente    1006      27.4%
# Nem um nem outro                   991      27.0%
#
#
# 9. Erros que ocorreram levaram a mudanças positivas nesta unidade =========================
#                                 counts percentage
# Concordo + Concordo totalmente    2736      74.4%
# Nem um nem outro                   639      17.4%
# Discordo + Discordo totalmente     300       8.2%
#
#
# 10. É apenas por acaso que erros mais sérios não acontecem por aqui =========================
#                                 counts percentage
# Discordo + Discordo totalmente    2557      69.6%
# Nem um nem outro                   578      15.7%
# Concordo + Concordo totalmente     540      14.7%
#
#
# 11. Quando uma área nesta unidade fica muito movimentada, as demais ajudam =========================
#                                 counts percentage
# Concordo + Concordo totalmente    1916      52.1%
# Nem um nem outro                   941      25.6%
# Discordo + Discordo totalmente     824      22.4%
#
#
# 12. Quando um evento é notificado, sentimos que o foco se concentra no indivíduo, e não no problema =========================
#                                 counts percentage
# Discordo + Discordo totalmente    1861      50.6%
# Concordo + Concordo totalmente     916      24.9%
# Nem um nem outro                   903      24.5%
#
#
# 13. Quando fazemos mudanças para melhorar a segurança do paciente, nós avaliamos sua efetividade =========================
#                                 counts percentage
# Concordo + Concordo totalmente    2653      72.2%
# Nem um nem outro                   689      18.7%
# Discordo + Discordo totalmente     333       9.1%
#
#
# 14. Trabalhamos “em modo de crise”, tentando fazer coisas demais, rápido demais =========================
#                                 counts percentage
# Discordo + Discordo totalmente    2083      56.6%
# Concordo + Concordo totalmente     843      22.9%
# Nem um nem outro                   754      20.5%
#
#
# 15. A segurança do paciente nunca é sacrificada em prol de se trabalhar mais =========================
#                                 counts percentage
# Concordo + Concordo totalmente    1982      53.9%
# Discordo + Discordo totalmente    1010      27.5%
# Nem um nem outro                   685      18.6%
#
#
# 16. Os funcionários se preocupam que seus erros sejam registrados em seu arquivo funcional =========================
#                                 counts percentage
# Concordo + Concordo totalmente    1688      46.0%
# Nem um nem outro                  1097      29.9%
# Discordo + Discordo totalmente     887      24.2%
#
#
# 17. Temos problemas com a segurança do paciente nesta unidade =========================
#                                 counts percentage
# Discordo + Discordo totalmente    2329      63.3%
# Concordo + Concordo totalmente     790      21.5%
# Nem um nem outro                   559      15.2%
#
#
# 18. Nossos procedimentos e sistemas são bons para impedir que os erros aconteçam =========================
#                                 counts percentage
# Concordo + Concordo totalmente    2645      72.0%
# Nem um nem outro                   574      15.6%
# Discordo + Discordo totalmente     457      12.4%
#
#
# 19. Meu supervisor/gerente elogia quando vê um trabalho feito de acordo com os procedimentos estabelecidos para a segurança do paciente. =========================
#                                 counts percentage
# Concordo + Concordo totalmente    2681      73.0%
# Nem um nem outro                   605      16.5%
# Discordo + Discordo totalmente     387      10.5%
#
#
# 20. Meu supervisor/gerente considera seriamente as sugestões dos funcionários para melhorar a segurança do paciente =========================
#                                 counts percentage
# Concordo + Concordo totalmente    2823      76.8%
# Nem um nem outro                   552      15.0%
# Discordo + Discordo totalmente     301       8.2%
#
#
# 21. Sempre que a pressão aumenta, meu supervisor/gerente quer que trabalhemos mais rápido, mesmo que isto signifique tomar atalhos =========================
#                                 counts percentage
# Discordo + Discordo totalmente    2404      65.5%
# Nem um nem outro                   670      18.3%
# Concordo + Concordo totalmente     595      16.2%
#
#
# 22. Meu supervisor/gerente ignora problemas recorrentes na segurança do paciente =========================
#                                 counts percentage
# Discordo + Discordo totalmente    3125      85.0%
# Nem um nem outro                   362       9.9%
# Concordo + Concordo totalmente     188       5.1%
#
#
# 23. Recebemos feedback das mudanças implementadas com base nos eventos notificados =========================
#                            counts percentage
# Maioria do tempo + Sempre    1945      53.0%
# Algumas vezes                1167      31.8%
# Nunca + Raramente             561      15.3%
#
#
# 24. Os funcionários falam voluntariamente se vêem algo que possa afetar negativamente o atendimento aos pacientes =========================
#                            counts percentage
# Maioria do tempo + Sempre    2024      55.1%
# Algumas vezes                1206      32.8%
# Nunca + Raramente             446      12.1%
#
#
# 25. Somos informados sobre os erros que acontecem nesta unidade =========================
#                            counts percentage
# Maioria do tempo + Sempre    1949      53.1%
# Algumas vezes                1215      33.1%
# Nunca + Raramente             509      13.9%
#
#
# 26. Os funcionários sentem-se à vontade para questionar decisões ou ações dos que têm mais autoridade =========================
#                            counts percentage
# Algumas vezes                1364      37.2%
# Maioria do tempo + Sempre    1359      37.1%
# Nunca + Raramente             945      25.8%
#
#
# 27. Nesta unidade, discutimos maneiras de impedir que os erros tornem a acontecer =========================
#                            counts percentage
# Maioria do tempo + Sempre    2440      66.5%
# Algumas vezes                 899      24.5%
# Nunca + Raramente             330       9.0%
#
#
# 28. Os funcionários têm receio de perguntar quando algo não parece certo =========================
#                            counts percentage
# Nunca + Raramente            1705      46.5%
# Algumas vezes                1455      39.7%
# Maioria do tempo + Sempre     509      13.9%
#
#
# 29. Quando acontece um erro, mas ele é identificado e corrigido antes de afetar o paciente, com que frequência é notificado? =========================
#                            counts percentage
# Maioria do tempo + Sempre    2256      61.3%
# Algumas vezes                 978      26.6%
# Nunca + Raramente             444      12.1%
#
#
# 30. Quando acontece um erro, mas que não tem potencial de dano ao paciente, com que frequência é notificado? =========================
#                            counts percentage
# Maioria do tempo + Sempre    2133      58.1%
# Algumas vezes                1049      28.6%
# Nunca + Raramente             491      13.4%
#
#
# 31. Quando acontece um erro que poderia prejudicar o paciente, mas isto não ocorreu, com que frequência é notificado? =========================
#                            counts percentage
# Maioria do tempo + Sempre    2378      64.8%
# Algumas vezes                 935      25.5%
# Nunca + Raramente             358       9.8%
#
#
# Por favor, dê uma nota geral para a segurança do paciente em sua área/unidade de trabalho hospitalar. =========================
#               counts percentage
# Muito boa       1413      38.5%
# Excelente       1066      29.0%
# Satisfatória     952      25.9%
# Ruim             198       5.4%
# Muito ruim        44       1.2%
#
#
# 32. A administração do hospital cria um ambiente de trabalho que promove a segurança do paciente =========================
#                                 counts percentage
# Concordo + Concordo totalmente    2757      74.9%
# Nem um nem outro                   587      16.0%
# Discordo + Discordo totalmente     335       9.1%
#
#
# 33. As unidades hospitalares não se coordenam bem entre si. =========================
#                                 counts percentage
# Discordo + Discordo totalmente    1806      49.1%
# Nem um nem outro                  1011      27.5%
# Concordo + Concordo totalmente     861      23.4%
#
#
# 34. Coisas "escapam por entre os dedos” quando os pacientes são transferidos de uma unidade para outra =========================
#                                 counts percentage
# Discordo + Discordo totalmente    1601      43.5%
# Nem um nem outro                  1099      29.9%
# Concordo + Concordo totalmente     977      26.6%
#
#
# 35. Existe uma boa cooperação entre as unidades hospitalares que precisam trabalhar juntas =========================
#                                 counts percentage
# Concordo + Concordo totalmente    2099      57.1%
# Nem um nem outro                  1093      29.7%
# Discordo + Discordo totalmente     487      13.2%
#
#
# 36. Importantes informações sobre a assistência se perdem durante as mudanças de turno =========================
#                                 counts percentage
# Discordo + Discordo totalmente    1843      50.1%
# Nem um nem outro                   935      25.4%
# Concordo + Concordo totalmente     901      24.5%
#
#
# 37. Muitas vezes é desagradável trabalhar unidades com funcionários de outras unidades do hospital =========================
#                                 counts percentage
# Discordo + Discordo totalmente    1713      46.7%
# Nem um nem outro                  1172      31.9%
# Concordo + Concordo totalmente     786      21.4%
#
#
# 38. Os problemas com frequência ocorrem na troca de informações entre as unidades do hospital =========================
#                                 counts percentage
# Discordo + Discordo totalmente    1576      42.9%
# Nem um nem outro                  1183      32.2%
# Concordo + Concordo totalmente     912      24.8%
#
#
# 39. As ações da administração do hospital mostram que a segurança do paciente é uma prioridade máxima =========================
#                                 counts percentage
# Concordo + Concordo totalmente    2527      68.8%
# Nem um nem outro                   728      19.8%
# Discordo + Discordo totalmente     420      11.4%
#
#
# 40. A administração do hospital parece se interessar pela segurança do paciente apenas quando acontece um evento adverso =========================
#                                 counts percentage
# Discordo + Discordo totalmente    2162      58.8%
# Concordo + Concordo totalmente     865      23.5%
# Nem um nem outro                   649      17.7%
#
#
# 41. As unidades do hospital trabalham bem juntas para prestar o melhor atendimento aos pacientes =========================
#                                 counts percentage
# Concordo + Concordo totalmente    2394      65.2%
# Nem um nem outro                   889      24.2%
# Discordo + Discordo totalmente     388      10.6%
#
#
# 42. As mudanças de turno são problemáticas para os pacientes deste Hospital =========================
#                                 counts percentage
# Discordo + Discordo totalmente    1783      48.6%
# Nem um nem outro                  1008      27.5%
# Concordo + Concordo totalmente     880      24.0%
#
#
# SEÇÃO G: Número de Eventos Notificados  Nos últimos 12 meses, quantas notificações de evento você preencheu e enviou? =========================
#                                        counts percentage
# a. Nenhuma notificações de eventos        903      24.6%
# b. 1 a 2 notificações de eventos          776      21.1%
# c. 3 a 5 notificações de eventos          637      17.3%
# f. 21 notificações de eventos ou mais     545      14.8%
# d. 6 a 10 notificações de eventos         460      12.5%
# e. 11 a 20 notificações de eventos        354       9.6%
#
#
# SEÇÃO H: 1. Há quanto tempo você trabalha neste hospital? =========================
#                  counts percentage
# 1 a 5 anos         1481      40.3%
# menos de 1 ano      886      24.1%
# 6 a 10 anos         559      15.2%
# 11 a 15 anos        323       8.8%
# 21 anos ou mais     227       6.2%
# 16 a 20 anos        196       5.3%
#
#
# SEÇÃO H: 2.Há quanto tempo você trabalha nesta área/unidade de trabalho hospitalar? =========================
#                  counts percentage
# 1 a 5 anos         1463      39.8%
# menos de 1 ano      814      22.1%
# 6 a 10 anos         579      15.7%
# 11 a 15 anos        350       9.5%
# 21 anos ou mais     247       6.7%
# 16 a 20 anos        224       6.1%
#
#
# SEÇÃO H: 3.Tipicamente, quantas horas por semana você trabalha neste hospital?   =========================
#                                  counts percentage
# b. 20 a 39 horas por semana        1272      34.6%
# a. Menos de 20 horas por semana    1127      30.6%
# c. 40 a 59 horas por semana         778      21.2%
# d. 60 a 79 horas por semana         386      10.5%
# e. 80 a 99 horas por semana          96       2.6%
# f. 100 horas por semana ou mais      18       0.5%
#
#
# 5. Em sua função, você tipicamente tem contato ou interação direta com os pacientes?   =========================
#                                                     counts percentage
# a. SIM, tipicamente tenho contato ou interação ...    3608      97.4%
# b. NÃO, tipicamente não tenho contato ou intera...      97       2.6%
#
#
# 6. Há quanto tempo você trabalha em sua profissão ou especialização atual?   =========================
#                     counts percentage
# b. 1 a 5 anos         1297      35.3%
# c. 6 a 10 anos         716      19.5%
# f. 21 anos ou mais     555      15.1%
# d. 11 a 15 anos        456      12.4%
# e. 16 a 20 anos        372      10.1%
# a. Menos de 1 ano      277       7.5%
#
#
# Regional =========================
#      counts percentage
# SE     2794      75.4%
# NE      445      12.0%
# CO      441      11.9%
# SUL      21       0.6%
# N         4       0.1%
#
#
# Estado =========================
#      counts percentage
# SP     2468      66.6%
# DF      415      11.2%
# RJ      326       8.8%
# BA      221       6.0%
# SE      116       3.1%
# PE       59       1.6%
# MS       26       0.7%
# PR       21       0.6%
# MA       19       0.5%
# AL       19       0.5%
# PB        7       0.2%
# CE        4       0.1%
# PA        4       0.1%
#
#
# Acreditação =========================
#          counts percentage
# ONA        1557      42.0%
# JCI         896      24.2%
# Qmentum     717      19.4%
# 0           535      14.4%
#
#
# Cargo =========================
#                        counts percentage
# Médico                   2572      97.5%
# Outros                     33       1.3%
# Tecnico de Enfermeiro      15       0.6%
# Enfermeiro                 14       0.5%
# Tecnico Enfermeiro          3       0.1%
#
#
# Acreditação2 =========================
#          counts percentage
# ONA 3      1050      28.3%
# JCI         896      24.2%
# Qmentum     717      19.4%
# 0           535      14.4%
# ONA 2       420      11.3%
# ONA 1        87       2.3%
#
#
# acreditacao =========================
#    counts percentage
# 1    3170      85.6%
# 0     535      14.4%

# %%
df_alianca = df[(df['Unidade'] == 'Aliança') & (df['Ano'] == 2022)]

for coluna in df_alianca.columns:
    print(coluna, '='*25)
    counts = df_alianca[coluna].value_counts()
    percentages = df_alianca[coluna].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'

    # Usando o método 'agg' para juntar contagens e porcentagens em uma mesma DataFrame
    res = pd.DataFrame({'counts': counts, 'percentage': percentages})
    print(res)
    print('\n')
# Out:
# Ano =========================
#       counts percentage
# 2022      32     100.0%
#
#
# Unidade =========================
#          counts percentage
# Aliança      32     100.0%
#
#
# Qual é sua principal área ou unidade neste hospital? =========================
#                 counts percentage
# Anestesiologia      32     100.0%
#
#
# 1. As pessoas se apoiam umas às outras nesta unidade =========================
#                                 counts percentage
# Concordo + Concordo totalmente      32     100.0%
#
#
# 2. Temos pessoas suficientes para lidar com o volume de trabalho =========================
#                                 counts percentage
# Concordo + Concordo totalmente      28      87.5%
# Nem um nem outro                     3       9.4%
# Discordo + Discordo totalmente       1       3.1%
#
#
# 3. Quando há muito trabalho a ser feito e rapidamente, trabalhamos juntos em equipe para realizar a tarefa =========================
#                                 counts percentage
# Concordo + Concordo totalmente      30      93.8%
# Nem um nem outro                     1       3.1%
# Discordo + Discordo totalmente       1       3.1%
#
#
# 4. Nesta unidade, as pessoas se tratam com respeito =========================
#                                 counts percentage
# Concordo + Concordo totalmente      32     100.0%
#
#
# 5. Os funcionários desta unidade trabalham mais horas do que o recomendado no atendimento a pacientes =========================
#                                 counts percentage
# Discordo + Discordo totalmente      13      40.6%
# Nem um nem outro                    10      31.2%
# Concordo + Concordo totalmente       9      28.1%
#
#
# 6. Estamos ativamente buscando melhorias para a segurança do paciente =========================
#                                 counts percentage
# Concordo + Concordo totalmente      32     100.0%
#
#
# 7. Utilizamos mais funcionários temporários do que o recomendado no atendimento a paciente =========================
#                                 counts percentage
# Discordo + Discordo totalmente      19      59.4%
# Nem um nem outro                     9      28.1%
# Concordo + Concordo totalmente       4      12.5%
#
#
# 8. Os funcionários sentem que seus erros são usados contra eles =========================
#                                 counts percentage
# Discordo + Discordo totalmente      18      56.2%
# Nem um nem outro                     9      28.1%
# Concordo + Concordo totalmente       5      15.6%
#
#
# 9. Erros que ocorreram levaram a mudanças positivas nesta unidade =========================
#                                 counts percentage
# Concordo + Concordo totalmente      31      96.9%
# Nem um nem outro                     1       3.1%
#
#
# 10. É apenas por acaso que erros mais sérios não acontecem por aqui =========================
#                                 counts percentage
# Discordo + Discordo totalmente      27      84.4%
# Concordo + Concordo totalmente       3       9.4%
# Nem um nem outro                     2       6.2%
#
#
# 11. Quando uma área nesta unidade fica muito movimentada, as demais ajudam =========================
#                                 counts percentage
# Concordo + Concordo totalmente      25      78.1%
# Nem um nem outro                     4      12.5%
# Discordo + Discordo totalmente       3       9.4%
#
#
# 12. Quando um evento é notificado, sentimos que o foco se concentra no indivíduo, e não no problema =========================
#                                 counts percentage
# Discordo + Discordo totalmente      23      71.9%
# Concordo + Concordo totalmente       5      15.6%
# Nem um nem outro                     4      12.5%
#
#
# 13. Quando fazemos mudanças para melhorar a segurança do paciente, nós avaliamos sua efetividade =========================
#                                 counts percentage
# Concordo + Concordo totalmente      30      93.8%
# Discordo + Discordo totalmente       1       3.1%
# Nem um nem outro                     1       3.1%
#
#
# 14. Trabalhamos “em modo de crise”, tentando fazer coisas demais, rápido demais =========================
#                                 counts percentage
# Discordo + Discordo totalmente      24      77.4%
# Nem um nem outro                     5      16.1%
# Concordo + Concordo totalmente       2       6.5%
#
#
# 15. A segurança do paciente nunca é sacrificada em prol de se trabalhar mais =========================
#                                 counts percentage
# Concordo + Concordo totalmente      25      78.1%
# Discordo + Discordo totalmente       6      18.8%
# Nem um nem outro                     1       3.1%
#
#
# 16. Os funcionários se preocupam que seus erros sejam registrados em seu arquivo funcional =========================
#                                 counts percentage
# Concordo + Concordo totalmente      14      43.8%
# Nem um nem outro                    10      31.2%
# Discordo + Discordo totalmente       8      25.0%
#
#
# 17. Temos problemas com a segurança do paciente nesta unidade =========================
#                                 counts percentage
# Discordo + Discordo totalmente      31      96.9%
# Nem um nem outro                     1       3.1%
#
#
# 18. Nossos procedimentos e sistemas são bons para impedir que os erros aconteçam =========================
#                                 counts percentage
# Concordo + Concordo totalmente      32     100.0%
#
#
# 19. Meu supervisor/gerente elogia quando vê um trabalho feito de acordo com os procedimentos estabelecidos para a segurança do paciente. =========================
#                                 counts percentage
# Concordo + Concordo totalmente      28      87.5%
# Nem um nem outro                     2       6.2%
# Discordo + Discordo totalmente       2       6.2%
#
#
# 20. Meu supervisor/gerente considera seriamente as sugestões dos funcionários para melhorar a segurança do paciente =========================
#                                 counts percentage
# Concordo + Concordo totalmente      28      87.5%
# Nem um nem outro                     3       9.4%
# Discordo + Discordo totalmente       1       3.1%
#
#
# 21. Sempre que a pressão aumenta, meu supervisor/gerente quer que trabalhemos mais rápido, mesmo que isto signifique tomar atalhos =========================
#                                 counts percentage
# Discordo + Discordo totalmente      24      75.0%
# Nem um nem outro                     7      21.9%
# Concordo + Concordo totalmente       1       3.1%
#
#
# 22. Meu supervisor/gerente ignora problemas recorrentes na segurança do paciente =========================
#                                 counts percentage
# Discordo + Discordo totalmente      31      96.9%
# Nem um nem outro                     1       3.1%
#
#
# 23. Recebemos feedback das mudanças implementadas com base nos eventos notificados =========================
#                            counts percentage
# Maioria do tempo + Sempre      24      75.0%
# Algumas vezes                   8      25.0%
#
#
# 24. Os funcionários falam voluntariamente se vêem algo que possa afetar negativamente o atendimento aos pacientes =========================
#                            counts percentage
# Maioria do tempo + Sempre      25      78.1%
# Algumas vezes                   6      18.8%
# Nunca + Raramente               1       3.1%
#
#
# 25. Somos informados sobre os erros que acontecem nesta unidade =========================
#                            counts percentage
# Maioria do tempo + Sempre      25      78.1%
# Algumas vezes                   6      18.8%
# Nunca + Raramente               1       3.1%
#
#
# 26. Os funcionários sentem-se à vontade para questionar decisões ou ações dos que têm mais autoridade =========================
#                            counts percentage
# Maioria do tempo + Sempre      18      56.2%
# Algumas vezes                  12      37.5%
# Nunca + Raramente               2       6.2%
#
#
# 27. Nesta unidade, discutimos maneiras de impedir que os erros tornem a acontecer =========================
#                            counts percentage
# Maioria do tempo + Sempre      29      90.6%
# Algumas vezes                   3       9.4%
#
#
# 28. Os funcionários têm receio de perguntar quando algo não parece certo =========================
#                            counts percentage
# Nunca + Raramente              22      68.8%
# Algumas vezes                   7      21.9%
# Maioria do tempo + Sempre       3       9.4%
#
#
# 29. Quando acontece um erro, mas ele é identificado e corrigido antes de afetar o paciente, com que frequência é notificado? =========================
#                            counts percentage
# Maioria do tempo + Sempre      26      81.2%
# Algumas vezes                   5      15.6%
# Nunca + Raramente               1       3.1%
#
#
# 30. Quando acontece um erro, mas que não tem potencial de dano ao paciente, com que frequência é notificado? =========================
#                            counts percentage
# Maioria do tempo + Sempre      22      68.8%
# Algumas vezes                   8      25.0%
# Nunca + Raramente               2       6.2%
#
#
# 31. Quando acontece um erro que poderia prejudicar o paciente, mas isto não ocorreu, com que frequência é notificado? =========================
#                            counts percentage
# Maioria do tempo + Sempre      26      81.2%
# Algumas vezes                   4      12.5%
# Nunca + Raramente               2       6.2%
#
#
# Por favor, dê uma nota geral para a segurança do paciente em sua área/unidade de trabalho hospitalar. =========================
#            counts percentage
# Excelente      22      68.8%
# Muito boa      10      31.2%
#
#
# 32. A administração do hospital cria um ambiente de trabalho que promove a segurança do paciente =========================
#                                 counts percentage
# Concordo + Concordo totalmente      29      90.6%
# Nem um nem outro                     2       6.2%
# Discordo + Discordo totalmente       1       3.1%
#
#
# 33. As unidades hospitalares não se coordenam bem entre si. =========================
#                                 counts percentage
# Discordo + Discordo totalmente      19      59.4%
# Nem um nem outro                     9      28.1%
# Concordo + Concordo totalmente       4      12.5%
#
#
# 34. Coisas "escapam por entre os dedos” quando os pacientes são transferidos de uma unidade para outra =========================
#                                 counts percentage
# Discordo + Discordo totalmente      21      65.6%
# Nem um nem outro                     7      21.9%
# Concordo + Concordo totalmente       4      12.5%
#
#
# 35. Existe uma boa cooperação entre as unidades hospitalares que precisam trabalhar juntas =========================
#                                 counts percentage
# Concordo + Concordo totalmente      24      75.0%
# Nem um nem outro                     5      15.6%
# Discordo + Discordo totalmente       3       9.4%
#
#
# 36. Importantes informações sobre a assistência se perdem durante as mudanças de turno =========================
#                                 counts percentage
# Discordo + Discordo totalmente      23      71.9%
# Concordo + Concordo totalmente       5      15.6%
# Nem um nem outro                     4      12.5%
#
#
# 37. Muitas vezes é desagradável trabalhar unidades com funcionários de outras unidades do hospital =========================
#                                 counts percentage
# Discordo + Discordo totalmente      20      62.5%
# Nem um nem outro                     8      25.0%
# Concordo + Concordo totalmente       4      12.5%
#
#
# 38. Os problemas com frequência ocorrem na troca de informações entre as unidades do hospital =========================
#                                 counts percentage
# Discordo + Discordo totalmente      17      53.1%
# Nem um nem outro                     9      28.1%
# Concordo + Concordo totalmente       6      18.8%
#
#
# 39. As ações da administração do hospital mostram que a segurança do paciente é uma prioridade máxima =========================
#                                 counts percentage
# Concordo + Concordo totalmente      28      87.5%
# Nem um nem outro                     3       9.4%
# Discordo + Discordo totalmente       1       3.1%
#
#
# 40. A administração do hospital parece se interessar pela segurança do paciente apenas quando acontece um evento adverso =========================
#                                 counts percentage
# Discordo + Discordo totalmente      25      78.1%
# Nem um nem outro                     4      12.5%
# Concordo + Concordo totalmente       3       9.4%
#
#
# 41. As unidades do hospital trabalham bem juntas para prestar o melhor atendimento aos pacientes =========================
#                                 counts percentage
# Concordo + Concordo totalmente      27      87.1%
# Nem um nem outro                     4      12.9%
#
#
# 42. As mudanças de turno são problemáticas para os pacientes deste Hospital =========================
#                                 counts percentage
# Discordo + Discordo totalmente      23      71.9%
# Nem um nem outro                     6      18.8%
# Concordo + Concordo totalmente       3       9.4%
#
#
# SEÇÃO G: Número de Eventos Notificados  Nos últimos 12 meses, quantas notificações de evento você preencheu e enviou? =========================
#                                     counts percentage
# a. Nenhuma notificações de eventos      21      65.6%
# b. 1 a 2 notificações de eventos         9      28.1%
# c. 3 a 5 notificações de eventos         2       6.2%
#
#
# SEÇÃO H: 1. Há quanto tempo você trabalha neste hospital? =========================
#                  counts percentage
# 21 anos ou mais       8      25.0%
# 16 a 20 anos          7      21.9%
# 11 a 15 anos          6      18.8%
# 6 a 10 anos           5      15.6%
# menos de 1 ano        4      12.5%
# 1 a 5 anos            2       6.2%
#
#
# SEÇÃO H: 2.Há quanto tempo você trabalha nesta área/unidade de trabalho hospitalar? =========================
#                  counts percentage
# 21 anos ou mais       8      25.0%
# 16 a 20 anos          7      21.9%
# 11 a 15 anos          6      18.8%
# 6 a 10 anos           5      15.6%
# menos de 1 ano        4      12.5%
# 1 a 5 anos            2       6.2%
#
#
# SEÇÃO H: 3.Tipicamente, quantas horas por semana você trabalha neste hospital?   =========================
#                                  counts percentage
# b. 20 a 39 horas por semana          15      46.9%
# a. Menos de 20 horas por semana      10      31.2%
# c. 40 a 59 horas por semana           6      18.8%
# d. 60 a 79 horas por semana           1       3.1%
#
#
# 5. Em sua função, você tipicamente tem contato ou interação direta com os pacientes?   =========================
#                                                     counts percentage
# a. SIM, tipicamente tenho contato ou interação ...      32     100.0%
#
#
# 6. Há quanto tempo você trabalha em sua profissão ou especialização atual?   =========================
#                     counts percentage
# f. 21 anos ou mais      13      40.6%
# d. 11 a 15 anos          7      21.9%
# c. 6 a 10 anos           5      15.6%
# e. 16 a 20 anos          4      12.5%
# b. 1 a 5 anos            3       9.4%
#
#
# Regional =========================
#     counts percentage
# NE      32     100.0%
#
#
# Estado =========================
#     counts percentage
# BA      32     100.0%
#
#
# Acreditação =========================
#          counts percentage
# Qmentum      32     100.0%
#
#
# Cargo =========================
#         counts percentage
# Médico      25     100.0%
#
#
# Acreditação2 =========================
#          counts percentage
# Qmentum      32     100.0%
#
#
# acreditacao =========================
#    counts percentage
# 1      32     100.0%

# %%
lista1 = []
lista2 = []

for coluna in df.columns:
    if 'Nunca + Raramente' in df[coluna].unique():
        lista1.append(coluna)
        #print('alteração 1:', '"' + coluna + '"')
        
        #df[coluna][df[coluna] == 'Maioria do tempo + Sempre'] = 1
        #df[coluna][df[coluna] == 'Algumas vezes'] = 0
        #df[coluna][df[coluna] == 'Nunca + Raramente'] = 0
        #print("\n")
    elif 'Nem um nem outro' in df[coluna].unique():
        lista2.append(coluna)
        #print('alteração 2:', '"' + coluna + '"')
        
        #df[coluna][df[coluna] == 'Concordo + Concordo totalmente'] = 0
        #df[coluna][df[coluna] == 'Nem um nem outro'] = 0
        #df[coluna][df[coluna] == 'Discordo + Discordo totalmente'] = 1
        #print("\n")
# Out:
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_12624\3991450850.py:5: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if 'Nunca + Raramente' in df[coluna].unique():
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_12624\3991450850.py:13: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   elif 'Nem um nem outro' in df[coluna].unique():

# %%
lista1
# Out:
# ['23. Recebemos feedback das mudanças implementadas com base nos eventos notificados',
#  '24. Os funcionários falam voluntariamente se vêem algo que possa afetar negativamente o atendimento aos pacientes',
#  '25. Somos informados sobre os erros que acontecem nesta unidade',
#  '26. Os funcionários sentem-se à vontade para questionar decisões ou ações dos que têm mais autoridade',
#  '27. Nesta unidade, discutimos maneiras de impedir que os erros tornem a acontecer',
#  '28. Os funcionários têm receio de perguntar quando algo não parece certo',
#  '29. Quando acontece um erro, mas ele é identificado e corrigido antes de afetar o paciente, com que frequência é notificado?',
#  '30. Quando acontece um erro, mas que não tem potencial de dano ao paciente, com que frequência é notificado?',
#  '31. Quando acontece um erro que poderia prejudicar o paciente, mas isto não ocorreu, com que frequência é notificado?']

# %%
lista1.remove('28. Os funcionários têm receio de perguntar quando algo não parece certo')
for coluna in lista1:
    df[coluna][df[coluna] == 'Maioria do tempo + Sempre'] = 1
    df[coluna][df[coluna] == 'Algumas vezes'] = 0
    df[coluna][df[coluna] == 'Nunca + Raramente'] = 0

coluna = '28. Os funcionários têm receio de perguntar quando algo não parece certo'
df[coluna][df[coluna] == 'Maioria do tempo + Sempre'] = 0
df[coluna][df[coluna] == 'Algumas vezes'] = 0
df[coluna][df[coluna] == 'Nunca + Raramente'] = 1

print('Ok - Continue')
# Out:
# Ok - Continue

# %%
lista2
# Out:
# ['1. As pessoas se apoiam umas às outras nesta unidade',
#  '2. Temos pessoas suficientes para lidar com o volume de trabalho',
#  '3. Quando há muito trabalho a ser feito e rapidamente, trabalhamos juntos em equipe para realizar a tarefa',
#  '4. Nesta unidade, as pessoas se tratam com respeito',
#  '5. Os funcionários desta unidade trabalham mais horas do que o recomendado no atendimento a pacientes',
#  '6. Estamos ativamente buscando melhorias para a segurança do paciente',
#  '7. Utilizamos mais funcionários temporários do que o recomendado no atendimento a paciente',
#  '8. Os funcionários sentem que seus erros são usados contra eles',
#  '9. Erros que ocorreram levaram a mudanças positivas nesta unidade',
#  '10. É apenas por acaso que erros mais sérios não acontecem por aqui',
#  '11. Quando uma área nesta unidade fica muito movimentada, as demais ajudam',
#  '12. Quando um evento é notificado, sentimos que o foco se concentra no indivíduo, e não no problema',
#  '13. Quando fazemos mudanças para melhorar a segurança do paciente, nós avaliamos sua efetividade',
#  '14. Trabalhamos “em modo de crise”, tentando fazer coisas demais, rápido demais',
#  '15. A segurança do paciente nunca é sacrificada em prol de se trabalhar mais',
#  '16. Os funcionários se preocupam que seus erros sejam registrados em seu arquivo funcional',
#  '17. Temos problemas com a segurança do paciente nesta unidade',
#  '18. Nossos procedimentos e sistemas são bons para impedir que os erros aconteçam',
#  '19. Meu supervisor/gerente elogia quando vê um trabalho feito de acordo com os procedimentos estabelecidos para a segurança do paciente.',
#  '20. Meu supervisor/gerente considera seriamente as sugestões dos funcionários para melhorar a segurança do paciente',
#  '21. Sempre que a pressão aumenta, meu supervisor/gerente quer que trabalhemos mais rápido, mesmo que isto signifique tomar atalhos',
#  '22. Meu supervisor/gerente ignora problemas recorrentes na segurança do paciente',
#  '32. A administração do hospital cria um ambiente de trabalho que promove a segurança do paciente',
#  '33. As unidades hospitalares não se coordenam bem entre si.',
#  '34. Coisas "escapam por entre os dedos” quando os pacientes são transferidos de uma unidade para outra',
#  '35. Existe uma boa cooperação entre as unidades hospitalares que precisam trabalhar juntas',
#  '36. Importantes informações sobre a assistência se perdem durante as mudanças de turno',
#  '37. Muitas vezes é desagradável trabalhar unidades com funcionários de outras unidades do hospital',
#  '38. Os problemas com frequência ocorrem na troca de informações entre as unidades do hospital',
#  '39. As ações da administração do hospital mostram que a segurança do paciente é uma prioridade máxima',
#  '40. A administração do hospital parece se interessar pela segurança do paciente apenas quando acontece um evento adverso',
#  '41. As unidades do hospital trabalham bem juntas para prestar o melhor atendimento aos pacientes',
#  '42. As mudanças de turno são problemáticas para os pacientes deste Hospital']

# %%
lista_a2 = ['1. As pessoas se apoiam umas às outras nesta unidade',
            '2. Temos pessoas suficientes para lidar com o volume de trabalho',
            '3. Quando há muito trabalho a ser feito e rapidamente, trabalhamos juntos em equipe para realizar a tarefa',
            '4. Nesta unidade, as pessoas se tratam com respeito',
            '6. Estamos ativamente buscando melhorias para a segurança do paciente',
            '9. Erros que ocorreram levaram a mudanças positivas nesta unidade',
            '11. Quando uma área nesta unidade fica muito movimentada, as demais ajudam',
            '13. Quando fazemos mudanças para melhorar a segurança do paciente, nós avaliamos sua efetividade',
            '15. A segurança do paciente nunca é sacrificada em prol de se trabalhar mais',
            '18. Nossos procedimentos e sistemas são bons para impedir que os erros aconteçam',
            '19. Meu supervisor/gerente elogia quando vê um trabalho feito de acordo com os procedimentos estabelecidos para a segurança do paciente.',
            '20. Meu supervisor/gerente considera seriamente as sugestões dos funcionários para melhorar a segurança do paciente',
            '32. A administração do hospital cria um ambiente de trabalho que promove a segurança do paciente',
            '35. Existe uma boa cooperação entre as unidades hospitalares que precisam trabalhar juntas',
            '39. As ações da administração do hospital mostram que a segurança do paciente é uma prioridade máxima',
            '41. As unidades do hospital trabalham bem juntas para prestar o melhor atendimento aos pacientes']
for coluna in lista_a2:
    df[coluna][df[coluna] == 'Concordo + Concordo totalmente'] = 1
    df[coluna][df[coluna] == 'Nem um nem outro'] = 0
    df[coluna][df[coluna] == 'Discordo + Discordo totalmente'] = 0
    
print('Ok - Continue')
# Out:
# Ok - Continue

# %%
lista_a3 = ['5. Os funcionários desta unidade trabalham mais horas do que o recomendado no atendimento a pacientes',
            '7. Utilizamos mais funcionários temporários do que o recomendado no atendimento a paciente',
            '8. Os funcionários sentem que seus erros são usados contra eles',
            '10. É apenas por acaso que erros mais sérios não acontecem por aqui',
            '12. Quando um evento é notificado, sentimos que o foco se concentra no indivíduo, e não no problema',
            '14. Trabalhamos “em modo de crise”, tentando fazer coisas demais, rápido demais',
            '16. Os funcionários se preocupam que seus erros sejam registrados em seu arquivo funcional',
            '17. Temos problemas com a segurança do paciente nesta unidade',
            '21. Sempre que a pressão aumenta, meu supervisor/gerente quer que trabalhemos mais rápido, mesmo que isto signifique tomar atalhos',
            '22. Meu supervisor/gerente ignora problemas recorrentes na segurança do paciente',
            '33. As unidades hospitalares não se coordenam bem entre si.',
            '34. Coisas "escapam por entre os dedos” quando os pacientes são transferidos de uma unidade para outra',
            '36. Importantes informações sobre a assistência se perdem durante as mudanças de turno',
            '37. Muitas vezes é desagradável trabalhar unidades com funcionários de outras unidades do hospital',
            '38. Os problemas com frequência ocorrem na troca de informações entre as unidades do hospital',
            '40. A administração do hospital parece se interessar pela segurança do paciente apenas quando acontece um evento adverso',
            '42. As mudanças de turno são problemáticas para os pacientes deste Hospital']

for coluna in lista_a3:
    df[coluna][df[coluna] == 'Concordo + Concordo totalmente'] = 0
    df[coluna][df[coluna] == 'Nem um nem outro'] = 0
    df[coluna][df[coluna] == 'Discordo + Discordo totalmente'] = 1
    
print('Ok - Continue')
# Out:
# Ok - Continue

# %%
for coluna in df.columns:
    print(coluna, '='*25)
    counts = df[coluna].value_counts()
    percentages = df[coluna].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
    res = pd.DataFrame({'counts': counts, 'percentage': percentages})
    print(res)
    print('\n')
# Out:
# Ano =========================
#       counts percentage
# 2022     865      23.3%
# 2021     716      19.3%
# 2020     617      16.7%
# 2018     419      11.3%
# 2019     417      11.3%
# 2017     257       6.9%
# 2016     209       5.6%
# 2015     112       3.0%
# 2014      93       2.5%
#
#
# Unidade =========================
#                counts percentage
# Itaim             433      11.7%
# Anália Franco     346       9.3%
# Morumbi           317       8.6%
# Osasco            276       7.4%
# Villa Lobos       238       6.4%
# ...               ...        ...
# Santa Emília        2       0.1%
# 5 de outubro        1       0.0%
# Quinta D'Or         1       0.0%
# Copa Star           1       0.0%
# HNSN Epitácio       1       0.0%
#
# [68 rows x 2 columns]
#
#
# Qual é sua principal área ou unidade neste hospital? =========================
#                 counts percentage
# Anestesiologia    3705     100.0%
#
#
# 1. As pessoas se apoiam umas às outras nesta unidade =========================
#    counts percentage
# 1    2980      80.9%
# 0     705      19.1%
#
#
# 2. Temos pessoas suficientes para lidar com o volume de trabalho =========================
#    counts percentage
# 1    2125      57.8%
# 0    1554      42.2%
#
#
# 3. Quando há muito trabalho a ser feito e rapidamente, trabalhamos juntos em equipe para realizar a tarefa =========================
#    counts percentage
# 1    2926      79.6%
# 0     748      20.4%
#
#
# 4. Nesta unidade, as pessoas se tratam com respeito =========================
#    counts percentage
# 1    3180      86.4%
# 0     499      13.6%
#
#
# 5. Os funcionários desta unidade trabalham mais horas do que o recomendado no atendimento a pacientes =========================
#    counts percentage
# 0    2121      57.7%
# 1    1555      42.3%
#
#
# 6. Estamos ativamente buscando melhorias para a segurança do paciente =========================
#    counts percentage
# 1    3092      84.0%
# 0     589      16.0%
#
#
# 7. Utilizamos mais funcionários temporários do que o recomendado no atendimento a paciente =========================
#    counts percentage
# 1    1874      51.0%
# 0    1802      49.0%
#
#
# 8. Os funcionários sentem que seus erros são usados contra eles =========================
#    counts percentage
# 0    1997      54.4%
# 1    1675      45.6%
#
#
# 9. Erros que ocorreram levaram a mudanças positivas nesta unidade =========================
#    counts percentage
# 1    2736      74.4%
# 0     939      25.6%
#
#
# 10. É apenas por acaso que erros mais sérios não acontecem por aqui =========================
#    counts percentage
# 1    2557      69.6%
# 0    1118      30.4%
#
#
# 11. Quando uma área nesta unidade fica muito movimentada, as demais ajudam =========================
#    counts percentage
# 1    1916      52.1%
# 0    1765      47.9%
#
#
# 12. Quando um evento é notificado, sentimos que o foco se concentra no indivíduo, e não no problema =========================
#    counts percentage
# 1    1861      50.6%
# 0    1819      49.4%
#
#
# 13. Quando fazemos mudanças para melhorar a segurança do paciente, nós avaliamos sua efetividade =========================
#    counts percentage
# 1    2653      72.2%
# 0    1022      27.8%
#
#
# 14. Trabalhamos “em modo de crise”, tentando fazer coisas demais, rápido demais =========================
#    counts percentage
# 1    2083      56.6%
# 0    1597      43.4%
#
#
# 15. A segurança do paciente nunca é sacrificada em prol de se trabalhar mais =========================
#    counts percentage
# 1    1982      53.9%
# 0    1695      46.1%
#
#
# 16. Os funcionários se preocupam que seus erros sejam registrados em seu arquivo funcional =========================
#    counts percentage
# 0    2785      75.8%
# 1     887      24.2%
#
#
# 17. Temos problemas com a segurança do paciente nesta unidade =========================
#    counts percentage
# 1    2329      63.3%
# 0    1349      36.7%
#
#
# 18. Nossos procedimentos e sistemas são bons para impedir que os erros aconteçam =========================
#    counts percentage
# 1    2645      72.0%
# 0    1031      28.0%
#
#
# 19. Meu supervisor/gerente elogia quando vê um trabalho feito de acordo com os procedimentos estabelecidos para a segurança do paciente. =========================
#    counts percentage
# 1    2681      73.0%
# 0     992      27.0%
#
#
# 20. Meu supervisor/gerente considera seriamente as sugestões dos funcionários para melhorar a segurança do paciente =========================
#    counts percentage
# 1    2823      76.8%
# 0     853      23.2%
#
#
# 21. Sempre que a pressão aumenta, meu supervisor/gerente quer que trabalhemos mais rápido, mesmo que isto signifique tomar atalhos =========================
#    counts percentage
# 1    2404      65.5%
# 0    1265      34.5%
#
#
# 22. Meu supervisor/gerente ignora problemas recorrentes na segurança do paciente =========================
#    counts percentage
# 1    3125      85.0%
# 0     550      15.0%
#
#
# 23. Recebemos feedback das mudanças implementadas com base nos eventos notificados =========================
#    counts percentage
# 1    1945      53.0%
# 0    1728      47.0%
#
#
# 24. Os funcionários falam voluntariamente se vêem algo que possa afetar negativamente o atendimento aos pacientes =========================
#    counts percentage
# 1    2024      55.1%
# 0    1652      44.9%
#
#
# 25. Somos informados sobre os erros que acontecem nesta unidade =========================
#    counts percentage
# 1    1949      53.1%
# 0    1724      46.9%
#
#
# 26. Os funcionários sentem-se à vontade para questionar decisões ou ações dos que têm mais autoridade =========================
#    counts percentage
# 0    2309      62.9%
# 1    1359      37.1%
#
#
# 27. Nesta unidade, discutimos maneiras de impedir que os erros tornem a acontecer =========================
#    counts percentage
# 1    2440      66.5%
# 0    1229      33.5%
#
#
# 28. Os funcionários têm receio de perguntar quando algo não parece certo =========================
#    counts percentage
# 0    1964      53.5%
# 1    1705      46.5%
#
#
# 29. Quando acontece um erro, mas ele é identificado e corrigido antes de afetar o paciente, com que frequência é notificado? =========================
#    counts percentage
# 1    2256      61.3%
# 0    1422      38.7%
#
#
# 30. Quando acontece um erro, mas que não tem potencial de dano ao paciente, com que frequência é notificado? =========================
#    counts percentage
# 1    2133      58.1%
# 0    1540      41.9%
#
#
# 31. Quando acontece um erro que poderia prejudicar o paciente, mas isto não ocorreu, com que frequência é notificado? =========================
#    counts percentage
# 1    2378      64.8%
# 0    1293      35.2%
#
#
# Por favor, dê uma nota geral para a segurança do paciente em sua área/unidade de trabalho hospitalar. =========================
#               counts percentage
# Muito boa       1413      38.5%
# Excelente       1066      29.0%
# Satisfatória     952      25.9%
# Ruim             198       5.4%
# Muito ruim        44       1.2%
#
#
# 32. A administração do hospital cria um ambiente de trabalho que promove a segurança do paciente =========================
#    counts percentage
# 1    2757      74.9%
# 0     922      25.1%
#
#
# 33. As unidades hospitalares não se coordenam bem entre si. =========================
#    counts percentage
# 0    1872      50.9%
# 1    1806      49.1%
#
#
# 34. Coisas "escapam por entre os dedos” quando os pacientes são transferidos de uma unidade para outra =========================
#    counts percentage
# 0    2076      56.5%
# 1    1601      43.5%
#
#
# 35. Existe uma boa cooperação entre as unidades hospitalares que precisam trabalhar juntas =========================
#    counts percentage
# 1    2099      57.1%
# 0    1580      42.9%
#
#
# 36. Importantes informações sobre a assistência se perdem durante as mudanças de turno =========================
#    counts percentage
# 1    1843      50.1%
# 0    1836      49.9%
#
#
# 37. Muitas vezes é desagradável trabalhar unidades com funcionários de outras unidades do hospital =========================
#    counts percentage
# 0    1958      53.3%
# 1    1713      46.7%
#
#
# 38. Os problemas com frequência ocorrem na troca de informações entre as unidades do hospital =========================
#    counts percentage
# 0    2095      57.1%
# 1    1576      42.9%
#
#
# 39. As ações da administração do hospital mostram que a segurança do paciente é uma prioridade máxima =========================
#    counts percentage
# 1    2527      68.8%
# 0    1148      31.2%
#
#
# 40. A administração do hospital parece se interessar pela segurança do paciente apenas quando acontece um evento adverso =========================
#    counts percentage
# 1    2162      58.8%
# 0    1514      41.2%
#
#
# 41. As unidades do hospital trabalham bem juntas para prestar o melhor atendimento aos pacientes =========================
#    counts percentage
# 1    2394      65.2%
# 0    1277      34.8%
#
#
# 42. As mudanças de turno são problemáticas para os pacientes deste Hospital =========================
#    counts percentage
# 0    1888      51.4%
# 1    1783      48.6%
#
#
# SEÇÃO G: Número de Eventos Notificados  Nos últimos 12 meses, quantas notificações de evento você preencheu e enviou? =========================
#                                        counts percentage
# a. Nenhuma notificações de eventos        903      24.6%
# b. 1 a 2 notificações de eventos          776      21.1%
# c. 3 a 5 notificações de eventos          637      17.3%
# f. 21 notificações de eventos ou mais     545      14.8%
# d. 6 a 10 notificações de eventos         460      12.5%
# e. 11 a 20 notificações de eventos        354       9.6%
#
#
# SEÇÃO H: 1. Há quanto tempo você trabalha neste hospital? =========================
#                  counts percentage
# 1 a 5 anos         1481      40.3%
# menos de 1 ano      886      24.1%
# 6 a 10 anos         559      15.2%
# 11 a 15 anos        323       8.8%
# 21 anos ou mais     227       6.2%
# 16 a 20 anos        196       5.3%
#
#
# SEÇÃO H: 2.Há quanto tempo você trabalha nesta área/unidade de trabalho hospitalar? =========================
#                  counts percentage
# 1 a 5 anos         1463      39.8%
# menos de 1 ano      814      22.1%
# 6 a 10 anos         579      15.7%
# 11 a 15 anos        350       9.5%
# 21 anos ou mais     247       6.7%
# 16 a 20 anos        224       6.1%
#
#
# SEÇÃO H: 3.Tipicamente, quantas horas por semana você trabalha neste hospital?   =========================
#                                  counts percentage
# b. 20 a 39 horas por semana        1272      34.6%
# a. Menos de 20 horas por semana    1127      30.6%
# c. 40 a 59 horas por semana         778      21.2%
# d. 60 a 79 horas por semana         386      10.5%
# e. 80 a 99 horas por semana          96       2.6%
# f. 100 horas por semana ou mais      18       0.5%
#
#
# 5. Em sua função, você tipicamente tem contato ou interação direta com os pacientes?   =========================
#                                                     counts percentage
# a. SIM, tipicamente tenho contato ou interação ...    3608      97.4%
# b. NÃO, tipicamente não tenho contato ou intera...      97       2.6%
#
#
# 6. Há quanto tempo você trabalha em sua profissão ou especialização atual?   =========================
#                     counts percentage
# b. 1 a 5 anos         1297      35.3%
# c. 6 a 10 anos         716      19.5%
# f. 21 anos ou mais     555      15.1%
# d. 11 a 15 anos        456      12.4%
# e. 16 a 20 anos        372      10.1%
# a. Menos de 1 ano      277       7.5%
#
#
# Regional =========================
#      counts percentage
# SE     2794      75.4%
# NE      445      12.0%
# CO      441      11.9%
# SUL      21       0.6%
# N         4       0.1%
#
#
# Estado =========================
#      counts percentage
# SP     2468      66.6%
# DF      415      11.2%
# RJ      326       8.8%
# BA      221       6.0%
# SE      116       3.1%
# PE       59       1.6%
# MS       26       0.7%
# PR       21       0.6%
# MA       19       0.5%
# AL       19       0.5%
# PB        7       0.2%
# CE        4       0.1%
# PA        4       0.1%
#
#
# Acreditação =========================
#          counts percentage
# ONA        1557      42.0%
# JCI         896      24.2%
# Qmentum     717      19.4%
# 0           535      14.4%
#
#
# Cargo =========================
#                        counts percentage
# Médico                   2572      97.5%
# Outros                     33       1.3%
# Tecnico de Enfermeiro      15       0.6%
# Enfermeiro                 14       0.5%
# Tecnico Enfermeiro          3       0.1%
#
#
# Acreditação2 =========================
#          counts percentage
# ONA 3      1050      28.3%
# JCI         896      24.2%
# Qmentum     717      19.4%
# 0           535      14.4%
# ONA 2       420      11.3%
# ONA 1        87       2.3%
#
#
# acreditacao =========================
#    counts percentage
# 1    3170      85.6%
# 0     535      14.4%

# %%
lista = ['1. As pessoas se apoiam umas às outras nesta unidade',
       '2. Temos pessoas suficientes para lidar com o volume de trabalho',
       '3. Quando há muito trabalho a ser feito e rapidamente, trabalhamos juntos em equipe para realizar a tarefa',
       '4. Nesta unidade, as pessoas se tratam com respeito',
       '5. Os funcionários desta unidade trabalham mais horas do que o recomendado no atendimento a pacientes',
       '6. Estamos ativamente buscando melhorias para a segurança do paciente',
       '7. Utilizamos mais funcionários temporários do que o recomendado no atendimento a paciente',
       '8. Os funcionários sentem que seus erros são usados contra eles',
       '9. Erros que ocorreram levaram a mudanças positivas nesta unidade',
       '10. É apenas por acaso que erros mais sérios não acontecem por aqui',
       '11. Quando uma área nesta unidade fica muito movimentada, as demais ajudam',
       '12. Quando um evento é notificado, sentimos que o foco se concentra no indivíduo, e não no problema',
       '13. Quando fazemos mudanças para melhorar a segurança do paciente, nós avaliamos sua efetividade',
       '14. Trabalhamos “em modo de crise”, tentando fazer coisas demais, rápido demais',
       '15. A segurança do paciente nunca é sacrificada em prol de se trabalhar mais',
       '16. Os funcionários se preocupam que seus erros sejam registrados em seu arquivo funcional',
       '17. Temos problemas com a segurança do paciente nesta unidade',
       '18. Nossos procedimentos e sistemas são bons para impedir que os erros aconteçam',
       '19. Meu supervisor/gerente elogia quando vê um trabalho feito de acordo com os procedimentos estabelecidos para a segurança do paciente.',
       '20. Meu supervisor/gerente considera seriamente as sugestões dos funcionários para melhorar a segurança do paciente',
       '21. Sempre que a pressão aumenta, meu supervisor/gerente quer que trabalhemos mais rápido, mesmo que isto signifique tomar atalhos',
       '22. Meu supervisor/gerente ignora problemas recorrentes na segurança do paciente',
       '23. Recebemos feedback das mudanças implementadas com base nos eventos notificados',
       '24. Os funcionários falam voluntariamente se vêem algo que possa afetar negativamente o atendimento aos pacientes',
       '25. Somos informados sobre os erros que acontecem nesta unidade',
       '26. Os funcionários sentem-se à vontade para questionar decisões ou ações dos que têm mais autoridade',
       '27. Nesta unidade, discutimos maneiras de impedir que os erros tornem a acontecer',
       '28. Os funcionários têm receio de perguntar quando algo não parece certo',
       '29. Quando acontece um erro, mas ele é identificado e corrigido antes de afetar o paciente, com que frequência é notificado?',
       '30. Quando acontece um erro, mas que não tem potencial de dano ao paciente, com que frequência é notificado?',
       '31. Quando acontece um erro que poderia prejudicar o paciente, mas isto não ocorreu, com que frequência é notificado?',
       'Por favor, dê uma nota geral para a segurança do paciente em sua área/unidade de trabalho hospitalar.',
       '32. A administração do hospital cria um ambiente de trabalho que promove a segurança do paciente',
       '33. As unidades hospitalares não se coordenam bem entre si.',
       '34. Coisas "escapam por entre os dedos” quando os pacientes são transferidos de uma unidade para outra',
       '35. Existe uma boa cooperação entre as unidades hospitalares que precisam trabalhar juntas',
       '36. Importantes informações sobre a assistência se perdem durante as mudanças de turno',
       '37. Muitas vezes é desagradável trabalhar unidades com funcionários de outras unidades do hospital',
       '38. Os problemas com frequência ocorrem na troca de informações entre as unidades do hospital',
       '39. As ações da administração do hospital mostram que a segurança do paciente é uma prioridade máxima',
       '40. A administração do hospital parece se interessar pela segurança do paciente apenas quando acontece um evento adverso',
       '41. As unidades do hospital trabalham bem juntas para prestar o melhor atendimento aos pacientes',
       '42. As mudanças de turno são problemáticas para os pacientes deste Hospital']

# %% [markdown]
# # verificando as proporções:

# %%
df_backup1 = df_backup[(df_backup['Ano'] == 2022) & (df_backup['Unidade'] == 'Aliança')].reset_index(drop=True)
df1 = df[(df['Ano'] == 2022) & (df['Unidade'] == 'Anália Franco')].reset_index(drop=True)

for coluna in lista:
    print(coluna, '='*50)
    
    counts = df_backup1[coluna].value_counts()
    percentages = df_backup1[coluna].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'

    # Usando o método 'agg' para juntar contagens e porcentagens em uma mesma DataFrame
    res = pd.DataFrame({'counts': counts, 'percentage': percentages})
    print(res)
    
    print('\n')
    #
    
    counts = df1[coluna].value_counts()
    percentages = df1[coluna].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'

    # Usando o método 'agg' para juntar contagens e porcentagens em uma mesma DataFrame
    res = pd.DataFrame({'counts': counts, 'percentage': percentages})
    print(res)
    
    print('\n')
# Out:
# 1. As pessoas se apoiam umas às outras nesta unidade ==================================================
#                                 counts percentage
# Concordo + Concordo totalmente      32     100.0%
#
#
#    counts percentage
# 1      57      86.4%
# 0       9      13.6%
#
#
# 2. Temos pessoas suficientes para lidar com o volume de trabalho ==================================================
#                                 counts percentage
# Concordo + Concordo totalmente      28      87.5%
# Nem um nem outro                     3       9.4%
# Discordo + Discordo totalmente       1       3.1%
#
#
#    counts percentage
# 0      41      62.1%
# 1      25      37.9%
#
#
# 3. Quando há muito trabalho a ser feito e rapidamente, trabalhamos juntos em equipe para realizar a tarefa ==================================================
#                                 counts percentage
# Concordo + Concordo totalmente      30      93.8%
# Nem um nem outro                     1       3.1%
# Discordo + Discordo totalmente       1       3.1%
#
#
#    counts percentage
# 1      54      81.8%
# 0      12      18.2%
#
#
# 4. Nesta unidade, as pessoas se tratam com respeito ==================================================
#                                 counts percentage
# Concordo + Concordo totalmente      32     100.0%
#
#
#    counts percentage
# 1      57      86.4%
# 0       9      13.6%
#
#
# 5. Os funcionários desta unidade trabalham mais horas do que o recomendado no atendimento a pacientes ==================================================
#                                 counts percentage
# Discordo + Discordo totalmente      13      40.6%
# Nem um nem outro                    10      31.2%
# Concordo + Concordo totalmente       9      28.1%
#
#
#    counts percentage
# 0      53      80.3%
# 1      13      19.7%
#
#
# 6. Estamos ativamente buscando melhorias para a segurança do paciente ==================================================
#                                 counts percentage
# Concordo + Concordo totalmente      32     100.0%
#
#
#    counts percentage
# 1      56      84.8%
# 0      10      15.2%
#
#
# 7. Utilizamos mais funcionários temporários do que o recomendado no atendimento a paciente ==================================================
#                                 counts percentage
# Discordo + Discordo totalmente      19      59.4%
# Nem um nem outro                     9      28.1%
# Concordo + Concordo totalmente       4      12.5%
#
#
#    counts percentage
# 0      34      51.5%
# 1      32      48.5%
#
#
# 8. Os funcionários sentem que seus erros são usados contra eles ==================================================
#                                 counts percentage
# Discordo + Discordo totalmente      18      56.2%
# Nem um nem outro                     9      28.1%
# Concordo + Concordo totalmente       5      15.6%
#
#
#    counts percentage
# 0      39      59.1%
# 1      27      40.9%
#
#
# 9. Erros que ocorreram levaram a mudanças positivas nesta unidade ==================================================
#                                 counts percentage
# Concordo + Concordo totalmente      31      96.9%
# Nem um nem outro                     1       3.1%
#
#
#    counts percentage
# 1      46      70.8%
# 0      19      29.2%
#
#
# 10. É apenas por acaso que erros mais sérios não acontecem por aqui ==================================================
#                                 counts percentage
# Discordo + Discordo totalmente      27      84.4%
# Concordo + Concordo totalmente       3       9.4%
# Nem um nem outro                     2       6.2%
#
#
#    counts percentage
# 1      45      68.2%
# 0      21      31.8%
#
#
# 11. Quando uma área nesta unidade fica muito movimentada, as demais ajudam ==================================================
#                                 counts percentage
# Concordo + Concordo totalmente      25      78.1%
# Nem um nem outro                     4      12.5%
# Discordo + Discordo totalmente       3       9.4%
#
#
#    counts percentage
# 1      33      50.0%
# 0      33      50.0%
#
#
# 12. Quando um evento é notificado, sentimos que o foco se concentra no indivíduo, e não no problema ==================================================
#                                 counts percentage
# Discordo + Discordo totalmente      23      71.9%
# Concordo + Concordo totalmente       5      15.6%
# Nem um nem outro                     4      12.5%
#
#
#    counts percentage
# 1      35      53.0%
# 0      31      47.0%
#
#
# 13. Quando fazemos mudanças para melhorar a segurança do paciente, nós avaliamos sua efetividade ==================================================
#                                 counts percentage
# Concordo + Concordo totalmente      30      93.8%
# Discordo + Discordo totalmente       1       3.1%
# Nem um nem outro                     1       3.1%
#
#
#    counts percentage
# 1      47      71.2%
# 0      19      28.8%
#
#
# 14. Trabalhamos “em modo de crise”, tentando fazer coisas demais, rápido demais ==================================================
#                                 counts percentage
# Discordo + Discordo totalmente      24      77.4%
# Nem um nem outro                     5      16.1%
# Concordo + Concordo totalmente       2       6.5%
#
#
#    counts percentage
# 0      41      62.1%
# 1      25      37.9%
#
#
# 15. A segurança do paciente nunca é sacrificada em prol de se trabalhar mais ==================================================
#                                 counts percentage
# Concordo + Concordo totalmente      25      78.1%
# Discordo + Discordo totalmente       6      18.8%
# Nem um nem outro                     1       3.1%
#
#
#    counts percentage
# 0      42      63.6%
# 1      24      36.4%
#
#
# 16. Os funcionários se preocupam que seus erros sejam registrados em seu arquivo funcional ==================================================
#                                 counts percentage
# Concordo + Concordo totalmente      14      43.8%
# Nem um nem outro                    10      31.2%
# Discordo + Discordo totalmente       8      25.0%
#
#
#    counts percentage
# 0      53      80.3%
# 1      13      19.7%
#
#
# 17. Temos problemas com a segurança do paciente nesta unidade ==================================================
#                                 counts percentage
# Discordo + Discordo totalmente      31      96.9%
# Nem um nem outro                     1       3.1%
#
#
#    counts percentage
# 1      40      60.6%
# 0      26      39.4%
#
#
# 18. Nossos procedimentos e sistemas são bons para impedir que os erros aconteçam ==================================================
#                                 counts percentage
# Concordo + Concordo totalmente      32     100.0%
#
#
#    counts percentage
# 1      51      77.3%
# 0      15      22.7%
#
#
# 19. Meu supervisor/gerente elogia quando vê um trabalho feito de acordo com os procedimentos estabelecidos para a segurança do paciente. ==================================================
#                                 counts percentage
# Concordo + Concordo totalmente      28      87.5%
# Nem um nem outro                     2       6.2%
# Discordo + Discordo totalmente       2       6.2%
#
#
#    counts percentage
# 1      45      68.2%
# 0      21      31.8%
#
#
# 20. Meu supervisor/gerente considera seriamente as sugestões dos funcionários para melhorar a segurança do paciente ==================================================
#                                 counts percentage
# Concordo + Concordo totalmente      28      87.5%
# Nem um nem outro                     3       9.4%
# Discordo + Discordo totalmente       1       3.1%
#
#
#    counts percentage
# 1      50      75.8%
# 0      16      24.2%
#
#
# 21. Sempre que a pressão aumenta, meu supervisor/gerente quer que trabalhemos mais rápido, mesmo que isto signifique tomar atalhos ==================================================
#                                 counts percentage
# Discordo + Discordo totalmente      24      75.0%
# Nem um nem outro                     7      21.9%
# Concordo + Concordo totalmente       1       3.1%
#
#
#    counts percentage
# 1      39      59.1%
# 0      27      40.9%
#
#
# 22. Meu supervisor/gerente ignora problemas recorrentes na segurança do paciente ==================================================
#                                 counts percentage
# Discordo + Discordo totalmente      31      96.9%
# Nem um nem outro                     1       3.1%
#
#
#    counts percentage
# 1      54      81.8%
# 0      12      18.2%
#
#
# 23. Recebemos feedback das mudanças implementadas com base nos eventos notificados ==================================================
#                            counts percentage
# Maioria do tempo + Sempre      24      75.0%
# Algumas vezes                   8      25.0%
#
#
#    counts percentage
# 0      38      57.6%
# 1      28      42.4%
#
#
# 24. Os funcionários falam voluntariamente se vêem algo que possa afetar negativamente o atendimento aos pacientes ==================================================
#                            counts percentage
# Maioria do tempo + Sempre      25      78.1%
# Algumas vezes                   6      18.8%
# Nunca + Raramente               1       3.1%
#    counts percentage
# 1      39      59.1%
# 0      27      40.9%
#
#
# 25. Somos informados sobre os erros que acontecem nesta unidade ==================================================
#                            counts percentage
# Maioria do tempo + Sempre      25      78.1%
# Algumas vezes                   6      18.8%
# Nunca + Raramente               1       3.1%
#
#
#    counts percentage
# 0      37      56.1%
# 1      29      43.9%
#
#
# 26. Os funcionários sentem-se à vontade para questionar decisões ou ações dos que têm mais autoridade ==================================================
#                            counts percentage
# Maioria do tempo + Sempre      18      56.2%
# Algumas vezes                  12      37.5%
# Nunca + Raramente               2       6.2%
#
#
#    counts percentage
# 0      42      63.6%
# 1      24      36.4%
#
#
# 27. Nesta unidade, discutimos maneiras de impedir que os erros tornem a acontecer ==================================================
#                            counts percentage
# Maioria do tempo + Sempre      29      90.6%
# Algumas vezes                   3       9.4%
#
#
#    counts percentage
# 1      40      60.6%
# 0      26      39.4%
#
#
# 28. Os funcionários têm receio de perguntar quando algo não parece certo ==================================================
#                            counts percentage
# Nunca + Raramente              22      68.8%
# Algumas vezes                   7      21.9%
# Maioria do tempo + Sempre       3       9.4%
#
#
#    counts percentage
# 0      41      62.1%
# 1      25      37.9%
#
#
# 29. Quando acontece um erro, mas ele é identificado e corrigido antes de afetar o paciente, com que frequência é notificado? ==================================================
#                            counts percentage
# Maioria do tempo + Sempre      26      81.2%
# Algumas vezes                   5      15.6%
# Nunca + Raramente               1       3.1%
#
#
#    counts percentage
# 1      36      54.5%
# 0      30      45.5%
#
#
# 30. Quando acontece um erro, mas que não tem potencial de dano ao paciente, com que frequência é notificado? ==================================================
#                            counts percentage
# Maioria do tempo + Sempre      22      68.8%
# Algumas vezes                   8      25.0%
# Nunca + Raramente               2       6.2%
#
#
#    counts percentage
# 0      35      53.0%
# 1      31      47.0%
#
#
# 31. Quando acontece um erro que poderia prejudicar o paciente, mas isto não ocorreu, com que frequência é notificado? ==================================================
#                            counts percentage
# Maioria do tempo + Sempre      26      81.2%
# Algumas vezes                   4      12.5%
# Nunca + Raramente               2       6.2%
#
#
#    counts percentage
# 1      37      56.1%
# 0      29      43.9%
#
#
# Por favor, dê uma nota geral para a segurança do paciente em sua área/unidade de trabalho hospitalar. ==================================================
#            counts percentage
# Excelente      22      68.8%
# Muito boa      10      31.2%
#
#
#               counts percentage
# Muito boa         30      46.2%
# Satisfatória      20      30.8%
# Excelente         12      18.5%
# Ruim               3       4.6%
#
#
# 32. A administração do hospital cria um ambiente de trabalho que promove a segurança do paciente ==================================================
#                                 counts percentage
# Concordo + Concordo totalmente      29      90.6%
# Nem um nem outro                     2       6.2%
# Discordo + Discordo totalmente       1       3.1%
#
#
#    counts percentage
# 1      49      74.2%
# 0      17      25.8%
#
#
# 33. As unidades hospitalares não se coordenam bem entre si. ==================================================
#                                 counts percentage
# Discordo + Discordo totalmente      19      59.4%
# Nem um nem outro                     9      28.1%
# Concordo + Concordo totalmente       4      12.5%
#
#
#    counts percentage
# 0      42      63.6%
# 1      24      36.4%
#
#
# 34. Coisas "escapam por entre os dedos” quando os pacientes são transferidos de uma unidade para outra ==================================================
#                                 counts percentage
# Discordo + Discordo totalmente      21      65.6%
# Nem um nem outro                     7      21.9%
# Concordo + Concordo totalmente       4      12.5%
#
#
#    counts percentage
# 0      45      68.2%
# 1      21      31.8%
#
#
# 35. Existe uma boa cooperação entre as unidades hospitalares que precisam trabalhar juntas ==================================================
#                                 counts percentage
# Concordo + Concordo totalmente      24      75.0%
# Nem um nem outro                     5      15.6%
# Discordo + Discordo totalmente       3       9.4%
#
#
#    counts percentage
# 0      34      51.5%
# 1      32      48.5%
#
#
# 36. Importantes informações sobre a assistência se perdem durante as mudanças de turno ==================================================
#                                 counts percentage
# Discordo + Discordo totalmente      23      71.9%
# Concordo + Concordo totalmente       5      15.6%
# Nem um nem outro                     4      12.5%
#
#
#    counts percentage
# 0      38      57.6%
# 1      28      42.4%
#
#
# 37. Muitas vezes é desagradável trabalhar unidades com funcionários de outras unidades do hospital ==================================================
#                                 counts percentage
# Discordo + Discordo totalmente      20      62.5%
# Nem um nem outro                     8      25.0%
# Concordo + Concordo totalmente       4      12.5%
#
#
#    counts percentage
# 0      40      60.6%
# 1      26      39.4%
#
#
# 38. Os problemas com frequência ocorrem na troca de informações entre as unidades do hospital ==================================================
#                                 counts percentage
# Discordo + Discordo totalmente      17      53.1%
# Nem um nem outro                     9      28.1%
# Concordo + Concordo totalmente       6      18.8%
#
#
#    counts percentage
# 0      39      59.1%
# 1      27      40.9%
#
#
# 39. As ações da administração do hospital mostram que a segurança do paciente é uma prioridade máxima ==================================================
#                                 counts percentage
# Concordo + Concordo totalmente      28      87.5%
# Nem um nem outro                     3       9.4%
# Discordo + Discordo totalmente       1       3.1%
#
#
#    counts percentage
# 1      39      59.1%
# 0      27      40.9%
#
#
# 40. A administração do hospital parece se interessar pela segurança do paciente apenas quando acontece um evento adverso ==================================================
#                                 counts percentage
# Discordo + Discordo totalmente      25      78.1%
# Nem um nem outro                     4      12.5%
# Concordo + Concordo totalmente       3       9.4%
#
#
#    counts percentage
# 0      37      56.1%
# 1      29      43.9%
#
#
# 41. As unidades do hospital trabalham bem juntas para prestar o melhor atendimento aos pacientes ==================================================
#                                 counts percentage
# Concordo + Concordo totalmente      27      87.1%
# Nem um nem outro                     4      12.9%
#
#
#    counts percentage
# 1      36      54.5%
# 0      30      45.5%
#
#
# 42. As mudanças de turno são problemáticas para os pacientes deste Hospital ==================================================
#                                 counts percentage
# Discordo + Discordo totalmente      23      71.9%
# Nem um nem outro                     6      18.8%
# Concordo + Concordo totalmente       3       9.4%
#
#
#    counts percentage
# 0      36      54.5%
# 1      30      45.5%

# %%
for i in df.columns:
    print(i, '='*75)
    print(df[i].unique())
    print('\n')
# Out:
# Ano ===========================================================================
# [2014 2015 2016 2017 2018 2019 2020 2021 2022]
#
#
# Unidade ===========================================================================
# ['Coração do Brasil' 'Santa Luzia' 'Esperança' 'Esperança Olinda'
#  'Santa Helena' 'Memorial São José' 'UDI' 'DF Star' 'São Lucas'
#  'São Marcos' 'São Rafael' 'Aliança' 'Cárdio Pulmonar' 'São Carlos'
#  '5 de outubro' 'Proncor' 'Santa Marina' 'Yutaka' 'Aeroporto'
#  'Arthur Ramos' 'HNSN Epitácio' 'HNSN JB' 'Santa Emília' "Barra D'Or"
#  "Oeste D'Or" "Caxias D'Or" "Copa D'Or" 'Criança RJ' "Rios D'Or"
#  "Norte D'Or" "Quinta D'Or" 'Bangu' "Glória D'Or" 'Jutta Batista'
#  'Perinatal Barra' 'Perinatal Laranjeiras' 'Balbino' 'Copa Star' 'Samer'
#  'São Vicente' "Niterói D'Or" 'Anália Franco' 'Assunção' 'Itaim' 'Brasil'
#  'Jabaquara' 'Morumbi' 'IFOR' 'Villa Lobos' 'viValle' 'Bartira' 'Osasco'
#  'Criança SP' 'Ribeirão Pires' 'Alpha Med' 'Jabaquara/ Criança'
#  'São Caetano' 'Vivalle' 'Vila Nova Star' 'Aviccena' 'Santa Cruz'
#  'Brasil Mauá' 'Central Leste' 'Serra Mayor' 'Antônio Afonso'
#  'Novo Atibaia' 'Orthoservice' 'Santa Isabel']
#
#
# Qual é sua principal área ou unidade neste hospital? ===========================================================================
# ['Anestesiologia']
#
#
# 1. As pessoas se apoiam umas às outras nesta unidade ===========================================================================
# [1 0 nan]
#
#
# 2. Temos pessoas suficientes para lidar com o volume de trabalho ===========================================================================
# [1 0 nan]
#
#
# 3. Quando há muito trabalho a ser feito e rapidamente, trabalhamos juntos em equipe para realizar a tarefa ===========================================================================
# [1 0 nan]
#
#
# 4. Nesta unidade, as pessoas se tratam com respeito ===========================================================================
# [1 0 nan]
#
#
# 5. Os funcionários desta unidade trabalham mais horas do que o recomendado no atendimento a pacientes ===========================================================================
# [1 0 nan]
#
#
# 6. Estamos ativamente buscando melhorias para a segurança do paciente ===========================================================================
# [1 0 nan]
#
#
# 7. Utilizamos mais funcionários temporários do que o recomendado no atendimento a paciente ===========================================================================
# [1 0 nan]
#
#
# 8. Os funcionários sentem que seus erros são usados contra eles ===========================================================================
# [1 0 nan]
#
#
# 9. Erros que ocorreram levaram a mudanças positivas nesta unidade ===========================================================================
# [1 0 nan]
#
#
# 10. É apenas por acaso que erros mais sérios não acontecem por aqui ===========================================================================
# [1 0 nan]
#
#
# 11. Quando uma área nesta unidade fica muito movimentada, as demais ajudam ===========================================================================
# [1 0 nan]
#
#
# 12. Quando um evento é notificado, sentimos que o foco se concentra no indivíduo, e não no problema ===========================================================================
# [1 0 nan]
#
#
# 13. Quando fazemos mudanças para melhorar a segurança do paciente, nós avaliamos sua efetividade ===========================================================================
# [1 0 nan]
#
#
# 14. Trabalhamos “em modo de crise”, tentando fazer coisas demais, rápido demais ===========================================================================
# [1 0 nan]
#
#
# 15. A segurança do paciente nunca é sacrificada em prol de se trabalhar mais ===========================================================================
# [1 0 nan]
#
#
# 16. Os funcionários se preocupam que seus erros sejam registrados em seu arquivo funcional ===========================================================================
# [0 1 nan]
#
#
# 17. Temos problemas com a segurança do paciente nesta unidade ===========================================================================
# [1 0 nan]
#
#
# 18. Nossos procedimentos e sistemas são bons para impedir que os erros aconteçam ===========================================================================
# [1 0 nan]
#
#
# 19. Meu supervisor/gerente elogia quando vê um trabalho feito de acordo com os procedimentos estabelecidos para a segurança do paciente. ===========================================================================
# [1 0 nan]
#
#
# 20. Meu supervisor/gerente considera seriamente as sugestões dos funcionários para melhorar a segurança do paciente ===========================================================================
# [1 0 nan]
#
#
# 21. Sempre que a pressão aumenta, meu supervisor/gerente quer que trabalhemos mais rápido, mesmo que isto signifique tomar atalhos ===========================================================================
# [1 0 nan]
#
#
# 22. Meu supervisor/gerente ignora problemas recorrentes na segurança do paciente ===========================================================================
# [1 0 nan]
#
#
# 23. Recebemos feedback das mudanças implementadas com base nos eventos notificados ===========================================================================
# [1 0 nan]
#
#
# 24. Os funcionários falam voluntariamente se vêem algo que possa afetar negativamente o atendimento aos pacientes ===========================================================================
# [1 0 nan]
#
#
# 25. Somos informados sobre os erros que acontecem nesta unidade ===========================================================================
# [1 0 nan]
#
#
# 26. Os funcionários sentem-se à vontade para questionar decisões ou ações dos que têm mais autoridade ===========================================================================
# [1 0 nan]
#
#
# 27. Nesta unidade, discutimos maneiras de impedir que os erros tornem a acontecer ===========================================================================
# [1 nan 0]
#
#
# 28. Os funcionários têm receio de perguntar quando algo não parece certo ===========================================================================
# [1 0 nan]
#
#
# 29. Quando acontece um erro, mas ele é identificado e corrigido antes de afetar o paciente, com que frequência é notificado? ===========================================================================
# [1 0 nan]
#
#
# 30. Quando acontece um erro, mas que não tem potencial de dano ao paciente, com que frequência é notificado? ===========================================================================
# [1 0 nan]
#
#
# 31. Quando acontece um erro que poderia prejudicar o paciente, mas isto não ocorreu, com que frequência é notificado? ===========================================================================
# [1 0 nan]
#
#
# Por favor, dê uma nota geral para a segurança do paciente em sua área/unidade de trabalho hospitalar. ===========================================================================
# ['Muito boa' 'Excelente' 'Satisfatória' 'Ruim' nan 'Muito ruim']
#
#
# 32. A administração do hospital cria um ambiente de trabalho que promove a segurança do paciente ===========================================================================
# [1 0 nan]
#
#
# 33. As unidades hospitalares não se coordenam bem entre si. ===========================================================================
# [1 0 nan]
#
#
# 34. Coisas "escapam por entre os dedos” quando os pacientes são transferidos de uma unidade para outra ===========================================================================
# [1 0 nan]
#
#
# 35. Existe uma boa cooperação entre as unidades hospitalares que precisam trabalhar juntas ===========================================================================
# [1 0 nan]
#
#
# 36. Importantes informações sobre a assistência se perdem durante as mudanças de turno ===========================================================================
# [1 0 nan]
#
#
# 37. Muitas vezes é desagradável trabalhar unidades com funcionários de outras unidades do hospital ===========================================================================
# [1 0 nan]
#
#
# 38. Os problemas com frequência ocorrem na troca de informações entre as unidades do hospital ===========================================================================
# [1 0 nan]
#
#
# 39. As ações da administração do hospital mostram que a segurança do paciente é uma prioridade máxima ===========================================================================
# [1 0 nan]
#
#
# 40. A administração do hospital parece se interessar pela segurança do paciente apenas quando acontece um evento adverso ===========================================================================
# [1 0 nan]
#
#
# 41. As unidades do hospital trabalham bem juntas para prestar o melhor atendimento aos pacientes ===========================================================================
# [1 0 nan]
#
#
# 42. As mudanças de turno são problemáticas para os pacientes deste Hospital ===========================================================================
# [1 0 nan]
#
#
# SEÇÃO G: Número de Eventos Notificados  Nos últimos 12 meses, quantas notificações de evento você preencheu e enviou? ===========================================================================
# ['a. Nenhuma notificações de eventos' 'b. 1 a 2 notificações de eventos'
#  'c. 3 a 5 notificações de eventos' 'e. 11 a 20 notificações de eventos'
#  'd. 6 a 10 notificações de eventos'
#  'f. 21 notificações de eventos ou mais' nan]
#
#
# SEÇÃO H: 1. Há quanto tempo você trabalha neste hospital? ===========================================================================
# ['6 a 10 anos' '21 anos ou mais' '1 a 5 anos' '11 a 15 anos'
#  'menos de 1 ano' '16 a 20 anos' nan]
#
#
# SEÇÃO H: 2.Há quanto tempo você trabalha nesta área/unidade de trabalho hospitalar? ===========================================================================
# ['6 a 10 anos' '21 anos ou mais' 'menos de 1 ano' '11 a 15 anos'
#  '1 a 5 anos' '16 a 20 anos' nan]
#
#
# SEÇÃO H: 3.Tipicamente, quantas horas por semana você trabalha neste hospital?   ===========================================================================
# ['a. Menos de 20 horas por semana' 'b. 20 a 39 horas por semana'
#  'c. 40 a 59 horas por semana' 'd. 60 a 79 horas por semana' nan
#  'e. 80 a 99 horas por semana' 'f. 100 horas por semana ou mais']
#
#
# 5. Em sua função, você tipicamente tem contato ou interação direta com os pacientes?   ===========================================================================
# ['a. SIM, tipicamente tenho contato ou interação direta com os pacientes.'
#  'b. NÃO, tipicamente não tenho contato ou interação direta com os pacientes.']
#
#
# 6. Há quanto tempo você trabalha em sua profissão ou especialização atual?   ===========================================================================
# ['c. 6 a 10 anos' 'f. 21 anos ou mais' 'd. 11 a 15 anos' 'e. 16 a 20 anos'
#  'b. 1 a 5 anos' 'a. Menos de 1 ano' nan]
#
#
# Regional ===========================================================================
# ['CO' 'NE' 'N' 'SE' 'SUL']
#
#
# Estado ===========================================================================
# ['DF' 'PE' 'MA' 'SE' 'BA' 'CE' 'PA' 'MS' 'AL' 'PB' 'RJ' 'SP' 'PR ']
#
#
# Acreditação ===========================================================================
# [0 'ONA' 'Qmentum' 'JCI']
#
#
# Cargo ===========================================================================
# ['Médico' 'Tecnico de Enfermeiro' nan 'Outros' 'Enfermeiro'
#  'Tecnico Enfermeiro']
#
#
# Acreditação2 ===========================================================================
# [0 'ONA 2' 'Qmentum' 'ONA 3' 'JCI' 'ONA 1']
#
#
# acreditacao ===========================================================================
# [0 1]

# %%
coluna = 'SEÇÃO G: Número de Eventos Notificados  Nos últimos 12 meses, quantas notificações de evento você preencheu e enviou?'

print(df[coluna].value_counts(), '\n')
df['SEÇÃO G2: Notificou algum evento nos ultimos 12 meses'] = 0
df['SEÇÃO G2: Notificou algum evento nos ultimos 12 meses'][df[coluna] != 'a. Nenhuma notificações de eventos'] = 1
df['SEÇÃO G2: Notificou algum evento nos ultimos 12 meses'][pd.isnull(df[coluna])] = np.nan
print(df['SEÇÃO G2: Notificou algum evento nos ultimos 12 meses'].value_counts(),'\n')

#################################################################################################
df[coluna][df[coluna] == 'a. Nenhuma notificações de eventos'] = '0. Nenhuma notificações de eventos'
df[coluna][df[coluna] == 'b. 1 a 2 notificações de eventos'] = '1. 1 a 2 notificações de eventos'
df[coluna][df[coluna] == 'c. 3 a 5 notificações de eventos'] = '2. 3 a 5 notificações de eventos'
df[coluna][df[coluna] == 'd. 6 a 10 notificações de eventos'] = '3. 6 a 10 notificações de eventos'
df[coluna][df[coluna] == 'e. 11 a 20 notificações de eventos'] = '4. 11 a 20 notificações de eventos'
df[coluna][df[coluna] == 'f. 21 notificações de eventos ou mais'] = '5. 21 notificações de eventos ou mais'
print(df[coluna].value_counts())

# Gerando as variáveis dummy
dummies = pd.get_dummies(df[coluna], prefix=coluna)
df = pd.concat([df, dummies], axis=1)
# Out:
# a. Nenhuma notificações de eventos       903
# b. 1 a 2 notificações de eventos         776
# c. 3 a 5 notificações de eventos         637
# f. 21 notificações de eventos ou mais    545
# d. 6 a 10 notificações de eventos        460
# e. 11 a 20 notificações de eventos       354
# Name: SEÇÃO G: Número de Eventos Notificados  Nos últimos 12 meses, quantas notificações de evento você preencheu e enviou?, dtype: int64
#
# 1.0    2772
# 0.0     903
# Name: SEÇÃO G2: Notificou algum evento nos ultimos 12 meses, dtype: int64
#
# 0. Nenhuma notificações de eventos       903
# 1. 1 a 2 notificações de eventos         776
# 2. 3 a 5 notificações de eventos         637
# 5. 21 notificações de eventos ou mais    545
# 3. 6 a 10 notificações de eventos        460
# 4. 11 a 20 notificações de eventos       354
# Name: SEÇÃO G: Número de Eventos Notificados  Nos últimos 12 meses, quantas notificações de evento você preencheu e enviou?, dtype: int64

# %%
coluna = 'SEÇÃO H: 1. Há quanto tempo você trabalha neste hospital?'
df[coluna].unique()
# Out:
# array(['6 a 10 anos', '21 anos ou mais', '1 a 5 anos', '11 a 15 anos',
#        'menos de 1 ano', '16 a 20 anos', nan], dtype=object)

# %%
#Na unidade tem muito funcionario que sobrecarregado ?
coluna = 'SEÇÃO H: 3.Tipicamente, quantas horas por semana você trabalha neste hospital?  '
print(df[coluna].value_counts(),'\n')

df['SEÇÃO H: 3.2 Trabalha mais que 40horas semanais'] = 1
df['SEÇÃO H: 3.2 Trabalha mais que 40horas semanais'][(df[coluna] == 'a. Menos de 20 horas por semana') |
                                                        (df[coluna] == 'b. 20 a 39 horas por semana')] = 0
df['SEÇÃO H: 3.2 Trabalha mais que 40horas semanais'][pd.isnull(df[coluna])] = np.nan
print(df['SEÇÃO H: 3.2 Trabalha mais que 40horas semanais'].value_counts(), '\n')

##########################################################################
df['SEÇÃO H: 3.2 Trabalha mais que 60horas semanais'] = 1
df['SEÇÃO H: 3.2 Trabalha mais que 60horas semanais'][(df[coluna] == 'a. Menos de 20 horas por semana') |
                                                      (df[coluna] == 'b. 20 a 39 horas por semana') |
                                                      (df[coluna] == 'c. 40 a 59 horas por semana')] = 0
df['SEÇÃO H: 3.2 Trabalha mais que 60horas semanais'][pd.isnull(df[coluna])] = np.nan
print(df['SEÇÃO H: 3.2 Trabalha mais que 60horas semanais'].value_counts(), '\n')

##########################################################################
df['SEÇÃO H: 3.2 Trabalha mais que 80horas semanais'] = 0
df['SEÇÃO H: 3.2 Trabalha mais que 80horas semanais'][(df[coluna] == 'e. 80 a 99 horas por semana') |
                                                      (df[coluna] == 'f. 100 horas por semana ou mais')] = 1
df['SEÇÃO H: 3.2 Trabalha mais que 80horas semanais'][pd.isnull(df[coluna])] = np.nan
print(df['SEÇÃO H: 3.2 Trabalha mais que 80horas semanais'].value_counts(), '\n')

##########################################################################
coluna2 = 'SEÇÃO H: Horas trabalhadas semanais'
df[coluna2] = np.nan
df[coluna2][df[coluna] == 'a. Menos de 20 horas por semana'] = '0. 20 a 39'
df[coluna2][df[coluna] == 'b. 20 a 39 horas por semana'] = '0. 20 a 39'
df[coluna2][df[coluna] == 'c. 40 a 59 horas por semana'] = '1. 40 a - 79'
df[coluna2][df[coluna] == 'd. 60 a 79 horas por semana'] = '1. 40 a - 79'
df[coluna2][df[coluna] == 'e. 80 a 99 horas por semana'] = '2. > 80'
df[coluna2][df[coluna] == 'f. 100 horas por semana ou mais'] = '2. > 80'

########################################################################## ARRUMANDO OS NIVEIS
coluna = "SEÇÃO H: 3.Tipicamente, quantas horas por semana você trabalha neste hospital?  "
df[coluna][df[coluna] == 'a. Menos de 20 horas por semana'] = '1. Menos de 20 horas por semana'
df[coluna][df[coluna] == 'b. 20 a 39 horas por semana'] = '2. 20 a 39 horas por semana'
df[coluna][df[coluna] == 'c. 40 a 59 horas por semana'] = '3. 40 a 59 horas por semana'
df[coluna][df[coluna] == 'd. 60 a 79 horas por semana'] = '4. 60 a 79 horas por semana'
df[coluna][df[coluna] == 'e. 80 a 99 horas por semana'] = '5. 80 a 99 horas por semana'
df[coluna][df[coluna] == 'f. 100 horas por semana ou mais'] = '6. 100 horas por semana ou mais'
# Out:
# b. 20 a 39 horas por semana        1272
# a. Menos de 20 horas por semana    1127
# c. 40 a 59 horas por semana         778
# d. 60 a 79 horas por semana         386
# e. 80 a 99 horas por semana          96
# f. 100 horas por semana ou mais      18
# Name: SEÇÃO H: 3.Tipicamente, quantas horas por semana você trabalha neste hospital?  , dtype: int64
#
# 0.0    2399
# 1.0    1278
# Name: SEÇÃO H: 3.2 Trabalha mais que 40horas semanais, dtype: int64
#
# 0.0    3177
# 1.0     500
# Name: SEÇÃO H: 3.2 Trabalha mais que 60horas semanais, dtype: int64
#
# 0.0    3563
# 1.0     114
# Name: SEÇÃO H: 3.2 Trabalha mais que 80horas semanais, dtype: int64

# %%
coluna = 'Por favor, dê uma nota geral para a segurança do paciente em sua área/unidade de trabalho hospitalar.'
print(df[coluna].value_counts(),'\n')

# Gerando as variáveis dummy
dummies = pd.get_dummies(df[coluna], prefix=coluna)
df = pd.concat([df, dummies], axis=1)

df['Nota Geral == Satisfatoria ?'] = 1
df['Nota Geral == Satisfatoria ?'][(df[coluna] == 'Ruim') |
                                   (df[coluna] == 'Muito ruim')] = 0
df['Nota Geral == Satisfatoria ?'][pd.isnull(df[coluna])] = np.nan
print(df['Nota Geral == Satisfatoria ?'].value_counts(), '\n')

##########################################################################
df['Nota Geral == Boa ?'] = 1
df['Nota Geral == Boa ?'][(df[coluna] == 'Ruim') |
                          (df[coluna] == 'Muito ruim') |
                         (df[coluna] == 'Satisfatória')] = 0
df['Nota Geral == Boa ?'][pd.isnull(df[coluna])] = np.nan
print(df['Nota Geral == Boa ?'].value_counts(), '\n')

##########################################################################
df['Nota Geral'] = 1
df['Nota Geral'][(df[coluna] == 'Ruim') |
                   (df[coluna] == 'Muito ruim')] = 0
df['Nota Geral'][df[coluna] == 'Satisfatória'] = 1
df['Nota Geral'][(df[coluna] == 'Excelente') |
                   (df[coluna] == 'Muito boa')] = 2
df['Nota Geral'][pd.isnull(df[coluna])] = np.nan
print(df['Nota Geral'].value_counts(), '\n')

########################################################################## ARRUMANDO NIVEIS
df[coluna][df[coluna] == 'Muito ruim'] = '0. Muito ruim'
df[coluna][df[coluna] == 'Ruim'] = '1. Ruim'
df[coluna][df[coluna] == 'Satisfatória'] = '2. Satisfatória'
df[coluna][df[coluna] == 'Excelente'] = '3. Excelente'
df[coluna][df[coluna] == 'Muito boa'] = '4. Muito boa'
print(df[coluna].value_counts(),'\n')
# Out:
# Muito boa       1413
# Excelente       1066
# Satisfatória     952
# Ruim             198
# Muito ruim        44
# Name: Por favor, dê uma nota geral para a segurança do paciente em sua área/unidade de trabalho hospitalar., dtype: int64
#
# 1.0    3431
# 0.0     242
# Name: Nota Geral == Satisfatoria ?, dtype: int64
#
# 1.0    2479
# 0.0    1194
# Name: Nota Geral == Boa ?, dtype: int64
#
# 2.0    2479
# 1.0     952
# 0.0     242
# Name: Nota Geral, dtype: int64
#
# 4. Muito boa       1413
# 3. Excelente       1066
# 2. Satisfatória     952
# 1. Ruim             198
# 0. Muito ruim        44
# Name: Por favor, dê uma nota geral para a segurança do paciente em sua área/unidade de trabalho hospitalar., dtype: int64

# %%
df.columns
# Out:
# Index(['Ano', 'Unidade',
#        'Qual é sua principal área ou unidade neste hospital?',
#        '1. As pessoas se apoiam umas às outras nesta unidade',
#        '2. Temos pessoas suficientes para lidar com o volume de trabalho',
#        '3. Quando há muito trabalho a ser feito e rapidamente, trabalhamos juntos em equipe para realizar a tarefa',
#        '4. Nesta unidade, as pessoas se tratam com respeito',
#        '5. Os funcionários desta unidade trabalham mais horas do que o recomendado no atendimento a pacientes',
#        '6. Estamos ativamente buscando melhorias para a segurança do paciente',
#        '7. Utilizamos mais funcionários temporários do que o recomendado no atendimento a paciente',
#        '8. Os funcionários sentem que seus erros são usados contra eles',
#        '9. Erros que ocorreram levaram a mudanças positivas nesta unidade',
#        '10. É apenas por acaso que erros mais sérios não acontecem por aqui',
#        '11. Quando uma área nesta unidade fica muito movimentada, as demais ajudam',
#        '12. Quando um evento é notificado, sentimos que o foco se concentra no indivíduo, e não no problema',
#        '13. Quando fazemos mudanças para melhorar a segurança do paciente, nós avaliamos sua efetividade',
#        '14. Trabalhamos “em modo de crise”, tentando fazer coisas demais, rápido demais',
#        '15. A segurança do paciente nunca é sacrificada em prol de se trabalhar mais',
#        '16. Os funcionários se preocupam que seus erros sejam registrados em seu arquivo funcional',
#        '17. Temos problemas com a segurança do paciente nesta unidade',
#        '18. Nossos procedimentos e sistemas são bons para impedir que os erros aconteçam',
#        '19. Meu supervisor/gerente elogia quando vê um trabalho feito de acordo com os procedimentos estabelecidos para a segurança do paciente.',
#        '20. Meu supervisor/gerente considera seriamente as sugestões dos funcionários para melhorar a segurança do paciente',
#        '21. Sempre que a pressão aumenta, meu supervisor/gerente quer que trabalhemos mais rápido, mesmo que isto signifique tomar atalhos',
#        '22. Meu supervisor/gerente ignora problemas recorrentes na segurança do paciente',
#        '23. Recebemos feedback das mudanças implementadas com base nos eventos notificados',
#        '24. Os funcionários falam voluntariamente se vêem algo que possa afetar negativamente o atendimento aos pacientes',
#        '25. Somos informados sobre os erros que acontecem nesta unidade',
#        '26. Os funcionários sentem-se à vontade para questionar decisões ou ações dos que têm mais autoridade',
#        '27. Nesta unidade, discutimos maneiras de impedir que os erros tornem a acontecer',
#        '28. Os funcionários têm receio de perguntar quando algo não parece certo',
#        '29. Quando acontece um erro, mas ele é identificado e corrigido antes de afetar o paciente, com que frequência é notificado?',
#        '30. Quando acontece um erro, mas que não tem potencial de dano ao paciente, com que frequência é notificado?',
#        '31. Quando acontece um erro que poderia prejudicar o paciente, mas isto não ocorreu, com que frequência é notificado?',
#        'Por favor, dê uma nota geral para a segurança do paciente em sua área/unidade de trabalho hospitalar.',
#        '32. A administração do hospital cria um ambiente de trabalho que promove a segurança do paciente',
#        '33. As unidades hospitalares não se coordenam bem entre si.',
#        '34. Coisas "escapam por entre os dedos” quando os pacientes são transferidos de uma unidade para outra',
#        '35. Existe uma boa cooperação entre as unidades hospitalares que precisam trabalhar juntas',
#        '36. Importantes informações sobre a assistência se perdem durante as mudanças de turno',
#        '37. Muitas vezes é desagradável trabalhar unidades com funcionários de outras unidades do hospital',
#        '38. Os problemas com frequência ocorrem na troca de informações entre as unidades do hospital',
#        '39. As ações da administração do hospital mostram que a segurança do paciente é uma prioridade máxima',
#        '40. A administração do hospital parece se interessar pela segurança do paciente apenas quando acontece um evento adverso',
#        '41. As unidades do hospital trabalham bem juntas para prestar o melhor atendimento aos pacientes',
#        '42. As mudanças de turno são problemáticas para os pacientes deste Hospital',
#        'SEÇÃO G: Número de Eventos Notificados  Nos últimos 12 meses, quantas notificações de evento você preencheu e enviou?',
#        'SEÇÃO H: 1. Há quanto tempo você trabalha neste hospital?',
#        'SEÇÃO H: 2.Há quanto tempo você trabalha nesta área/unidade de trabalho hospitalar?',
#        'SEÇÃO H: 3.Tipicamente, quantas horas por semana você trabalha neste hospital?  ',
#        '5. Em sua função, você tipicamente tem contato ou interação direta com os pacientes?  ',
#        '6. Há quanto tempo você trabalha em sua profissão ou especialização atual?  ',
#        'Regional', 'Estado', 'Acreditação', 'Cargo', 'Acreditação2',
#        'acreditacao', 'SEÇÃO G2: Notificou algum evento nos ultimos 12 meses',
#        'SEÇÃO G: Número de Eventos Notificados  Nos últimos 12 meses, quantas notificações de evento você preencheu e enviou?_0. Nenhuma notificações de eventos',
#        'SEÇÃO G: Número de Eventos Notificados  Nos últimos 12 meses, quantas notificações de evento você preencheu e enviou?_1. 1 a 2 notificações de eventos',
#        'SEÇÃO G: Número de Eventos Notificados  Nos últimos 12 meses, quantas notificações de evento você preencheu e enviou?_2. 3 a 5 notificações de eventos',
#        'SEÇÃO G: Número de Eventos Notificados  Nos últimos 12 meses, quantas notificações de evento você preencheu e enviou?_3. 6 a 10 notificações de eventos',
#        'SEÇÃO G: Número de Eventos Notificados  Nos últimos 12 meses, quantas notificações de evento você preencheu e enviou?_4. 11 a 20 notificações de eventos',
#        'SEÇÃO G: Número de Eventos Notificados  Nos últimos 12 meses, quantas notificações de evento você preencheu e enviou?_5. 21 notificações de eventos ou mais',
#        'SEÇÃO H: 3.2 Trabalha mais que 40horas semanais',
#        'SEÇÃO H: 3.2 Trabalha mais que 60horas semanais',
#        'SEÇÃO H: 3.2 Trabalha mais que 80horas semanais',
#        'SEÇÃO H: Horas trabalhadas semanais',
#        'Por favor, dê uma nota geral para a segurança do paciente em sua área/unidade de trabalho hospitalar._Excelente',
#        'Por favor, dê uma nota geral para a segurança do paciente em sua área/unidade de trabalho hospitalar._Muito boa',
#        'Por favor, dê uma nota geral para a segurança do paciente em sua área/unidade de trabalho hospitalar._Muito ruim',
#        'Por favor, dê uma nota geral para a segurança do paciente em sua área/unidade de trabalho hospitalar._Ruim',
#        'Por favor, dê uma nota geral para a segurança do paciente em sua área/unidade de trabalho hospitalar._Satisfatória',
#        'Nota Geral == Satisfatoria ?', 'Nota Geral == Boa ?', 'Nota Geral'],
#       dtype='object')

# %%
print(df['Qual é sua principal área ou unidade neste hospital?'].value_counts(),'\n')

df['Setor'] = np.nan
df['Setor'][df['Qual é sua principal área ou unidade neste hospital?'] == 'Administrativa'] = 'Gestão'
df['Setor'][df['Qual é sua principal área ou unidade neste hospital?'] == 'Anestesiologia'] = 'Processo Cirurgico ou Obstétrico'
df['Setor'][df['Qual é sua principal área ou unidade neste hospital?'] == 'Cardiologia Intervencionistas'] = 'Processo Cirurgico ou Obstétrico'
df['Setor'][df['Qual é sua principal área ou unidade neste hospital?'] == 'Central de Material Esterilizado'] = 'Área de Apoio'
df['Setor'][df['Qual é sua principal área ou unidade neste hospital?'] == 'Centro Cirúrgico'] = 'Processo Cirurgico ou Obstétrico'
df['Setor'][df['Qual é sua principal área ou unidade neste hospital?'] == 'Centro Obstétrico'] = 'Processo Cirurgico ou Obstétrico'
df['Setor'][df['Qual é sua principal área ou unidade neste hospital?'] == 'Diretoria'] = 'Gestão'
df['Setor'][df['Qual é sua principal área ou unidade neste hospital?'] == 'Emergência adulto'] = 'Emergência'
df['Setor'][df['Qual é sua principal área ou unidade neste hospital?'] == 'Emergência ginecologia'] = 'Emergência'
df['Setor'][df['Qual é sua principal área ou unidade neste hospital?'] == 'Emergência pediátrica'] = 'Emergência'
df['Setor'][df['Qual é sua principal área ou unidade neste hospital?'] == 'Endoscopia'] = 'Processo Cirurgico ou Obstétrico'
df['Setor'][df['Qual é sua principal área ou unidade neste hospital?'] == 'Farmácia'] = 'Área de Apoio'
df['Setor'][df['Qual é sua principal área ou unidade neste hospital?'] == 'Gerência'] = 'Área de Apoio'
df['Setor'][df['Qual é sua principal área ou unidade neste hospital?'] == 'Laboratório Clínico'] = 'Serviço Diagnóstico'
df['Setor'][df['Qual é sua principal área ou unidade neste hospital?'] == 'Maternidade'] = 'Processo Cirurgico ou Obstétrico'
df['Setor'][df['Qual é sua principal área ou unidade neste hospital?'] == 'Nutrição'] = 'Área de Apoio'
df['Setor'][df['Qual é sua principal área ou unidade neste hospital?'] == 'Pediatria'] = 'UI'
df['Setor'][df['Qual é sua principal área ou unidade neste hospital?'] == 'Psiquiatria/Saúde mental'] = 'UI'
df['Setor'][df['Qual é sua principal área ou unidade neste hospital?'] == 'Radiologia'] = 'Serviço Diagnóstico'
df['Setor'][df['Qual é sua principal área ou unidade neste hospital?'] == 'Reabilitação'] = 'Área de Apoio'
df['Setor'][df['Qual é sua principal área ou unidade neste hospital?'] == 'Ressonância Magnética'] = 'Serviço Diagnóstico'
df['Setor'][df['Qual é sua principal área ou unidade neste hospital?'] == 'Suprimentos'] = 'Área de Apoio'
df['Setor'][df['Qual é sua principal área ou unidade neste hospital?'] == 'Ultrassonografia'] = 'Área de Apoio'
df['Setor'][df['Qual é sua principal área ou unidade neste hospital?'] == 'Unidade de Internação adulto'] = 'UI'
df['Setor'][df['Qual é sua principal área ou unidade neste hospital?'] == 'Unidade de Internação neonatal/ berçário'] = 'UI'
df['Setor'][df['Qual é sua principal área ou unidade neste hospital?'] == 'Unidade de Internação pediátrica'] = 'UI'
df['Setor'][df['Qual é sua principal área ou unidade neste hospital?'] == 'Unidade de terapia intensiva adulto'] = 'UTI'
df['Setor'][df['Qual é sua principal área ou unidade neste hospital?'] == 'Unidade de terapia intensiva neonatal'] = 'UTI'
df['Setor'][df['Qual é sua principal área ou unidade neste hospital?'] == 'Unidade de terapia intensiva pediátrica'] = 'UTI'

print(df['Setor'].value_counts(), '\n')
# Out:
# Anestesiologia    3705
# Name: Qual é sua principal área ou unidade neste hospital?, dtype: int64
#
# Processo Cirurgico ou Obstétrico    3705
# Name: Setor, dtype: int64

# %%
print(df['SEÇÃO H: 1. Há quanto tempo você trabalha neste hospital?'].value_counts(), '\n')

#Verificar a rotatividade do hospital
df['SEÇÃO H: 1.2 trabalha a mais de 1 ano no hospital?'] = 0
df['SEÇÃO H: 1.2 trabalha a mais de 1 ano no hospital?'][df['SEÇÃO H: 1. Há quanto tempo você trabalha neste hospital?'] != 'menos de 1 ano'] = 1
df['SEÇÃO H: 1.2 trabalha a mais de 1 ano no hospital?'][pd.isnull(df['SEÇÃO H: 1. Há quanto tempo você trabalha neste hospital?'])] = np.nan
print(df['SEÇÃO H: 1.2 trabalha a mais de 1 ano no hospital?'].value_counts(), '\n')

df['SEÇÃO H: 1.3 trabalha a mais de 5 anos no hospital?'] = 1
df['SEÇÃO H: 1.3 trabalha a mais de 5 anos no hospital?'][(df['SEÇÃO H: 1. Há quanto tempo você trabalha neste hospital?'] == 'menos de 1 ano') | 
                                                          (df['SEÇÃO H: 1. Há quanto tempo você trabalha neste hospital?'] == '1 a 5 anos')] = 0
df['SEÇÃO H: 1.3 trabalha a mais de 5 anos no hospital?'][pd.isnull(df['SEÇÃO H: 1. Há quanto tempo você trabalha neste hospital?'])] = np.nan
print(df['SEÇÃO H: 1.3 trabalha a mais de 5 anos no hospital?'].value_counts())
# Out:
# 1 a 5 anos         1481
# menos de 1 ano      886
# 6 a 10 anos         559
# 11 a 15 anos        323
# 21 anos ou mais     227
# 16 a 20 anos        196
# Name: SEÇÃO H: 1. Há quanto tempo você trabalha neste hospital?, dtype: int64
#
# 1.0    2786
# 0.0     886
# Name: SEÇÃO H: 1.2 trabalha a mais de 1 ano no hospital?, dtype: int64
#
# 0.0    2367
# 1.0    1305
# Name: SEÇÃO H: 1.3 trabalha a mais de 5 anos no hospital?, dtype: int64

# %%
colunas = ["SEÇÃO H: 1. Há quanto tempo você trabalha neste hospital?",
           'SEÇÃO H: 2.Há quanto tempo você trabalha nesta área/unidade de trabalho hospitalar?',
           "6. Há quanto tempo você trabalha em sua profissão ou especialização atual?  "]

for coluna in colunas:
    print('\n')
    df[coluna][df[coluna] == 'a. Menos de 1 ano'] = '0. Menos de 1 ano'
    df[coluna][df[coluna] == 'Menos de 1 ano'] = '0. Menos de 1 ano'
    df[coluna][df[coluna] == 'menos de 1 ano'] = '0. Menos de 1 ano'
    
    df[coluna][df[coluna] == 'b. 1 a 5 anos'] = '1. 1 a 5 anos'
    df[coluna][df[coluna] == '1 a 5 anos'] = '1. 1 a 5 anos'
    
    df[coluna][df[coluna] == 'c. 6 a 10 anos'] = '2. 6 a 10 anos'
    df[coluna][df[coluna] == '6 a 10 anos'] = '2. 6 a 10 anos'
    
    df[coluna][df[coluna] == 'd. 11 a 15 anos'] = '3. 11 a 15 anos'
    df[coluna][df[coluna] == '11 a 15 anos'] = '3. 11 a 15 anos'
    
    df[coluna][df[coluna] == 'e. 16 a 20 anos'] = '4. 16 a 20 anos'
    df[coluna][df[coluna] == '16 a 20 anos'] = '4. 16 a 20 anos'
    
    df[coluna][df[coluna] == 'f. 21 anos ou mais'] = '5. 21 anos ou mais'
    df[coluna][df[coluna] == '21 anos ou mais'] = '5. 21 anos ou mais'
    
    print(df[coluna].value_counts())
# Out:
# 1. 1 a 5 anos         1481
# 0. Menos de 1 ano      886
# 2. 6 a 10 anos         559
# 3. 11 a 15 anos        323
# 5. 21 anos ou mais     227
# 4. 16 a 20 anos        196
# Name: SEÇÃO H: 1. Há quanto tempo você trabalha neste hospital?, dtype: int64
#
#
# 1. 1 a 5 anos         1463
# 0. Menos de 1 ano      814
# 2. 6 a 10 anos         579
# 3. 11 a 15 anos        350
# 5. 21 anos ou mais     247
# 4. 16 a 20 anos        224
# Name: SEÇÃO H: 2.Há quanto tempo você trabalha nesta área/unidade de trabalho hospitalar?, dtype: int64
#
#
# 1. 1 a 5 anos         1297
# 2. 6 a 10 anos         716
# 5. 21 anos ou mais     555
# 3. 11 a 15 anos        456
# 4. 16 a 20 anos        372
# 0. Menos de 1 ano      277
# Name: 6. Há quanto tempo você trabalha em sua profissão ou especialização atual?  , dtype: int64

# %%
coluna = 'SEÇÃO H: 1. Há quanto tempo você trabalha neste hospital?'
# Gerando as variáveis dummy
dummies = pd.get_dummies(df[coluna], prefix=coluna)
df = pd.concat([df, dummies], axis=1)

# %%
df.columns
# Out:
# Index(['Ano', 'Unidade',
#        'Qual é sua principal área ou unidade neste hospital?',
#        '1. As pessoas se apoiam umas às outras nesta unidade',
#        '2. Temos pessoas suficientes para lidar com o volume de trabalho',
#        '3. Quando há muito trabalho a ser feito e rapidamente, trabalhamos juntos em equipe para realizar a tarefa',
#        '4. Nesta unidade, as pessoas se tratam com respeito',
#        '5. Os funcionários desta unidade trabalham mais horas do que o recomendado no atendimento a pacientes',
#        '6. Estamos ativamente buscando melhorias para a segurança do paciente',
#        '7. Utilizamos mais funcionários temporários do que o recomendado no atendimento a paciente',
#        '8. Os funcionários sentem que seus erros são usados contra eles',
#        '9. Erros que ocorreram levaram a mudanças positivas nesta unidade',
#        '10. É apenas por acaso que erros mais sérios não acontecem por aqui',
#        '11. Quando uma área nesta unidade fica muito movimentada, as demais ajudam',
#        '12. Quando um evento é notificado, sentimos que o foco se concentra no indivíduo, e não no problema',
#        '13. Quando fazemos mudanças para melhorar a segurança do paciente, nós avaliamos sua efetividade',
#        '14. Trabalhamos “em modo de crise”, tentando fazer coisas demais, rápido demais',
#        '15. A segurança do paciente nunca é sacrificada em prol de se trabalhar mais',
#        '16. Os funcionários se preocupam que seus erros sejam registrados em seu arquivo funcional',
#        '17. Temos problemas com a segurança do paciente nesta unidade',
#        '18. Nossos procedimentos e sistemas são bons para impedir que os erros aconteçam',
#        '19. Meu supervisor/gerente elogia quando vê um trabalho feito de acordo com os procedimentos estabelecidos para a segurança do paciente.',
#        '20. Meu supervisor/gerente considera seriamente as sugestões dos funcionários para melhorar a segurança do paciente',
#        '21. Sempre que a pressão aumenta, meu supervisor/gerente quer que trabalhemos mais rápido, mesmo que isto signifique tomar atalhos',
#        '22. Meu supervisor/gerente ignora problemas recorrentes na segurança do paciente',
#        '23. Recebemos feedback das mudanças implementadas com base nos eventos notificados',
#        '24. Os funcionários falam voluntariamente se vêem algo que possa afetar negativamente o atendimento aos pacientes',
#        '25. Somos informados sobre os erros que acontecem nesta unidade',
#        '26. Os funcionários sentem-se à vontade para questionar decisões ou ações dos que têm mais autoridade',
#        '27. Nesta unidade, discutimos maneiras de impedir que os erros tornem a acontecer',
#        '28. Os funcionários têm receio de perguntar quando algo não parece certo',
#        '29. Quando acontece um erro, mas ele é identificado e corrigido antes de afetar o paciente, com que frequência é notificado?',
#        '30. Quando acontece um erro, mas que não tem potencial de dano ao paciente, com que frequência é notificado?',
#        '31. Quando acontece um erro que poderia prejudicar o paciente, mas isto não ocorreu, com que frequência é notificado?',
#        'Por favor, dê uma nota geral para a segurança do paciente em sua área/unidade de trabalho hospitalar.',
#        '32. A administração do hospital cria um ambiente de trabalho que promove a segurança do paciente',
#        '33. As unidades hospitalares não se coordenam bem entre si.',
#        '34. Coisas "escapam por entre os dedos” quando os pacientes são transferidos de uma unidade para outra',
#        '35. Existe uma boa cooperação entre as unidades hospitalares que precisam trabalhar juntas',
#        '36. Importantes informações sobre a assistência se perdem durante as mudanças de turno',
#        '37. Muitas vezes é desagradável trabalhar unidades com funcionários de outras unidades do hospital',
#        '38. Os problemas com frequência ocorrem na troca de informações entre as unidades do hospital',
#        '39. As ações da administração do hospital mostram que a segurança do paciente é uma prioridade máxima',
#        '40. A administração do hospital parece se interessar pela segurança do paciente apenas quando acontece um evento adverso',
#        '41. As unidades do hospital trabalham bem juntas para prestar o melhor atendimento aos pacientes',
#        '42. As mudanças de turno são problemáticas para os pacientes deste Hospital',
#        'SEÇÃO G: Número de Eventos Notificados  Nos últimos 12 meses, quantas notificações de evento você preencheu e enviou?',
#        'SEÇÃO H: 1. Há quanto tempo você trabalha neste hospital?',
#        'SEÇÃO H: 2.Há quanto tempo você trabalha nesta área/unidade de trabalho hospitalar?',
#        'SEÇÃO H: 3.Tipicamente, quantas horas por semana você trabalha neste hospital?  ',
#        '5. Em sua função, você tipicamente tem contato ou interação direta com os pacientes?  ',
#        '6. Há quanto tempo você trabalha em sua profissão ou especialização atual?  ',
#        'Regional', 'Estado', 'Acreditação', 'Cargo', 'Acreditação2',
#        'acreditacao', 'SEÇÃO G2: Notificou algum evento nos ultimos 12 meses',
#        'SEÇÃO G: Número de Eventos Notificados  Nos últimos 12 meses, quantas notificações de evento você preencheu e enviou?_0. Nenhuma notificações de eventos',
#        'SEÇÃO G: Número de Eventos Notificados  Nos últimos 12 meses, quantas notificações de evento você preencheu e enviou?_1. 1 a 2 notificações de eventos',
#        'SEÇÃO G: Número de Eventos Notificados  Nos últimos 12 meses, quantas notificações de evento você preencheu e enviou?_2. 3 a 5 notificações de eventos',
#        'SEÇÃO G: Número de Eventos Notificados  Nos últimos 12 meses, quantas notificações de evento você preencheu e enviou?_3. 6 a 10 notificações de eventos',
#        'SEÇÃO G: Número de Eventos Notificados  Nos últimos 12 meses, quantas notificações de evento você preencheu e enviou?_4. 11 a 20 notificações de eventos',
#        'SEÇÃO G: Número de Eventos Notificados  Nos últimos 12 meses, quantas notificações de evento você preencheu e enviou?_5. 21 notificações de eventos ou mais',
#        'SEÇÃO H: 3.2 Trabalha mais que 40horas semanais',
#        'SEÇÃO H: 3.2 Trabalha mais que 60horas semanais',
#        'SEÇÃO H: 3.2 Trabalha mais que 80horas semanais',
#        'SEÇÃO H: Horas trabalhadas semanais',
#        'Por favor, dê uma nota geral para a segurança do paciente em sua área/unidade de trabalho hospitalar._Excelente',
#        'Por favor, dê uma nota geral para a segurança do paciente em sua área/unidade de trabalho hospitalar._Muito boa',
#        'Por favor, dê uma nota geral para a segurança do paciente em sua área/unidade de trabalho hospitalar._Muito ruim',
#        'Por favor, dê uma nota geral para a segurança do paciente em sua área/unidade de trabalho hospitalar._Ruim',
#        'Por favor, dê uma nota geral para a segurança do paciente em sua área/unidade de trabalho hospitalar._Satisfatória',
#        'Nota Geral == Satisfatoria ?', 'Nota Geral == Boa ?', 'Nota Geral',
#        'Setor', 'SEÇÃO H: 1.2 trabalha a mais de 1 ano no hospital?',
#        'SEÇÃO H: 1.3 trabalha a mais de 5 anos no hospital?',
#        'SEÇÃO H: 1. Há quanto tempo você trabalha neste hospital?_0. Menos de 1 ano',
#        'SEÇÃO H: 1. Há quanto tempo você trabalha neste hospital?_1. 1 a 5 anos',
#        'SEÇÃO H: 1. Há quanto tempo você trabalha neste hospital?_2. 6 a 10 anos',
#        'SEÇÃO H: 1. Há quanto tempo você trabalha neste hospital?_3. 11 a 15 anos',
#        'SEÇÃO H: 1. Há quanto tempo você trabalha neste hospital?_4. 16 a 20 anos',
#        'SEÇÃO H: 1. Há quanto tempo você trabalha neste hospital?_5. 21 anos ou mais'],
#       dtype='object')

# %%
df.columns = [col.strip() for col in df.columns]

coluna = "6. Há quanto tempo você trabalha em sua profissão ou especialização atual?"
# Gerando as variáveis dummy
dummies = pd.get_dummies(df[coluna], prefix=coluna)
df = pd.concat([df, dummies], axis=1)

# %%
df.to_excel('0 - Dados Limpos.xlsx', index=False)
df_bruto = df.copy()
len(df)
# Out:
# 3705

# %%
print('quantidade de linhas:',len(df))
print('quantidade de coluna:',len(df.columns))
print('quantidade de dados:',len(df)*len(df.columns))
# Out:
# quantidade de linhas: 3705
# quantidade de coluna: 92
# quantidade de dados: 340860

# %% [raw]
# # inicio = time.time() #iniciando o cronometro
#
# df = pd.read_excel('0 - Dados Limpos.xlsx')
# df.sample(5)
#
# fim = time.time() #encerrando cronometro
# print('Tempo para rodar a simulação:', round(fim - inicio, 3))

# %%
stop
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12624\3957423419.py in <module>
# ----> 1 stop
#
# NameError: name 'stop' is not defined

# %% [markdown]
# # TESTES / ANALISES =================================

# %%
for i in lista:
    print('coluna:', i)
    print('0: mean(', round(resultado[i][resultado['acreditacao'] == 0].mean(),4), ') ; median(', round(resultado[i][resultado['acreditacao'] == 0].median(),4), ')')
    print('1: mean(', round(resultado[i][resultado['acreditacao'] == 1].mean(),4), ') ; median(', round(resultado[i][resultado['acreditacao'] == 1].median(),4), ')')
    
    a = resultado[i][resultado['acreditacao'] == 0] # amostra a
    b = resultado[i][resultado['acreditacao'] == 1] # amostra b
    ttest = round(stats.ttest_ind(a,b)[1], 4)
    mann = round(stats.mannwhitneyu(a, b)[1], 4)
    print('pvalor:  '+str(ttest)+'             '+str(mann))
    
    grupos = resultado['acreditacao'].unique()

    plt.figure(figsize=(10,2))

    for grupo in grupos:

        if grupo == 0:
            label_grupo = "Sem Acreditação"
        else:
            label_grupo = "Com Acreditação"

        sns.kdeplot(resultado[resultado['acreditacao'] == grupo][i], label=label_grupo)

    plt.axvline(x = resultado[i][resultado['acreditacao'] == 0].mean(), color='red', linestyle='--', label='Média sem')
    plt.axvline(x = resultado[i][resultado['acreditacao'] == 0].median(), color='blue', linestyle='--', label='Mediana sem')

    plt.axvline(x = resultado[i][resultado['acreditacao'] == 1].mean(), color='orange', linestyle='--', label='Média com')
    plt.axvline(x = resultado[i][resultado['acreditacao'] == 1].median(), color='brown', linestyle='--', label='Mediana com')

    plt.title(i)
    plt.legend()
    plt.show()
    
    print('='*125)

# %% [markdown]
# # APLICANDO ANOVA:

# %%
resultado1 = resultado.rename(columns={"42. As mudanças de turno são problemáticas para os pacientes deste Hospital": "var_num"})

# Ajuste o modelo
modelo = ols('var_num ~ C(acreditacao) + C(Regional) + C(acreditacao):C(Regional)', data=resultado1).fit()

# Realize a ANOVA e imprima a tabela de resultados
anova_table = sm.stats.anova_lm(modelo, typ=2)
print(anova_table)

# %%
modelo = ols('var_num ~ C(acreditacao)', data = resultado1).fit()

# Realize a ANOVA e imprima a tabela de resultados
anova_table = sm.stats.anova_lm(modelo, typ=2)
print(anova_table)

# %%
resultado['Regional2'] = np.nan
resultado['Regional2'][(resultado['Regional'] == 'SUL') | (resultado['Regional'] == 'SE')] = 'SUL'
resultado['Regional2'][(resultado['Regional'] == 'N') | (resultado['Regional'] == 'NE')] = 'NORTE'
resultado['Regional2'][resultado['Regional'] == 'CO'] = 'CO'
print(resultado['Regional2'].value_counts())

##########
resultado['Regional3'] = resultado['Regional2']
resultado['Regional3'][(resultado['Regional2'] == 'CO') | (resultado['Regional2'] == 'NORTE')] = 'NORTE_OC'
print(resultado['Regional3'].value_counts())

# %%
#resultado.to_excel('tabela3.xlsx')

# %%
for i in lista:
    print('coluna:', i)
    print('NORTE_OC: mean(', round(resultado[i][resultado['Regional3'] == 'NORTE_OC'].mean(),4), ') ; median(', round(resultado[i][resultado['Regional3'] == 'NORTE_OC'].median(),4), ')')
    print('SUL: mean(', round(resultado[i][resultado['Regional3'] == 'SUL'].mean(),4), ') ; median(', round(resultado[i][resultado['Regional3'] == 'SUL'].median(),4), ')')
    
    a = resultado[i][resultado['Regional3'] == 'NORTE_OC'] # amostra a
    b = resultado[i][resultado['Regional3'] == 'SUL'] # amostra b
    ttest = round(stats.ttest_ind(a,b)[1], 4)
    mann = round(stats.mannwhitneyu(a, b)[1], 4)
    print('pvalor:  '+str(ttest)+'             '+str(mann))
    
    grupos = resultado['Regional3'].unique()

    plt.figure(figsize=(10,2))

    for grupo in grupos:

        if grupo == 'NORTE_OC':
            label_grupo = "NORTE"
        else:
            label_grupo = "SUL"

        sns.kdeplot(resultado[resultado['Regional3'] == grupo][i], label=label_grupo)

    plt.axvline(x = resultado[i][resultado['Regional3'] == 'NORTE_OC'].mean(), color='red', linestyle='--', label='Média NORTE')
    plt.axvline(x = resultado[i][resultado['Regional3'] == 'NORTE_OC'].median(), color='blue', linestyle='--', label='Mediana NORTE')

    plt.axvline(x = resultado[i][resultado['Regional3'] == 'SUL'].mean(), color='orange', linestyle='--', label='Média SUL')
    plt.axvline(x = resultado[i][resultado['Regional3'] == 'SUL'].median(), color='brown', linestyle='--', label='Mediana SUL')

    plt.title(i)
    plt.legend()
    plt.show()
    
    print('='*125)

# %%
df

# %%
df = pd.read_excel("tabela3.xlsx")
print(len(df))
df.sample(5)

# %% [markdown]
# # VERFICANDO SE HOUVE MELHORA

# %%
for i in lista:
    print('coluna:', i)
    print('0: mean(', round(tabela[i][tabela['acreditacao'] == 0].mean(),4), ') ; median(', round(tabela[i][tabela['acreditacao'] == 0].median(),4), ')')
    print('1: mean(', round(tabela[i][tabela['acreditacao'] == 1].mean(),4), ') ; median(', round(tabela[i][tabela['acreditacao'] == 1].median(),4), ')')
    
    a = tabela[i][tabela['acreditacao'] == 0] # amostra a
    b = tabela[i][tabela['acreditacao'] == 1] # amostra b
    ttest = round(stats.ttest_ind(a,b)[1], 4)
    mann = round(stats.mannwhitneyu(a, b)[1], 4)
    print('pvalor:  '+str(ttest)+'             '+str(mann))
    
    grupos = tabela['acreditacao'].unique()

    plt.figure(figsize=(10,2))

    for grupo in grupos:

        if grupo == 0:
            label_grupo = "Sem Acreditação"
        else:
            label_grupo = "Com Acreditação"

        sns.kdeplot(tabela[tabela['acreditacao'] == grupo][i], label=label_grupo)

    plt.axvline(x = tabela[i][tabela['acreditacao'] == 0].mean(), color='red', linestyle='--', label='Média sem')
    plt.axvline(x = tabela[i][tabela['acreditacao'] == 0].median(), color='blue', linestyle='--', label='Mediana sem')

    plt.axvline(x = tabela[i][tabela['acreditacao'] == 1].mean(), color='orange', linestyle='--', label='Média com')
    plt.axvline(x = tabela[i][tabela['acreditacao'] == 1].median(), color='brown', linestyle='--', label='Mediana com')

    plt.title(i)
    plt.legend()
    plt.show()
    
    print('='*125)

# %%
count = 0
for unidade in sorted(df['Unidade'].unique()):
    if len(df['acreditacao'][df['Unidade'] == unidade].unique()) == 1:
        if df['acreditacao'][df['Unidade'] == unidade].unique()[0] == 0:
            print(unidade, '='*25)
            print(df[df['Unidade'] == unidade].groupby(['Ano', 'acreditacao']).size(), '\n')
            count += 1
            
print('='*25, 'QUANTIDADE:', count, '='*25)

# %%
count = 0 
for unidade in sorted(df['Unidade'].unique()):
    if len(df['acreditacao'][df['Unidade'] == unidade].unique()) == 1:
        if df['acreditacao'][df['Unidade'] == unidade].unique()[0] == 1:
            print(unidade, '='*25)
            print(df[df['Unidade'] == unidade].groupby(['Ano', 'acreditacao']).size(), '\n')
            count += 1
            
print('='*25, 'QUANTIDADE:', count, '='*25)

# %% [markdown]
# # Existe uma mudança no score com o passar do tempo

# %%
#tabela = df[df['acreditacao'] == 1].reset_index(drop=True)
#tabela = df
count = 0 
for coluna in lista:
    subtitulo = ''
    mediana = df.groupby(['Ano', 'acreditacao'])[coluna].median().unstack().reset_index()
    
    ##############################################################################################
    for acre in range(0, 2):
        X = df['Ano'][df['acreditacao'] == acre]
        Y = df[coluna][df['acreditacao'] == acre]
        X = sm.add_constant(X)
        model = sm.OLS(Y, X)
        results = model.fit()
        p_valor = round(results.pvalues['Ano'], 3)
        if p_valor < 0.001:p_valor="<0.001"
        coef = str(round(results.params['Ano'], 2))
        interval = results.conf_int(alpha=0.05).loc['Ano']
        interval_0 = str(round(interval[0], 2))
        interval_1 = str(round(interval[1], 2))
        subtitulo = coef + ' (' + interval_0 + ' - ' + interval_1 + ')'
        subtitulo = 'p-valor = ' + str(p_valor) + ' | '+ subtitulo
        subtitulo = subtitulo + " | R² = " + str(round(results.rsquared, 2))
        
        subtitulo = str(round(Y.mean(), 2)) + " | " + subtitulo

        plt.figure(figsize=(10,3))
        if acre == 0:
            cor = "red"
            plt.title(coluna, fontproperties=fonte, fontsize=16)
        else:
            cor = 'blue'
        sns.scatterplot(x="Ano", y=coluna, data=df[df['acreditacao'] == acre],
                           edgecolor = "black", color = cor)
        sns.lineplot(x='Ano', y=acre, data = mediana, color = 'green')
        sns.lineplot(x="Ano", y=coluna, data=df[df['acreditacao'] == acre], color = 'red')

        plt.xlabel(subtitulo, fontproperties=fonte, fontsize=13)
        plt.ylabel(str(acre)+'acreditação', fontproperties=fonte, fontsize=13)
        plt.ylim(0, 100)
        plt.show()

        ##############################################################################################

# %%
#tabela = df[df['acreditacao'] == 1].reset_index(drop=True)
#tabela = df
count = 0 
for coluna in lista:
    subtituloo = ''
    plt.figure(figsize=(10,3))
    sns.lineplot(x="Ano", y=coluna, hue='acreditacao', data=df)
    plt.title(coluna, fontproperties=fonte, fontsize=16)
    plt.ylabel('Score Médio', fontproperties=fonte, fontsize=13)
    #plt.ylim(0, 100)
    
    ##############################################################################################
    for acre in range(0, 2):
        X = df['Ano'][df['acreditacao'] == acre]
        Y = df[coluna][df['acreditacao'] == acre]
        X = sm.add_constant(X)
        model = sm.OLS(Y, X)
        results = model.fit()
        p_valor = round(results.pvalues['Ano'], 3)
        if p_valor < 0.001:p_valor="<0.001"
        coef = str(round(results.params['Ano'], 2))
        interval = results.conf_int(alpha=0.05).loc['Ano']
        interval_0 = str(round(interval[0], 2))
        interval_1 = str(round(interval[1], 2))
        subtitulo = coef + ' (' + interval_0 + ' - ' + interval_1 + ')'
        subtitulo = 'p-valor = ' + str(p_valor) + ' | '+ subtitulo
        subtitulo = subtitulo + " | R² = " + str(round(results.rsquared, 2))
        
        subtitulo = str(round(Y.mean(), 2)) + " | " + subtitulo
        subtitulo = str(acre) + "=> " + subtitulo
        subtitulo = subtitulo + " | " + str(round(durbin_watson(results.resid), 2))
        
        if acre == 1:
            subtituloo = subtituloo + '\n' + subtitulo
        else:
            subtituloo = subtituloo + subtitulo
    
    plt.xlabel(subtituloo, fontproperties=fonte, fontsize=13)
    plt.show()

        ##############################################################################################

# %%
durbinWatson = durbin_watson(results.resid)
round(durbinWatson, 2)

# %%
for i in lista:
    print('='*25, i, '='*25)
    Y = df[i]
    X = df[['Ano', 'acreditacao']]
    X = sm.add_constant(X)
    model = sm.OLS(Y, X)
    results = model.fit()
    print(results.summary())
    durbinWatson = durbin_watson(results.resid)
    print('\n')
    print('O valor de Durbin-Watson é:', durbinWatson)
    print('\n')

# %%
df

# %%
df

# %%
lista2 = ['Abertura de comunicação','Feedback e comunicação sobre erros',
          'Frequência de eventos relatados','Apoio de gestão hospitalar para segurança do paciente',
          'Trabalho em equipe entre as unidades hospitalares','Trabalho em equipe no âmbito das unidades',
          'Transferências internas e passagens de plantão','Aprendizado organizacional - melhoria contínua',
          'Expectativas de promoção da segurança dos supervisores e gerentes','Percepção gerais sobre segurança',
          'Respostas não punitivas aos erros','Staffing']
count = 0 
for coluna in lista2:
    subtituloo = ''
    plt.figure(figsize=(10,3))
    sns.lineplot(x="Ano", y=coluna, hue='acreditacao', data=df)
    plt.title(coluna, fontproperties=fonte, fontsize=16)
    plt.ylabel('Score Médio', fontproperties=fonte, fontsize=13)
    #plt.ylim(0, 100)
    
    ##############################################################################################
    for acre in range(0, 2):
        X = df['Ano'][df['acreditacao'] == acre]
        Y = df[coluna][df['acreditacao'] == acre]
        X = sm.add_constant(X)
        model = sm.OLS(Y, X)
        results = model.fit()
        p_valor = round(results.pvalues['Ano'], 3)
        if p_valor < 0.001:p_valor="<0.001"
        coef = str(round(results.params['Ano'], 2))
        interval = results.conf_int(alpha=0.05).loc['Ano']
        interval_0 = str(round(interval[0], 2))
        interval_1 = str(round(interval[1], 2))
        subtitulo = coef + ' (' + interval_0 + ' - ' + interval_1 + ')'
        subtitulo = 'p-valor = ' + str(p_valor) + ' | '+ subtitulo
        subtitulo = subtitulo + " | R² = " + str(round(results.rsquared, 2))
        
        subtitulo = str(round(Y.mean(), 2)) + " | " + subtitulo
        subtitulo = str(acre) + "=> " + subtitulo
        subtitulo = subtitulo + " | " + str(round(durbin_watson(results.resid), 2))
        
        if acre == 1:
            subtituloo = subtituloo + '\n' + subtitulo
        else:
            subtituloo = subtituloo + subtitulo
    
    plt.xlabel(subtituloo, fontproperties=fonte, fontsize=13)
    plt.show()

        ##############################################################################################

# %%
tabela

# %%
for i in lista2:
    print('coluna:', i)
    print('0: mean(', round(tabela[i][tabela['acreditacao'] == 0].mean(),4), ') ; median(', round(tabela[i][tabela['acreditacao'] == 0].median(),4), ')')
    print('1: mean(', round(tabela[i][tabela['acreditacao'] == 1].mean(),4), ') ; median(', round(tabela[i][tabela['acreditacao'] == 1].median(),4), ')')
    
    a = tabela[i][tabela['acreditacao'] == 0] # amostra a
    b = tabela[i][tabela['acreditacao'] == 1] # amostra b
    ttest = round(stats.ttest_ind(a,b)[1], 4)
    mann = round(stats.mannwhitneyu(a, b)[1], 4)
    print('pvalor:  '+str(ttest)+'             '+str(mann))
    
    grupos = tabela['acreditacao'].unique()

    plt.figure(figsize=(10,2))

    for grupo in grupos:

        if grupo == 0:
            label_grupo = "Sem Acreditação"
        else:
            label_grupo = "Com Acreditação"

        sns.kdeplot(tabela[tabela['acreditacao'] == grupo][i], label=label_grupo)

    plt.axvline(x = tabela[i][tabela['acreditacao'] == 0].mean(), color='red', linestyle='--', label='Média sem')
    plt.axvline(x = tabela[i][tabela['acreditacao'] == 0].median(), color='blue', linestyle='--', label='Mediana sem')

    plt.axvline(x = tabela[i][tabela['acreditacao'] == 1].mean(), color='orange', linestyle='--', label='Média com')
    plt.axvline(x = tabela[i][tabela['acreditacao'] == 1].median(), color='brown', linestyle='--', label='Mediana com')

    plt.title(i)
    plt.legend()
    plt.show()
    
    print('='*125)
